# %%
import pandas as pd
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df[df.Opening_date.dt.year == 2017]
df2.head()
# Out:
#     Store_id State         Town                          Street  \
# 160     4203    AZ  Fort Mohave                  5210 S Hwy. 95
# 211     6477    AZ      Phoenix            9600 N Metro Pkwy. W
# 237     5725    AZ       Tucson          831 E Fort Lowell Road
# 260     7368    AR  Bentonville             1300 S Walton Blvd.
# 345      241    AR       Rogers  4206 S Pleasant Crossing Blvd.
#
#                   Category Opening_date Closing_date
# 160    Walmart Supercenter   2017-07-19          NaT
# 211    Walmart Supercenter   2017-10-11          NaT
# 237    Neighborhood Market   2017-05-24          NaT
# 260  Convenience with Fuel   2017-09-13          NaT
# 345  Convenience with Fuel   2017-01-31          NaT

# %%
df3.tail(60)
# Out:
#      Store_id State     Town          Street             Category  \
# 4669     2305    CT  Bristol  325 Oakland St  Neighborhood Market
#
#      Opening_date Closing_date  year
# 4669         2013         2017  2017

# %%
df = pd.read_csv('fandom_traitées.csv')
df.sort_values("Opening_date")
df["year"]=df["Opening_date"].str[-4:]
df2=df[df["Town"]=="Dover"]
df2.sort_values("year").tail(60)
# Out:
#      Store_id State   Town         Street             Category Opening_date  \
# 772      1736    DE  Dover  36 Jerome Dr.  Walmart Supercenter   12/31/1991
# 4768     4306    TN  Dover      934 US-79  Neighborhood Market      unknown
#
#      Closing_date  year
# 772           NaN  1991
# 4768    1/17/2016  nown

# %%
old_df = pd.read_csv('walmart_opening_1962_2006.csv')
old_df2 = old_df[old_df["state"]=="AR"]
df3 = old_df2.sort_values("city")
df3.head(60)
# Out:
#         opendate                     st.address                 city state  \
# 330   1981-06-02            200 HIGHWAY 64 WEST                 Alma    AR
# 267   1980-04-15             109 W.P. MALONE DR          Arkadelphia    AR
# 127   1976-05-01            1040 S CONSTITUTION              Ashdown    AR
# 145   1977-01-01                219 HIGHWAY 412              Ashflat    AR
# 120   1976-03-01           3150 HARRISON STREET           Batesville    AR
# 77    1974-04-01                     17309 I-30               Benton    AR
# 0     1962-03-01  5801 SW Regional Airport Blvd          Bentonville    AR
# 94    1974-10-01          406 SOUTH WALTON BLVD          Bentonville    AR
# 69    1973-11-01              1000 WEST TRIMBLE           Berryville    AR
# 52    1972-11-01               3700 EAST HWY 18          Blytheville    AR
# 48    1972-10-01                 1555 EAST MAIN           Booneville    AR
# ...
