# %%
import pandas as pd
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Closing_date>='2016-01-01')&(df.Closing_date<='2016-01-31')].groupby("State")["Store_id"].count()
df2.head(50)
# Out:
# State
# AL     9
# AR    11
# CA     9
# CO     2
# CT     1
# FL     3
# GA     7
# IL     2
# KS     9
# LA     8
# MD     1
# MI     1
# MO     4
# MS     6
# NC    17
# NV     1
# OH     1
# OK     6
# OR     2
# SC     3
# TN     5
# TX    29
# WI     4
# WV     1
# Name: Store_id, dtype: int64

# %%
import pandas as pd
import numpy as np
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
pd.set_option("display.max_rows", None)
df[np.vectorize(str)(df.Opening_date)=='NaT'].sort_values("State")
# Out:
#      Store_id State      County_name  County_fips            Town  Town_lat  \
# 4720     3769    AL         Marshall         1095           Grant   34.5190
# 4724     2260    AL           Blount         1009           Snead   34.1162
# 4723     2165    AL           Geneva         1061         Slocomb   31.1103
# 4722     3779    AL          Madison         1089        New Hope   34.5370
# 4717     2011    AL          Houston         1069         Ashford   31.1858
# 4719     2235    AL          Madison         1089          Gurley   34.7072
# 4721     2173    AL            Henry         1067        Headland   31.3501
# 4730     4217    AR           Benton         5007         Decatur   36.3402
# 4729     3878    AR        Van Buren         5141        Damascus   35.3671
# 4727     2669    AR          Johnson         5071       Coal Hill   35.4375
# 4726     2601    AR         Franklin         5047      Charleston   35.2948
# ...

# %%
import pandas as pd
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Opening_date>='2016-01-01')&(df.Opening_date<='2016-01-31')].groupby("State")["Store_id"].count()
df2.head(50)
# Out:
# State
# AL     6
# AR     1
# AZ     2
# CA     2
# FL     4
# GA     7
# IN     2
# KS     1
# KY     1
# LA     8
# MO     3
# MS     3
# NC     5
# NM     1
# OK     3
# OR     1
# PA     1
# SC     2
# TN     5
# TX    10
# Name: Store_id, dtype: int64

# %%
df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Opening_date>='2016-01-01')&(df.Opening_date<='2016-01-31')].groupby("Category")["Store_id"].count()
df2.head(50)
# Out:
# Category
# Neighborhood Market    60
# Walmart Supercenter     8
# Name: Store_id, dtype: int64

# %%
df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Opening_date>='2016-01-01')&(df.Opening_date<='2016-01-31')]
df2 = df2[df2["State"]=="AL"]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df2)
# Out:
#     Store_id State         Town                   Street             Category  \
# 10      4673    AL       Auburn    1810 Shug Jordan Pkwy  Neighborhood Market
# 11      5062    AL       Auburn     2047 E University Dr  Neighborhood Market
# 65      5716    AL   Huntsville  9020 Bailey Cove Rd. SE  Neighborhood Market
# 90      4672    AL   Montgomery          1600 Federal Dr  Neighborhood Market
# 107     5903    AL  Phenix City               3864 US-80  Neighborhood Market
# 122     5744    AL     Theodore  7320 Theodore Dawes Rd.  Neighborhood Market
#
#     Opening_date Closing_date
# 10    2016-01-27          NaT
# 11    2016-01-13          NaT
# 65    2016-01-27          NaT
# 90    2016-01-27          NaT
# 107   2016-01-20          NaT
# 122   2016-01-27          NaT

# %%
import pandas as pd
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Closing_date>='2016-01-01')&(df.Closing_date<='2016-01-31')]
df2 = df2[df2["State"]=="WI"]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df2)
df2.describe()
# Out:
#      Store_id State             Town                 Street  \
# 4815     3031    WI  Menomonee Falls     N88W15559 Main St.
# 4816     3496    WI        Milwaukee        5825 W Hope Ave
# 4817     5698    WI         Waukesha  S14W22605 Coral Drive
# 4818     3030    WI        Wauwatosa       3850 N 124th St.
#
#                  Category Opening_date Closing_date
# 4815  Neighborhood Market   1900-01-01   2016-01-28
# 4816              Walmart   2002-08-14   2016-01-28
# 4817  Neighborhood Market   1900-01-01   2016-01-28
# 4818  Neighborhood Market   1900-01-01   2016-01-28
# C:\Users\inesn\AppData\Local\Temp\ipykernel_6512\4148253924.py:9: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df2.describe()
# ...

# %%
import pandas as pd
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Opening_date>='2016-01-01')&(df.Opening_date<='2016-01-31')]

with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df2)
    
df2.describe()
# Out:
#      Store_id State             Town                          Street  \
# 10       4673    AL           Auburn           1810 Shug Jordan Pkwy
# 11       5062    AL           Auburn            2047 E University Dr
# 65       5716    AL       Huntsville         9020 Bailey Cove Rd. SE
# 90       4672    AL       Montgomery                 1600 Federal Dr
# 107      5903    AL      Phenix City                      3864 US-80
# 122      5744    AL         Theodore         7320 Theodore Dawes Rd.
# 235      4490    AZ           Tucson    2565 E Commerce Center Place
# 248      7320    AZ             Yuma                  2675 W 8th St.
# 324      4654    AR           Marion                      2100 AR-77
# 463      5008    CA            Hemet              859 W Florida Ave.
# 637      5859    CA            Wasco            401 N Central Avenue
# 850      2946    FL  Fort Lauderdale        2500 W Broward Boulevard
# 908       525    FL        Lake Mary            825 Casa Verde Blvd.
# ...

# %%
df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Opening_date>='2016-01-31')&(df.Opening_date<='2017-01-31')]
df3 = df2[df2["State"]=="TN"]
df3.head(10)
# Out:
#      Store_id State         Town                     Street  \
# 3645     3959    TN    Knoxville          3120 McKamey Road
# 3652     7020    TN    La Vergne     5511 Murfreesboro Road
# 3671     6807    TN      Memphis  6727 Raleigh Lagrange Rd.
# 3703     5908    TN  Sevierville    1185 Dolly Parton Pkwy.
#
#                  Category Opening_date Closing_date
# 3645  Neighborhood Market   2017-01-25          NaT
# 3652  Walmart Supercenter   2016-08-24          NaT
# 3671  Walmart Supercenter   2016-06-22          NaT
# 3703  Neighborhood Market   2016-03-02          NaT

# %%
df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df.loc[(df.Closing_date>='2015-01-31')&(df.Closing_date<='2017-01-31')]
df3 = df2[df2["State"]=="TN"]
df3.head(10)
# Out:
#      Store_id State   Town     Street             Category Opening_date  \
# 4771     4306    TN  Dover  934 US-79  Neighborhood Market          NaT
#
#      Closing_date
# 4771   2016-01-17

# %%
df = pd.read_csv('fandom_traitées.csv')
df2=df[(df["State"]=="TN")&(df["Category"]=="Neighborhood Market")]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df2)
# Out:
#      Store_id State          Town                      Street  \
# 3588     3599    TN      Bartlett  6520 Memphis Arlington Rd.
# 3595     3619    TN   Chattanooga  3901 Hixson Pike Suite 181
# 3596     5143    TN   Chattanooga      8101 East Brainerd Rd.
# 3601     4469    TN   Clarksville         2551 Whitfield Road
# 3602     4589    TN   Clarksville              216 Dover Road
# 3603     4591    TN   Clarksville          408 Tiny Town Road
# 3620     4692    TN    East Ridge          4150 Ringgold Road
# 3629     5188    TN        Hixson      7636 Middle Valley Rd.
# 3642     5734    TN     Kingsport         750 Lynn Garden Dr.
# 3645     3959    TN     Knoxville           3120 McKamey Road
# 3659     5107    TN       Madison         109 Gallatin Pike N
# 3666     5043    TN       Memphis           6990 E Shelby Dr.
# 3667     5122    TN       Memphis       2856 Hickory Hill Rd.
# 3674     5467    TN    Morristown          1997 Buffalo Trail
# ...

# %%
old_df = pd.read_csv('walmart_opening_1962_2006.csv')
old_df2 = old_df[old_df["state"]=="AR"]
df3 = old_df2.sort_values("city")
df3.head(60)
# Out:
#         opendate                     st.address                 city state  \
# 330   1981-06-02            200 HIGHWAY 64 WEST                 Alma    AR
# 267   1980-04-15             109 W.P. MALONE DR          Arkadelphia    AR
# 127   1976-05-01            1040 S CONSTITUTION              Ashdown    AR
# 145   1977-01-01                219 HIGHWAY 412              Ashflat    AR
# 120   1976-03-01           3150 HARRISON STREET           Batesville    AR
# 77    1974-04-01                     17309 I-30               Benton    AR
# 0     1962-03-01  5801 SW Regional Airport Blvd          Bentonville    AR
# 94    1974-10-01          406 SOUTH WALTON BLVD          Bentonville    AR
# 69    1973-11-01              1000 WEST TRIMBLE           Berryville    AR
# 52    1972-11-01               3700 EAST HWY 18          Blytheville    AR
# 48    1972-10-01                 1555 EAST MAIN           Booneville    AR
# ...

# %%
import pandas as pd
import datetime

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])

f = """Altamonte Springs
Apopka
Arcadia
Auburndale
Avon Park
Bartow
Boca Raton
Boynton Beach
Braden River
Bradenton
Brandon
Brooksville
Bushnell
Callaway
Cape Coral
Casselberry
Chiefland
Chipley
Clearwater
Clermont
Clewiston
Cocoa
Coconut Creek
Cooper City
Coral Springs
Crawfordville
Crestview
Dade City
Dania Beach
Davie
Daytona Beach
De Funiak Springs
Debary
Deerfield Beach
Deland
Delray Beach
Deltona
Destin
Doral
Dunedin
Dunnellon
Englewood
Estero
Fernandina Beach
Florida City
Fort Lauderdale
Fort Myers
Fort Myers Beach
Fort Pierce
Fort Walton Beach
Fruit Cove
Gainesville
Gibsonton
Greenacres
Gulf Breeze
Haines City
Hallandale Beach
Hialeah
Hialeah Gardens
Holly Hill
Hollywood
Homestead
Homosassa
Hudson
Inverness
Jacksonville
Jupiter
Kendall
Kissimmee
Labelle
Lake City
Lake Mary
Lake Park
Lake Wales
Lake Worth
Lakeland
Largo
Lauderdale Lakes
Lecanto
Leesburg
Lehigh Acres
Live Oak
Lutz
Lynn Haven
Macclenny
Margate
Marianna
Melbourne
Merritt Island
Miami
Miami Gardens
Middleburg
Milton
Miramar
Mount Dora
Mulberry
Naples
Navarre
New Port Richey
New Smyrna Beach
Niceville
North Fort Myers
North Lauderdale
North Miami Beach
North Port
Ocala
Ocoee
Okeechobee
Oldsmar
Orange City
Orange Park
Orlando
Ormond Beach
Osprey
Oviedo
Palatka
Palm Bay
Palm Coast
Palm Harbor
Palm Springs
Palm Springs Village
Palmetto
Panama City
Panama City Beach
Pasadena
Pembroke Pines
Pensacola
Perry
Pinellas Park
Plant City
Plantation
Pompano Beach
Port Charlotte
Port Orange
Port Richey
Port St Lucie
Port St. Lucie
Punta Gorda
Quincy
Riverview
Saint Cloud
Sanford
Santa Rosa Beach
Sarasota
Sebastian
Sebring
Seffner
Spring Hill
St Augustine
St Petersburg
St. Johns
Starke
Stuart
Summerfield
Sunrise
Tallahassee
Tamarac
Tampa
Tarpon Springs
The Villages
Titusville
Valrico
Venice
Vero Beach
Wauchula
Wesley Chapel
West Melbourne
West Palm Beach
Wimauma
Winter Garden
Winter Haven
Winter Springs
Yulee
Zephyrhills"""
for city in f.split('\n'):
    if city not in df[df.State == "FL"].Town.unique():
        print(city)
# Out:
# Debary
# Holly Hill
# Labelle
# Macclenny
# Port St Lucie
# St Augustine
# St Petersburg
# St. Johns

# %%
import numpy as np

df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df[(df.Closing_date>='2022-01-01')|(np.vectorize(str)(df.Closing_date)=="NaT")]
df3 = df2[df2["State"]=="FL"].groupby("Town")["Store_id"].count()
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df3)
# Out:
# Town
# Altamonte Springs        1
# Apopka                   2
# Arcadia                  1
# Auburndale               1
# Avon Park                1
# Bartow                   1
# Boca Raton               1
# Boynton Beach            4
# Braden River             1
# Bradenton                4
# Brandon                  3
# Brooksville              2
# Bushnell                 1
# Callaway                 1
# Cape Coral               4
# Casselberry              1
# Chiefland                1
# Chipley                  1
# Clearwater               3
# Clermont                 2
# Clewiston                1
# Cocoa                    1
# Coconut Creek            1
# Cooper City              1
# Coral Springs            4
# Crawfordville            1
# Crestview                1
# Dade City                1
# Dania Beach              1
# Davie                    1
# Daytona Beach            1
# De Funiak Springs        1
# DeBary                   1
# Deerfield Beach          1
# ...

# %%
df = pd.read_csv('fandom_traitées.csv', parse_dates = ["Opening_date", "Closing_date"])
df2 = df[(df.Opening_date<='2016-01-31')&(df.Closing_date>='2016-01-31')]
df3 = df2[(df2["State"]=="FL")]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df3)
# Out:
#      Store_id State      Town               Street             Category  \
# 4677     2305    CT   Bristol       325 Oakland St  Neighborhood Market
# 4679     3544    CT  Guilford  900 Boston Post Rd.              Walmart
#
#      Opening_date Closing_date
# 4677   2013-01-01   2017-01-01
# 4679   2002-10-16   2022-05-20
