# %% [markdown]
# ### Pre treatment interaction dummy

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

#density_path = r"C:\Users\inesn\Documents\Mines\2A\TR\econometrics\data_collection\plein_de_data\Average_Household_Size_and_Population_Density_-_County.csv"
#density = pd.read_csv(density_path)
#density = density[["GEOID", "B01001_calc_PopDensity"]]
#nielsen = pd.merge(nielsen, density,  how='inner', left_on='guessed_store_county_fips', right_on='GEOID')
#nielsen = nielsen.rename(columns={"B01001_calc_PopDensity": "Population density (people/km^2)"})

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
#movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
# Correction des effets de bord M12
movements = fandom[((fandom.Opening_date >= '2014-01-31') & (fandom.Opening_date <= '2018-01-31')) | ((fandom.Closing_date >= '2014-01-31') & (fandom.Closing_date <= '2018-01-31'))]

# %%
categories = [
    "BUTTER AND MARGARINE",
    "CANDY",
    "CONDIMENTS, GRAVIES, AND SAUCES",
    "COOKIES",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "CRACKERS",
    "DRESSINGS/SALADS/PREP FOODS-DELI",
    "MILK",
    "PAPER PRODUCTS",
    "PET FOOD",
    "PREPARED FOOD-DRY MIXES",
    "PREPARED FOOD-READY-TO-SERVE", 
    "PREPARED FOODS-FROZEN",
    "SNACKS",
    "SOFT DRINKS-NON CARBONATED",
    "SPICES, SEASONINGS, EXTRACTS",
    "UNPREP MEAT/POULTRY/SEAFOOD-FRZN",
    "VEGETABLES - CANNED", 
    "VEGETABLES-FROZEN",
    "WRAPPING MATERIALS AND BAGS",
]

# %%
# We choose to focus on milk prices
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]
    #product_group = pool
    #product_group = nielsen

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
    control['effects'] = list(zip(control.store_state, control.purchase_0))
    control['p_interaction'] = False

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
    treatment['p_interaction'] = treatment.purchase_0 < (treatment.opening_0 - 9)
    
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]
    
    if treatment.shape[0]>0 :
        # Final dataset for the regression :

        df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', "p_interaction"]]
        df = df[df.upc_price != 0]

        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + p_interaction + C(effects)', data=df)
        results1 = reg1.fit()
        print("=========================================================")
        print(category)
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Post-treat interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"p_value : {results1.pvalues[2]}")
        print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
        print(f"nobs : {results1.nobs}")
        print(f"R squared : {results1.rsquared}")
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Pre-treat interaction coef : {np.exp(results1.params[3])-1}")
            print(f"Coef/err : {np.abs(results1.params[3] / results1.bse[3])}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][3])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][3])-1}")
        #print(np.abs(results1.params[3] / results1.bse[3]))
        print(f"p_value : {results1.pvalues[3]}")
# Out:
# Size of the control group: 1695.
# Size of the control group: 558.
# Size of the control group: 289.
# Size of the treatment group: 65.
# =========================================================
# BUTTER AND MARGARINE
# Post-treat interaction Coef : 0.015413968427743452
# CI_up : -0.020395859134865635
# CI_down : 0.052532838793021064
# p_value : 0.4036429474803249
# Coef/err : 0.8351855369604139
# nobs : 7760.0
# R squared : 0.38214641727511556
# Pre-treat interaction coef : -0.00022171749128363505
# Coef/err : 0.012078855574744089
# CI_up : -0.03556128668730807
# CI_down : 0.03641278639962753
# p_value : 0.9903630605822685
# Size of the control group: 1751.
# Size of the control group: 701.
# Size of the control group: 460.
# Size of the treatment group: 65.
# =========================================================
# CANDY
# Post-treat interaction Coef : 0.04367860553265657
# CI_up : -0.0011882156492495355
# CI_down : 0.09056085311872497
# p_value : 0.056528202285628146
# Coef/err : 1.9071450334403608
# nobs : 11893.0
# R squared : 0.25728177199102686
# Pre-treat interaction coef : -0.02684472360809842
# Coef/err : 1.191426080731571
# CI_up : -0.06945170111656263
# CI_down : 0.017713097864709093
# p_value : 0.23351243244099765
# Size of the control group: 1751.
# Size of the control group: 751.
# Size of the control group: 485.
# Size of the treatment group: 65.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Post-treat interaction Coef : 0.0460597000885965
# CI_up : 0.011179718716822995
# CI_down : 0.08214284354716384
# p_value : 0.009259089046904983
# Coef/err : 2.602777796132969
# nobs : 12514.0
# R squared : 0.2400451649568427
# Pre-treat interaction coef : 0.011750523835796445
# Coef/err : 0.6657919694176014
# CI_up : -0.02245528504361849
# CI_down : 0.04715324713067859
# p_value : 0.5055574720502984
# Size of the control group: 1692.
# Size of the control group: 532.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# COOKIES
# Post-treat interaction Coef : 0.10434492961933284
# CI_up : 0.06827587929364687
# CI_down : 0.1416318080516097
# p_value : 4.849972232674417e-09
# Coef/err : 5.8592110881794035
# nobs : 8405.0
# R squared : 0.2655013445752842
# Pre-treat interaction coef : 0.05436776467124105
# Coef/err : 3.0848246736875007
# CI_up : 0.019486629895324903
# CI_down : 0.09044233693576897
# p_value : 0.0020442289854332852
# Size of the control group: 1692.
# Size of the control group: 579.
# Size of the control group: 320.
# Size of the treatment group: 65.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Post-treat interaction Coef : -0.010695610887530127
# CI_up : -0.04165909515148525
# CI_down : 0.021268287063155533
# p_value : 0.5074130362259219
# Coef/err : 0.6629029147605436
# nobs : 8513.0
# R squared : 0.3358468713314098
# Pre-treat interaction coef : 0.07553311632902937
# Coef/err : 4.528775055194159
# CI_up : 0.04216249080457746
# CI_down : 0.10997228793695579
# p_value : 6.024038697109316e-06
# Size of the control group: 1687.
# Size of the control group: 542.
# Size of the control group: 302.
# Size of the treatment group: 65.
# =========================================================
# CRACKERS
# Post-treat interaction Coef : 0.05209006444448572
# CI_up : 0.017092533814708988
# CI_down : 0.08829183865039836
# p_value : 0.003267879810132792
# Coef/err : 2.9423471474942486
# nobs : 8064.0
# R squared : 0.27600377780475394
# Pre-treat interaction coef : 0.055584801573910436
# Coef/err : 3.1351630855050296
# CI_up : 0.02047828888565384
# CI_down : 0.09189904915134028
# p_value : 0.0017245938159987431
# Size of the control group: 1721.
# Size of the control group: 751.
# Size of the control group: 492.
# Size of the treatment group: 65.
# =========================================================
# DRESSINGS/SALADS/PREP FOODS-DELI
# Post-treat interaction Coef : 0.05878753870400533
# CI_up : 0.017134959201802857
# CI_down : 0.10214582831231667
# p_value : 0.005280233344819703
# Coef/err : 2.789947421817929
# nobs : 12688.0
# R squared : 0.20104644008631467
# Pre-treat interaction coef : 0.005180958971184868
# Coef/err : 0.24870650106440081
# CI_up : -0.03493562484692658
# CI_down : 0.04696514169634347
# p_value : 0.8035922074654187
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.
# =========================================================
# MILK
# Post-treat interaction Coef : -0.051441186344157286
# CI_up : -0.07505559507050807
# CI_down : -0.027223887004572678
# p_value : 4.0435408176104293e-05
# Coef/err : 4.106145609885652
# nobs : 16736.0
# R squared : 0.4127277123961234
# Pre-treat interaction coef : 0.012848226083984615
# Coef/err : 0.969217993716824
# CI_up : -0.012967135974093935
# CI_down : 0.0393387763171269
# p_value : 0.3324513770617854
# Size of the control group: 1699.
# Size of the control group: 648.
# Size of the control group: 393.
# Size of the treatment group: 65.
# =========================================================
# PAPER PRODUCTS
# Post-treat interaction Coef : 0.056089601752724816
# CI_up : 0.004290083706421477
# CI_down : 0.11056084793152854
# p_value : 0.033440155621225806
# Coef/err : 2.12707668325191
# nobs : 10273.0
# R squared : 0.1845529454919923
# Pre-treat interaction coef : -0.09092448975505796
# Coef/err : 3.6629412593684543
# CI_up : -0.1361372480577212
# CI_down : -0.04334539084014
# p_value : 0.0002507311251595513
# Size of the control group: 1525.
# Size of the control group: 475.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# PET FOOD
# Post-treat interaction Coef : -0.0346996572869227
# CI_up : -0.1287836107900724
# CI_down : 0.06954456227229855
# p_value : 0.49964156385918035
# Coef/err : 0.6750872174967567
# nobs : 8376.0
# R squared : 0.17359723856352582
# Pre-treat interaction coef : -0.11715715175674246
# Coef/err : 2.3228251875549115
# CI_up : -0.20528182762569513
# CI_down : -0.019260510470406333
# p_value : 0.020215673734814043
# Size of the control group: 1704.
# Size of the control group: 594.
# Size of the control group: 338.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOOD-DRY MIXES
# Post-treat interaction Coef : 0.06609050636480762
# CI_up : 0.02613294825800594
# CI_down : 0.10760400949078952
# p_value : 0.0010277391978113285
# Coef/err : 3.2840423557662404
# nobs : 8949.0
# R squared : 0.2088909985241858
# Pre-treat interaction coef : 0.046068474361013356
# Coef/err : 2.325621294832272
# CI_up : 0.007100739206884921
# CI_down : 0.08654398755950932
# p_value : 0.020063899458284285
# Size of the control group: 1692.
# Size of the control group: 502.
# Size of the control group: 269.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOOD-READY-TO-SERVE
# Post-treat interaction Coef : -0.04531817968957874
# CI_up : -0.09367855305883654
# CI_down : 0.005622653096486685
# p_value : 0.08035666711218248
# Coef/err : 1.7489020853637016
# nobs : 7280.0
# R squared : 0.27154227495723493
# Pre-treat interaction coef : 0.023562207551681924
# Coef/err : 0.8866349374241501
# CI_up : -0.027808642617860313
# CI_down : 0.07764750712164648
# p_value : 0.37530933724144844
# Size of the control group: 1690.
# Size of the control group: 613.
# Size of the control group: 388.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOODS-FROZEN
# Post-treat interaction Coef : -0.027698864868199724
# CI_up : -0.06855286215889245
# CI_down : 0.014947020578911951
# p_value : 0.1996233222551596
# Coef/err : 1.2827185916610324
# nobs : 10139.0
# R squared : 0.1759677208741116
# Pre-treat interaction coef : 0.008439327362353977
# Coef/err : 0.38199863577463217
# CI_up : -0.034124893169303894
# CI_down : 0.052879269565121456
# p_value : 0.702471287675465
# Size of the control group: 1768.
# Size of the control group: 907.
# Size of the control group: 661.
# Size of the treatment group: 65.
# =========================================================
# SNACKS
# Post-treat interaction Coef : 0.042646221629409675
# CI_up : 0.01112731681508694
# CI_down : 0.07514763511912226
# p_value : 0.007667115665227148
# Coef/err : 2.6667323499549935
# nobs : 16747.0
# R squared : 0.22129260982885546
# Pre-treat interaction coef : -0.0007893871273925157
# Coef/err : 0.04929957271347017
# CI_up : -0.03167504457338843
# CI_down : 0.031081398121543202
# p_value : 0.96068118718478
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 1725.
# Size of the control group: 908.
# Size of the control group: 634.
# Size of the treatment group: 64.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Post-treat interaction Coef : -0.037608976588367704
# CI_up : -0.0710020286906834
# CI_down : -0.003015603319433735
# p_value : 0.0333735454695442
# Coef/err : 2.1277558208448677
# nobs : 16094.0
# R squared : 0.21798083272421598
# Pre-treat interaction coef : -0.004243924859594905
# Coef/err : 0.22999558058426947
# CI_up : -0.039689378208899506
# CI_down : 0.032509834505105584
# p_value : 0.8180983304713098
# Size of the control group: 1727.
# Size of the control group: 627.
# Size of the control group: 372.
# Size of the treatment group: 65.
# =========================================================
# VEGETABLES - CANNED
# Post-treat interaction Coef : 0.05368605196335596
# CI_up : 0.01708319988476026
# CI_down : 0.09160616970953872
# p_value : 0.0037482283459122074
# Coef/err : 2.8993854493305276
# nobs : 9782.0
# R squared : 0.22758869135604332
# Pre-treat interaction coef : 0.040094960539813984
# Coef/err : 2.1485116401038487
# CI_up : 0.0034509079446995994
# CI_down : 0.07807718182854595
# p_value : 0.03170043333916574
# Size of the control group: 1709.
# Size of the control group: 597.
# Size of the control group: 357.
# Size of the treatment group: 65.
# =========================================================
# VEGETABLES-FROZEN
# Post-treat interaction Coef : -0.03408170739705085
# CI_up : -0.06630338914218104
# CI_down : -0.0007480619129385246
# p_value : 0.045157478605258754
# Coef/err : 2.0034844550902244
# nobs : 9414.0
# R squared : 0.21777870497444163
# Pre-treat interaction coef : 0.011578513368913468
# Coef/err : 0.6716240030948378
# CI_up : -0.02184554770245062
# CI_down : 0.04614469249318631
# p_value : 0.5018416226434423
# Size of the control group: 1603.
# Size of the control group: 339.
# Size of the control group: 177.
# Size of the treatment group: 65.
# =========================================================
# WRAPPING MATERIALS AND BAGS
# Post-treat interaction Coef : 0.01637430256273209
# CI_up : -0.04225511388685488
# CI_down : 0.07859278382807533
# p_value : 0.5920353833637451
# Coef/err : 0.5359314349915487
# nobs : 4967.0
# R squared : 0.3625801461040896
# Pre-treat interaction coef : -0.056676568116074466
# Coef/err : 1.9462173403234444
# CI_up : -0.11052318221942037
# CI_down : 0.0004297800156740639
# p_value : 0.051697741214287295

# %% [markdown]
# #### Same with clustered standard errors

# %%
categories = [
    "COOKIES",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "MILK",
    "PAPER PRODUCTS",
]

# %%
# We choose to focus on milk prices
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]
    #product_group = pool
    #product_group = nielsen

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
    control['effects'] = list(zip(control.store_state, control.purchase_0))
    control['p_interaction'] = False

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
    treatment['p_interaction'] = treatment.purchase_0 < (treatment.opening_0 - 9)
    
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]
    
    if treatment.shape[0]>0 :
        # Final dataset for the regression :

        df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', "p_interaction", 'store_state']]
        df = df[df.upc_price != 0]

        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + p_interaction + C(effects)', data=df)
        results1 = reg1.fit(cov_type="cluster", cov_kwds={"groups": df['store_state']})
        print("=========================================================")
        print(category)
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Post-treat interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"p_value : {results1.pvalues[2]}")
        print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
        print(f"nobs : {results1.nobs}")
        print(f"R squared : {results1.rsquared}")
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Pre-treat interaction coef : {np.exp(results1.params[3])-1}")
            print(f"Coef/err : {np.abs(results1.params[3] / results1.bse[3])}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][3])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][3])-1}")
        #print(np.abs(results1.params[3] / results1.bse[3]))
        print(f"p_value : {results1.pvalues[3]}")
# Out:
# Size of the control group: 1692.
# Size of the control group: 532.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# COOKIES
# Post-treat interaction Coef : 0.10434492961933284
# CI_up : 0.042974538373204085
# CI_down : 0.16932645880136699
# p_value : 0.000668103142947125
# Coef/err : 3.4023446985836316
# nobs : 8405.0
# R squared : 0.2655013445752842
# Pre-treat interaction coef : 0.05436776467124105
# Coef/err : 1.697212776146985
# CI_up : -0.008162526462913378
# CI_down : 0.12084027155509713
# p_value : 0.08965644053669992
# Size of the control group: 1692.
# Size of the control group: 579.
# Size of the control group: 320.
# Size of the treatment group: 65.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Post-treat interaction Coef : -0.010695610887530127
# CI_up : -0.055651925713599226
# CI_down : 0.03640087904745504
# p_value : 0.6504226320813277
# Coef/err : 0.45317513999344156
# nobs : 8513.0
# R squared : 0.3358468713314098
# Pre-treat interaction coef : 0.07553311632902937
# Coef/err : 2.480198695240422
# CI_up : 0.015390873425869867
# CI_down : 0.1392376222740248
# p_value : 0.013130918826393247
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.
# =========================================================
# MILK
# Post-treat interaction Coef : -0.051441186344157286
# CI_up : -0.08380081655328864
# CI_down : -0.017938632536979915
# p_value : 0.0028628106153653615
# Coef/err : 2.9820972319137065
# nobs : 16736.0
# R squared : 0.4127277123961234
# Pre-treat interaction coef : 0.012848226083984615
# Coef/err : 0.7010155444585329
# CI_up : -0.022666230205849125
# CI_down : 0.04965321038435477
# p_value : 0.4832933144242373
# Size of the control group: 1699.
# Size of the control group: 648.
# Size of the control group: 393.
# Size of the treatment group: 65.
# =========================================================
# PAPER PRODUCTS
# Post-treat interaction Coef : 0.056089601752724816
# CI_up : -0.026364549474167887
# CI_down : 0.1455265380157167
# p_value : 0.18824940601980455
# Coef/err : 1.3157754961795858
# nobs : 10273.0
# R squared : 0.1845529454919923
# Pre-treat interaction coef : -0.09092448975505796
# Coef/err : 2.6914612705594605
# CI_up : -0.15189074248439116
# CI_down : -0.025575683788721992
# p_value : 0.007113975779018812

# %% [markdown]
# ### Pooled results

# %%
pool = nielsen.groupby(['store_state','guessed_store_county','guessed_store_county_fips','purchase_month','purchase_year']).mean().reset_index()
product_group = pool
#product_group = nielsen

# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# We keep in the control group the only counties where we have data for the entire time period (24 months)
nb_months = control.groupby('guessed_store_county_fips').count()
control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

#nb_obs = control.groupby('guessed_store_county_fips').min()
#control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
#print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")

# We create our dummies for the regression
control['treat'] = False
control['interaction'] = False
control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
control['effects'] = list(zip(control.store_state, control.purchase_0))
control['p_interaction'] = False

treatment['treat'] = True
treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
treatment['p_interaction'] = treatment.purchase_0 < treatment.opening_0

treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]

if treatment.shape[0]>0 :
    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', "p_interaction"]]
    df = df[df.upc_price != 0]

    reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + p_interaction + C(effects)', data=df)
    results1 = reg1.fit()
    print("=========================================================")
    if abs(results1.params[2] / results1.bse[2]) >= 2.:
        print(f"Post-t interaction Coef : {np.exp(results1.params[2])-1}")
    print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
    if abs(results1.params[2] / results1.bse[2]) >= 2.:
        print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"Pre-t interaction Coef : {np.exp(results1.params[3])-1}")
        print(f"Coef/err : {abs(results1.params[3] / results1.bse[3])}")
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_41112\1472247794.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pool = nielsen.groupby(['store_state','guessed_store_county','guessed_store_county_fips','purchase_month','purchase_year']).mean().reset_index()
# Size of the control group: 1802.
# Size of the control group: 1390.
# Size of the treatment group: 65.
# =========================================================
# Post-t interaction Coef : 0.0706284805014521
# Coef/err : 7.499050932256935
# CI_up : 0.05170046901642289
# CI_down : 0.08989714945439364
# Pre-t interaction Coef : 0.017884479832837474
# Coef/err : 2.0847475037421326

# %%
#control['p_interaction'] = False
#treatment['p_interaction'] = treatment.purchase_0 < treatment.opening_0
#df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'store_state', 'time_effects', 'p_interaction']]

# %% [markdown]
# ### Placebo 1 - placebo treatment group

# %% [markdown]
# We aim at designing a false treatment group. Each element of the actual treatment group will be replaced by a randomly selected element from the control group that is located in the same state. We will run our previously used model on this new "control group" and compare the statistical significance of the interaction coefficient with the one obtained using our original treatment group.

# %%
#TO_ADD
from random import choice
#END_TO_ADD

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime


nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
#movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
# Correction des effets de bord M12
movements = fandom[((fandom.Opening_date >= '2014-01-31') & (fandom.Opening_date <= '2018-01-31')) | ((fandom.Closing_date >= '2014-01-31') & (fandom.Closing_date <= '2018-01-31'))]

# %%
# We choose to focus on milk prices
category = 'MILK'
product_group = nielsen[nielsen.product_group_descr == category]

# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# We keep in the control group the only counties where we have data for the entire time period (24 months)
nb_months = control.groupby('guessed_store_county_fips').count()
control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

nb_obs = control.groupby('guessed_store_county_fips').min()
control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")
# Out:
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.

# %%
treatment.dtypes
# Out:
# is_walmart                             bool
# store_state                          object
# guessed_store_county                 object
# guessed_store_county_fips             int64
# purchase_year                         int64
# purchase_month                        int64
# product_group_descr                  object
# upc_price                           float64
# upc_price_std                       float64
# nb_of_obs                             int64
# year                                  int64
# State                                object
# County_name                          object
# County_fips                           int64
# Opening_date                 datetime64[ns]
# Closing_date                 datetime64[ns]
# dtype: object

# %%
#TO_ADD

#We create an 'Opening_date' column for the control group (because we have to add an Opening_date to the
#placebo treatment group counties)

control['Opening_date']=0

#We gather relevant information on the actual treatment group in an array

treatment_info = treatment.groupby(['guessed_store_county_fips','store_state','Opening_date']).nunique()['is_walmart'].reset_index().to_numpy()


#We select our placebo treatment group counties

new_t_county_fips_list = []
#total nb of counties we want in the placebo treatment group
nb_of_t_counties = treatment_info.shape[0]
#list of indexes in treatment_info of the actual Tg counties for which we could not find a placebo in the same state
index_of_missing_counties = []
for k in range(nb_of_t_counties): 
    #for each actual Tg county, we find a placebo replacement
    #we get the county state
    state = treatment_info[k][1]
    #we get the county opening date
    opening_date = treatment_info[k][2] 
    #list of the candidate county_fips for our placebo (same state as the actual Tg county, not the same county as another already existing placebo county)
    c_county_list = control[(control.store_state == state)&(~np.isin(control.guessed_store_county_fips, new_t_county_fips_list))].guessed_store_county_fips.unique().copy().tolist() 
    nb_of_c_counties = len(c_county_list) #nb of candidates
    if nb_of_c_counties > 0 :
        new_t_county_fips = choice(c_county_list) #random choice of one candidate
        new_t_county_fips_list.append(new_t_county_fips)
        #we add the right opening_date to placebo county
        control.loc[control.guessed_store_county_fips==new_t_county_fips, 'Opening_date'] = opening_date 
    else : 
        #if we did not find suitable candidates in the right state
        index_of_missing_counties.append(k)
        
nb_of_missing_counties = len(index_of_missing_counties)
if nb_of_missing_counties != 0 : 
    #if we did not find suitable candidates in the right state for at least one state, we search candidates whatever the state
    for k in index_of_missing_counties:
        remaining_c_county_list = control[~np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].guessed_store_county_fips.unique().copy().tolist()
        new_t_county_fips = choice(remaining_c_county_list)
        new_t_county_fips_list.append(new_t_county_fips)
        control.loc[control.guessed_store_county_fips==new_t_county_fips, 'Opening_date'] = opening_date

#we keep in our placebo Tg only the selected placebo counties
new_treatment = control[np.isin(control.guessed_store_county_fips, new_t_county_fips_list)] 
#END_TO_ADD

#DON'T FORGET TO CHANGE names : treatment -> new_treatment bellow

# %%
treatment_info[0][2].month
# Out:
# 11

# %%
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_1744\2299134106.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   control[control.guessed_store_county_fips==new_t_county_fips]['Opening_date'] = opening_date

# %%
pd.set_option('display.max_rows', 5000)
treatment.head()
# Out:
#    is_walmart store_state guessed_store_county  guessed_store_county_fips  \
# 0       False          AL              CULLMAN                       1043
# 1       False          AL              CULLMAN                       1043
# 2       False          AL              CULLMAN                       1043
# 3       False          AL              CULLMAN                       1043
# 4       False          AL              CULLMAN                       1043
#
#    purchase_year  purchase_month product_group_descr  upc_price  \
# 0           2015               1                MILK   3.225000
# 1           2015               2                MILK   3.120000
# 2           2015               3                MILK   3.264545
# 3           2015               4                MILK   3.090263
# 4           2015               5                MILK   3.084815
#
#    upc_price_std  nb_of_obs  year State County_name  County_fips Opening_date  \
# 0       0.609818         24  2015    AL     Cullman         1043   2015-11-11
# 1       0.932845         27  2015    AL     Cullman         1043   2015-11-11
# 2       1.061871         33  2015    AL     Cullman         1043   2015-11-11
# 3       0.948046         38  2015    AL     Cullman         1043   2015-11-11
# 4       0.715178         27  2015    AL     Cullman         1043   2015-11-11
#
#   Closing_date
# 0          NaT
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT

# %%
pd.set_option('display.max_rows', 5000)
new_treatment.head()
# Out:
#      is_walmart store_state guessed_store_county  guessed_store_county_fips  \
# 26        False          AL              AUTAUGA                       1001
# 68        False          AL              AUTAUGA                       1001
# 100       False          AL              AUTAUGA                       1001
# 146       False          AL              AUTAUGA                       1001
# 186       False          AL              AUTAUGA                       1001
#
#      purchase_year  purchase_month product_group_descr  upc_price  \
# 26            2015               1                MILK   3.572727
# 68            2015               2                MILK   3.490000
# 100           2015               3                MILK   3.911667
# 146           2015               4                MILK   3.586000
# 186           2015               5                MILK   3.606250
#
#      upc_price_std  nb_of_obs  year         Opening_date
# 26        0.338942         11  2015  2015-09-30 00:00:00
# 68        0.339074          8  2015  2015-09-30 00:00:00
# 100       0.090646          6  2015  2015-09-30 00:00:00
# 146       0.795695          5  2015  2015-09-30 00:00:00
# 186       0.414899          8  2015  2015-09-30 00:00:00

# %% [markdown]
# #### Test

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime
from random import choice


nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
#movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
# Correction des effets de bord M12
movements = fandom[((fandom.Opening_date >= '2014-01-31') & (fandom.Opening_date <= '2018-01-31')) | ((fandom.Closing_date >= '2014-01-31') & (fandom.Closing_date <= '2018-01-31'))]

# %%
categories = [
    "BUTTER AND MARGARINE",
    "CANDY",
    "CONDIMENTS, GRAVIES, AND SAUCES",
    "COOKIES",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "CRACKERS",
    "DRESSINGS/SALADS/PREP FOODS-DELI",
    "MILK",
    "PAPER PRODUCTS",
    "PET FOOD",
    "PREPARED FOOD-DRY MIXES",
    "PREPARED FOOD-READY-TO-SERVE", 
    "PREPARED FOODS-FROZEN",
    "SNACKS",
    "SOFT DRINKS-NON CARBONATED",
    "SPICES, SEASONINGS, EXTRACTS",
    "UNPREP MEAT/POULTRY/SEAFOOD-FRZN",
    "VEGETABLES - CANNED", 
    "VEGETABLES-FROZEN",
    "WRAPPING MATERIALS AND BAGS",
]

# %%
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")
    
    if treatment.shape[0] > 0 : 
    
        ### Creation of the placebo treatment group

            #We create an 'Opening_date' column for the control group (because we have to add an Opening_date to the
        #placebo treatment group counties)

        control['Opening_date']=0

        #We gather relevant information on the actual treatment group in an array

        treatment_info = treatment.groupby(['guessed_store_county_fips','store_state','Opening_date']).nunique()['is_walmart'].reset_index().to_numpy()


        #We select our placebo treatment group counties

        new_t_county_fips_list = []
        error = False
        #total nb of counties we want in the placebo treatment group
        nb_of_t_counties = treatment_info.shape[0]
        #list of indexes in treatment_info of the actual Tg counties for which we could not find a placebo in the same state
        index_of_missing_counties = []
        for k in range(nb_of_t_counties): 
            #for each actual Tg county, we find a placebo replacement
            #we get the county state
            state = treatment_info[k][1]
            #we get the county opening date
            opening_date = treatment_info[k][2]
            #list of the candidate county_fips for our placebo (same state as the actual Tg county, not the same county as another already existing placebo county)
            c_county_list = control[(control.store_state == state)&(~np.isin(control.guessed_store_county_fips, new_t_county_fips_list))].guessed_store_county_fips.unique().copy().tolist() 
            nb_of_c_counties = len(c_county_list) #nb of candidates
            if nb_of_c_counties > 0 :
                new_t_county_fips = choice(c_county_list) #random choice of one candidate
                new_t_county_fips_list.append(new_t_county_fips)
                #we add the right opening_date to placebo county
                control.loc[control.guessed_store_county_fips==new_t_county_fips, 'Opening_date'] = opening_date 
            else : 
                #if we did not find suitable candidates in the right state
                index_of_missing_counties.append(k)

        nb_of_missing_counties = len(index_of_missing_counties)
        if nb_of_missing_counties != 0 : 
            #if we did not find suitable candidates in the right state for at least one state, we search candidates whatever the state
            for k in index_of_missing_counties:
                remaining_c_county_list = control[~np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].guessed_store_county_fips.unique().copy().tolist()
                print(f'remaining_c_county_list len : {len(remaining_c_county_list)}')
                if len(remaining_c_county_list) <= 0 :
                    error = True
                else :
                    new_t_county_fips = choice(remaining_c_county_list)
                    new_t_county_fips_list.append(new_t_county_fips)
                    control.loc[control.guessed_store_county_fips==new_t_county_fips, 'Opening_date'] = opening_date
        if not error :

            #we keep in our placebo Tg only the selected placebo counties
            new_treatment = control[np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].copy()
            new_control = control[~np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].copy()

            ### End of the creation of the placebo treatment group

            # We create our dummies for the regression
            new_control['treat'] = False
            new_control['interaction'] = False
            new_control['purchase_0'] = new_control.purchase_month + 12 * (new_control.purchase_year - 2015)
            new_control['effects'] = list(zip(new_control.store_state, new_control.purchase_0))

            new_treatment['treat'] = True
            new_treatment['purchase_0'] = new_treatment.purchase_month + 12 * (new_treatment.purchase_year - 2015)
            new_treatment['opening_0'] = pd.DatetimeIndex(new_treatment.Opening_date).month  + 12 * (pd.DatetimeIndex(new_treatment.Opening_date).year - 2015)
            new_treatment['interaction'] = new_treatment.purchase_0 >= new_treatment.opening_0
            new_treatment['effects'] = list(zip(new_treatment.store_state, new_treatment.purchase_0))

            new_treatment = new_treatment[abs(new_treatment.purchase_0-new_treatment.opening_0) >= 6]

            if new_treatment.shape[0]>0 :
                # Final dataset for the regression :

                df = pd.concat((new_control, new_treatment))[['upc_price', 'treat', 'interaction', 'effects']]
                df = df[df.upc_price != 0]

                reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
                results1 = reg1.fit()
                print("=========================================================")
                print(category)
                if abs(results1.params[2] / results1.bse[2]) >= 2.:
                    print(f"Coef : {np.exp(results1.params[2])-1}")
                print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
                print(f"p_value : {results1.pvalues[2]}")
                print(f"nobs : {results1.nobs}")
                print(f"R squared : {results1.rsquared}")
                if abs(results1.params[2] / results1.bse[2]) >= 2.:
                    print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
                    print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 1695.
# Size of the control group: 558.
# Size of the control group: 289.
# Size of the treatment group: 65.
# remaining_c_county_list len : 247
# remaining_c_county_list len : 246
# remaining_c_county_list len : 245
# remaining_c_county_list len : 244
# remaining_c_county_list len : 243
# remaining_c_county_list len : 242
# remaining_c_county_list len : 241
# remaining_c_county_list len : 240
# remaining_c_county_list len : 239
# remaining_c_county_list len : 238
# remaining_c_county_list len : 237
# remaining_c_county_list len : 236
# remaining_c_county_list len : 235
# remaining_c_county_list len : 234
# remaining_c_county_list len : 233
# remaining_c_county_list len : 232
# remaining_c_county_list len : 231
# remaining_c_county_list len : 230
# remaining_c_county_list len : 229
# remaining_c_county_list len : 228
# remaining_c_county_list len : 227
# remaining_c_county_list len : 226
# remaining_c_county_list len : 225
# =========================================================
# BUTTER AND MARGARINE
# Coef : -0.04012970675654903
# Coef/err : 2.94065793772269
# p_value : 0.0032891883024620556
# nobs : 6263.0
# R squared : 0.3796884667534338
# CI_up : -0.06598373205418495
# CI_down : -0.013560029444028121
# Size of the control group: 1751.
# Size of the control group: 701.
# Size of the control group: 460.
# Size of the treatment group: 65.
# remaining_c_county_list len : 401
# remaining_c_county_list len : 400
# remaining_c_county_list len : 399
# remaining_c_county_list len : 398
# remaining_c_county_list len : 397
# remaining_c_county_list len : 396
# =========================================================
# CANDY
# Coef : 0.04236921543885552
# Coef/err : 2.250770174067129
# p_value : 0.024423177224131766
# nobs : 10380.0
# R squared : 0.28261991885943316
# CI_up : 0.005371140402586683
# CI_down : 0.08072883498478811
# Size of the control group: 1751.
# Size of the control group: 751.
# Size of the control group: 485.
# Size of the treatment group: 65.
# remaining_c_county_list len : 429
# remaining_c_county_list len : 428
# remaining_c_county_list len : 427
# remaining_c_county_list len : 426
# remaining_c_county_list len : 425
# remaining_c_county_list len : 424
# remaining_c_county_list len : 423
# remaining_c_county_list len : 422
# remaining_c_county_list len : 421
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef/err : 0.16263013754619296
# p_value : 0.8708129478340704
# nobs : 10979.0
# R squared : 0.25105664719820386
# Size of the control group: 1692.
# Size of the control group: 532.
# Size of the control group: 316.
# Size of the treatment group: 65.
# remaining_c_county_list len : 268
# remaining_c_county_list len : 267
# remaining_c_county_list len : 266
# remaining_c_county_list len : 265
# remaining_c_county_list len : 264
# remaining_c_county_list len : 263
# remaining_c_county_list len : 262
# remaining_c_county_list len : 261
# remaining_c_county_list len : 260
# remaining_c_county_list len : 259
# remaining_c_county_list len : 258
# remaining_c_county_list len : 257
# remaining_c_county_list len : 256
# remaining_c_county_list len : 255
# remaining_c_county_list len : 254
# remaining_c_county_list len : 253
# remaining_c_county_list len : 252
# =========================================================
# COOKIES
# Coef/err : 0.8312547681189818
# p_value : 0.4058627003270455
# nobs : 6912.0
# R squared : 0.2485229941254955
# Size of the control group: 1692.
# Size of the control group: 579.
# Size of the control group: 320.
# Size of the treatment group: 65.
# remaining_c_county_list len : 275
# remaining_c_county_list len : 274
# remaining_c_county_list len : 273
# remaining_c_county_list len : 272
# remaining_c_county_list len : 271
# remaining_c_county_list len : 270
# remaining_c_county_list len : 269
# remaining_c_county_list len : 268
# remaining_c_county_list len : 267
# remaining_c_county_list len : 266
# remaining_c_county_list len : 265
# remaining_c_county_list len : 264
# remaining_c_county_list len : 263
# remaining_c_county_list len : 262
# remaining_c_county_list len : 261
# remaining_c_county_list len : 260
# remaining_c_county_list len : 259
# remaining_c_county_list len : 258
# remaining_c_county_list len : 257
# remaining_c_county_list len : 256
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef/err : 0.11033183561618441
# p_value : 0.9121498061654523
# nobs : 7009.0
# R squared : 0.352458825344078
# Size of the control group: 1687.
# Size of the control group: 542.
# Size of the control group: 302.
# Size of the treatment group: 65.
# remaining_c_county_list len : 256
# remaining_c_county_list len : 255
# remaining_c_county_list len : 254
# remaining_c_county_list len : 253
# remaining_c_county_list len : 252
# remaining_c_county_list len : 251
# remaining_c_county_list len : 250
# remaining_c_county_list len : 249
# remaining_c_county_list len : 248
# remaining_c_county_list len : 247
# remaining_c_county_list len : 246
# remaining_c_county_list len : 245
# remaining_c_county_list len : 244
# remaining_c_county_list len : 243
# remaining_c_county_list len : 242
# remaining_c_county_list len : 241
# remaining_c_county_list len : 240
# remaining_c_county_list len : 239
# remaining_c_county_list len : 238
# =========================================================
# CRACKERS
# Coef/err : 0.14636862148704755
# p_value : 0.8836355297428327
# nobs : 6577.0
# R squared : 0.27280573348505266
# Size of the control group: 1721.
# Size of the control group: 751.
# Size of the control group: 492.
# Size of the treatment group: 65.
# remaining_c_county_list len : 439
# remaining_c_county_list len : 438
# remaining_c_county_list len : 437
# remaining_c_county_list len : 436
# remaining_c_county_list len : 435
# remaining_c_county_list len : 434
# remaining_c_county_list len : 433
# remaining_c_county_list len : 432
# remaining_c_county_list len : 431
# remaining_c_county_list len : 430
# remaining_c_county_list len : 429
# remaining_c_county_list len : 428
# =========================================================
# DRESSINGS/SALADS/PREP FOODS-DELI
# Coef/err : 0.42170482091005296
# p_value : 0.6732494185021947
# nobs : 11143.0
# R squared : 0.2071470656138258
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.
# remaining_c_county_list len : 597
# remaining_c_county_list len : 596
# =========================================================
# MILK
# Coef : -0.021465211064419232
# Coef/err : 2.0460520017814328
# p_value : 0.04076969793538129
# nobs : 15185.0
# R squared : 0.41565830599486564
# CI_up : -0.04159675905644489
# CI_down : -0.0009107938590589004
# Size of the control group: 1699.
# Size of the control group: 648.
# Size of the control group: 393.
# Size of the treatment group: 65.
# remaining_c_county_list len : 341
# remaining_c_county_list len : 340
# remaining_c_county_list len : 339
# remaining_c_county_list len : 338
# remaining_c_county_list len : 337
# remaining_c_county_list len : 336
# remaining_c_county_list len : 335
# remaining_c_county_list len : 334
# remaining_c_county_list len : 333
# remaining_c_county_list len : 332
# remaining_c_county_list len : 331
# remaining_c_county_list len : 330
# remaining_c_county_list len : 329
# =========================================================
# PAPER PRODUCTS
# Coef/err : 1.046989714549943
# p_value : 0.29513670187799496
# nobs : 8762.0
# R squared : 0.1986930253107806
# Size of the control group: 1525.
# Size of the control group: 475.
# Size of the control group: 316.
# Size of the treatment group: 65.
# remaining_c_county_list len : 265
# remaining_c_county_list len : 264
# remaining_c_county_list len : 263
# remaining_c_county_list len : 262
# remaining_c_county_list len : 261
# remaining_c_county_list len : 260
# remaining_c_county_list len : 259
# remaining_c_county_list len : 258
# remaining_c_county_list len : 257
# remaining_c_county_list len : 256
# remaining_c_county_list len : 255
# remaining_c_county_list len : 254
# remaining_c_county_list len : 253
# remaining_c_county_list len : 252
# =========================================================
# PET FOOD
# Coef : 0.2177442426797649
# Coef/err : 4.961943528648918
# p_value : 7.171928396533971e-07
# nobs : 6919.0
# R squared : 0.2007164472886367
# CI_up : 0.12656087768945845
# CI_down : 0.31630795099249176
# Size of the control group: 1704.
# Size of the control group: 594.
# Size of the control group: 338.
# Size of the treatment group: 65.
# remaining_c_county_list len : 292
# remaining_c_county_list len : 291
# remaining_c_county_list len : 290
# remaining_c_county_list len : 289
# remaining_c_county_list len : 288
# remaining_c_county_list len : 287
# remaining_c_county_list len : 286
# remaining_c_county_list len : 285
# remaining_c_county_list len : 284
# remaining_c_county_list len : 283
# remaining_c_county_list len : 282
# remaining_c_county_list len : 281
# remaining_c_county_list len : 280
# remaining_c_county_list len : 279
# remaining_c_county_list len : 278
# remaining_c_county_list len : 277
# remaining_c_county_list len : 276
# remaining_c_county_list len : 275
# remaining_c_county_list len : 274
# =========================================================
# PREPARED FOOD-DRY MIXES
# Coef/err : 1.3674001249452417
# p_value : 0.17154691393331636
# nobs : 7446.0
# R squared : 0.2030392886679373
# Size of the control group: 1692.
# Size of the control group: 502.
# Size of the control group: 269.
# Size of the treatment group: 65.
# remaining_c_county_list len : 223
# remaining_c_county_list len : 222
# remaining_c_county_list len : 221
# remaining_c_county_list len : 220
# remaining_c_county_list len : 219
# remaining_c_county_list len : 218
# remaining_c_county_list len : 217
# remaining_c_county_list len : 216
# remaining_c_county_list len : 215
# remaining_c_county_list len : 214
# remaining_c_county_list len : 213
# remaining_c_county_list len : 212
# remaining_c_county_list len : 211
# remaining_c_county_list len : 210
# remaining_c_county_list len : 209
# remaining_c_county_list len : 208
# remaining_c_county_list len : 207
# remaining_c_county_list len : 206
# remaining_c_county_list len : 205
# =========================================================
# PREPARED FOOD-READY-TO-SERVE
# Coef/err : 0.6221772524778747
# p_value : 0.533854159097995
# nobs : 5784.0
# R squared : 0.28007666385406227
# Size of the control group: 1690.
# Size of the control group: 613.
# Size of the control group: 388.
# Size of the treatment group: 65.
# remaining_c_county_list len : 339
# remaining_c_county_list len : 338
# remaining_c_county_list len : 337
# remaining_c_county_list len : 336
# remaining_c_county_list len : 335
# remaining_c_county_list len : 334
# remaining_c_county_list len : 333
# remaining_c_county_list len : 332
# remaining_c_county_list len : 331
# remaining_c_county_list len : 330
# remaining_c_county_list len : 329
# remaining_c_county_list len : 328
# remaining_c_county_list len : 327
# remaining_c_county_list len : 326
# remaining_c_county_list len : 325
# remaining_c_county_list len : 324
# =========================================================
# PREPARED FOODS-FROZEN
# Coef : -0.03264763512644675
# Coef/err : 2.08344312375397
# p_value : 0.037243668461491
# nobs : 8642.0
# R squared : 0.1908149101502331
# CI_up : -0.06239132107743428
# CI_down : -0.0019603925789400956
# Size of the control group: 1768.
# Size of the control group: 907.
# Size of the control group: 661.
# Size of the treatment group: 65.
# remaining_c_county_list len : 597
# =========================================================
# SNACKS
# Coef/err : 0.15360730914733065
# p_value : 0.8779215600791307
# nobs : 15209.0
# R squared : 0.2282691089176455
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 1725.
# Size of the control group: 908.
# Size of the control group: 634.
# Size of the treatment group: 64.
# remaining_c_county_list len : 573
# remaining_c_county_list len : 572
# remaining_c_county_list len : 571
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef/err : 1.6973930840824956
# p_value : 0.08964533838683082
# nobs : 14572.0
# R squared : 0.22443252615641252
# Size of the control group: 1727.
# Size of the control group: 627.
# Size of the control group: 372.
# Size of the treatment group: 65.
# remaining_c_county_list len : 317
# remaining_c_county_list len : 316
# remaining_c_county_list len : 315
# remaining_c_county_list len : 314
# remaining_c_county_list len : 313
# remaining_c_county_list len : 312
# remaining_c_county_list len : 311
# remaining_c_county_list len : 310
# remaining_c_county_list len : 309
# remaining_c_county_list len : 308
# =========================================================
# VEGETABLES - CANNED
# Coef : -0.05742266126614737
# Coef/err : 4.10273217356544
# p_value : 4.127341674593397e-05
# nobs : 8263.0
# R squared : 0.247905272329891
# CI_up : -0.08368323056525595
# CI_down : -0.030409494696186035
# Size of the control group: 1709.
# Size of the control group: 597.
# Size of the control group: 357.
# Size of the treatment group: 65.
# remaining_c_county_list len : 308
# remaining_c_county_list len : 307
# remaining_c_county_list len : 306
# remaining_c_county_list len : 305
# remaining_c_county_list len : 304
# remaining_c_county_list len : 303
# remaining_c_county_list len : 302
# remaining_c_county_list len : 301
# remaining_c_county_list len : 300
# remaining_c_county_list len : 299
# remaining_c_county_list len : 298
# remaining_c_county_list len : 297
# remaining_c_county_list len : 296
# remaining_c_county_list len : 295
# remaining_c_county_list len : 294
# remaining_c_county_list len : 293
# =========================================================
# VEGETABLES-FROZEN
# Coef : -0.05576389959791783
# Coef/err : 4.5652199416620896
# p_value : 5.0754005023472615e-06
# nobs : 7898.0
# R squared : 0.22895999692693003
# CI_up : -0.07874424309934624
# CI_down : -0.0322103209405753
# Size of the control group: 1603.
# Size of the control group: 339.
# Size of the control group: 177.
# Size of the treatment group: 65.
# remaining_c_county_list len : 148
# remaining_c_county_list len : 147
# remaining_c_county_list len : 146
# remaining_c_county_list len : 145
# remaining_c_county_list len : 144
# remaining_c_county_list len : 143
# remaining_c_county_list len : 142
# remaining_c_county_list len : 141
# remaining_c_county_list len : 140
# remaining_c_county_list len : 139
# remaining_c_county_list len : 138
# remaining_c_county_list len : 137
# remaining_c_county_list len : 136
# remaining_c_county_list len : 135
# remaining_c_county_list len : 134
# remaining_c_county_list len : 133
# remaining_c_county_list len : 132
# remaining_c_county_list len : 131
# remaining_c_county_list len : 130
# remaining_c_county_list len : 129
# remaining_c_county_list len : 128
# remaining_c_county_list len : 127
# remaining_c_county_list len : 126
# remaining_c_county_list len : 125
# remaining_c_county_list len : 124
# remaining_c_county_list len : 123
# remaining_c_county_list len : 122
# remaining_c_county_list len : 121
# remaining_c_county_list len : 120
# remaining_c_county_list len : 119
# remaining_c_county_list len : 118
# remaining_c_county_list len : 117
# remaining_c_county_list len : 116
# remaining_c_county_list len : 115
# remaining_c_county_list len : 114
# remaining_c_county_list len : 113
# =========================================================
# WRAPPING MATERIALS AND BAGS
# Coef/err : 1.6909676240886737
# p_value : 0.09095213385242766
# nobs : 3565.0
# R squared : 0.27459267348192673

# %% [markdown]
# #### Test - on poolled results

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime
from random import choice


nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
#movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
# Correction des effets de bord M12
movements = fandom[((fandom.Opening_date >= '2014-01-31') & (fandom.Opening_date <= '2018-01-31')) | ((fandom.Closing_date >= '2014-01-31') & (fandom.Closing_date <= '2018-01-31'))]

# %%
pool = nielsen.groupby(['store_state','guessed_store_county','guessed_store_county_fips','purchase_month','purchase_year']).mean().reset_index()
product_group = pool

# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# We keep in the control group the only counties where we have data for the entire time period (24 months)
nb_months = control.groupby('guessed_store_county_fips').count()
control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

#nb_obs = control.groupby('guessed_store_county_fips').min()
#control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
#print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")

if treatment.shape[0] > 0 : 

    ### Creation of the placebo treatment group

        #We create an 'Opening_date' column for the control group (because we have to add an Opening_date to the
    #placebo treatment group counties)

    control['Opening_date']=0

    #We gather relevant information on the actual treatment group in an array

    treatment_info = treatment.groupby(['guessed_store_county_fips','store_state','Opening_date']).nunique()['is_walmart'].reset_index().to_numpy()


    #We select our placebo treatment group counties

    new_t_county_fips_list = []
    error = False
    #total nb of counties we want in the placebo treatment group
    nb_of_t_counties = treatment_info.shape[0]
    #list of indexes in treatment_info of the actual Tg counties for which we could not find a placebo in the same state
    index_of_missing_counties = []
    for k in range(nb_of_t_counties): 
        #for each actual Tg county, we find a placebo replacement
        #we get the county state
        state = treatment_info[k][1]
        #we get the county opening date
        opening_date = treatment_info[k][2]
        #list of the candidate county_fips for our placebo (same state as the actual Tg county, not the same county as another already existing placebo county)
        c_county_list = control[(control.store_state == state)&(~np.isin(control.guessed_store_county_fips, new_t_county_fips_list))].guessed_store_county_fips.unique().copy().tolist() 
        nb_of_c_counties = len(c_county_list) #nb of candidates
        if nb_of_c_counties > 0 :
            new_t_county_fips = choice(c_county_list) #random choice of one candidate
            new_t_county_fips_list.append(new_t_county_fips)
            #we add the right opening_date to placebo county
            control.loc[control.guessed_store_county_fips==new_t_county_fips, 'Opening_date'] = opening_date 
        else : 
            #if we did not find suitable candidates in the right state
            index_of_missing_counties.append(k)

    nb_of_missing_counties = len(index_of_missing_counties)
    if nb_of_missing_counties != 0 : 
        #if we did not find suitable candidates in the right state for at least one state, we search candidates whatever the state
        for k in index_of_missing_counties:
            remaining_c_county_list = control[~np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].guessed_store_county_fips.unique().copy().tolist()
            print(f'remaining_c_county_list len : {len(remaining_c_county_list)}')
            if len(remaining_c_county_list) <= 0 :
                error = True
            else :
                new_t_county_fips = choice(remaining_c_county_list)
                new_t_county_fips_list.append(new_t_county_fips)
                control.loc[control.guessed_store_county_fips==new_t_county_fips, 'Opening_date'] = opening_date
    if not error :

        #we keep in our placebo Tg only the selected placebo counties
        new_treatment = control[np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].copy()
        new_control = control[~np.isin(control.guessed_store_county_fips, new_t_county_fips_list)].copy()

        ### End of the creation of the placebo treatment group

        # We create our dummies for the regression
        new_control['treat'] = False
        new_control['interaction'] = False
        new_control['purchase_0'] = new_control.purchase_month + 12 * (new_control.purchase_year - 2015)
        new_control['effects'] = list(zip(new_control.store_state, new_control.purchase_0))

        new_treatment['treat'] = True
        new_treatment['purchase_0'] = new_treatment.purchase_month + 12 * (new_treatment.purchase_year - 2015)
        new_treatment['opening_0'] = pd.DatetimeIndex(new_treatment.Opening_date).month  + 12 * (pd.DatetimeIndex(new_treatment.Opening_date).year - 2015)
        new_treatment['interaction'] = new_treatment.purchase_0 >= new_treatment.opening_0
        new_treatment['effects'] = list(zip(new_treatment.store_state, new_treatment.purchase_0))

        new_treatment = new_treatment[abs(new_treatment.purchase_0-new_treatment.opening_0) >= 6]

        if new_treatment.shape[0]>0 :
            # Final dataset for the regression :

            df = pd.concat((new_control, new_treatment))[['upc_price', 'treat', 'interaction', 'effects']]
            df = df[df.upc_price != 0]

            reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
            results1 = reg1.fit()
            print("=========================================================")
            if abs(results1.params[2] / results1.bse[2]) >= 2.:
                print(f"Interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
#            if abs(results1.params[2] / results1.bse[2]) >= 2.:
#                print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
#                print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_41112\3557818609.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pool = nielsen.groupby(['store_state','guessed_store_county','guessed_store_county_fips','purchase_month','purchase_year']).mean().reset_index()
# Size of the control group: 1802.
# Size of the control group: 1390.
# Size of the treatment group: 65.
# remaining_c_county_list len : 1326
# =========================================================
# Interaction Coef : -0.06451426573199459
# Coef/err : 3.999849438742275

# %% [markdown]
# Next step : paying attention to density characterstics when choosing the placebo group ?

# %% [markdown]
# ### Placebo 2 - a category not sold by Walmart

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen2 = pd.concat((nielsen15, nielsen16))
all_cats = nielsen2["product_group_descr"].unique()

# %%
nielsen = nielsen2[nielsen2.is_walmart]
w_cats = nielsen["product_group_descr"].unique()

# %%
len(all_cats)
# Out:
# 118

# %%
len(w_cats)
# Out:
# 118

# %%
pd.set_option('display.max_rows', 500)
nielsen.groupby("product_group_descr").sum()
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_1744\1431409200.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nielsen.groupby("product_group_descr").sum()
#                                   is_walmart  guessed_store_county_fips  \
# product_group_descr
# AUTOMOTIVE                             21398                  641501720
# BABY FOOD                              10383                  312836287
# BABY NEEDS                             13749                  412061104
# BAKED GOODS-FROZEN                     23158                  690493295
# BAKING MIXES                           28826                  870021148
# BAKING SUPPLIES                        31024                  944791582
# BATTERIES AND FLASHLIGHTS              24037                  726687527
# BEER                                   16120                  487781967
# BOOKS AND MAGAZINES                    11693                  353013614
# BREAD AND BAKED GOODS                  37170                 1125859031
# BREAKFAST FOOD                         29608                  895748497
# BREAKFAST FOODS-FROZEN                 24744                  746471466
# BUTTER AND MARGARINE                   31799                  961705653
# CANDY                                  36173                 1095945193
# CANNING, FREEZING SUPPLIES              5618                  171485354
# CARBONATED BEVERAGES                   35489                 1075292803
# CEREAL                                 34409                 1042745664
# CHARCOAL, LOGS, ACCESSORIES             8249                  240993482
# CHEESE                                 35723                 1082844677
# COFFEE                                 30337                  921271791
# CONDIMENTS, GRAVIES, AND SAUCES        35384                 1072684908
# COOKIES                                33251                 1008377089
# COOKWARE                               14178                  424054368
# COSMETICS                              24165                  729115714
# COT CHEESE, SOUR CREAM, TOPPINGS       30941                  939601551
# COUGH AND COLD REMEDIES                29434                  891088089
# CRACKERS                               31975                  966992656
# DEODORANT                              26639                  802198363
# DESSERTS, GELATINS, SYRUP              29775                  906236483
# DESSERTS/FRUITS/TOPPINGS-FROZEN        21506                  651064453
# DETERGENTS                             32375                  978433479
# DIET AIDS                               8682                  259353072
# DISPOSABLE DIAPERS                     11986                  364598018
# DOUGH PRODUCTS                         25328                  764950518
# DRESSINGS/SALADS/PREP FOODS-DELI       34241                 1037598293
# EGGS                                   32469                  984445426
# ELECTRONICS, RECORDS, TAPES            25605                  775794533
# ETHNIC HABA                             2190                   61739870
# FEMININE HYGIENE                        9966                  291873595
# FIRST AID                              27726                  839264740
# FLORAL, GARDENING                      13495                  400365537
# FLOUR                                  18521                  550927924
# FRAGRANCES - WOMEN                      7334                  219292828
# FRESH MEAT                             27222                  822630930
# FRESH PRODUCE                          36642                 1111395941
# FRESHENERS AND DEODORIZERS             27696                  834718332
# FRUIT - CANNED                         25649                  776966771
# FRUIT - DRIED                          22005                  665185420
# GLASSWARE, TABLEWARE                   18580                  559493355
# GROOMING AIDS                          23251                  700921703
# GRT CARDS/PARTY NEEDS/NOVELTIES         3256                   97110091
# GUM                                    22343                  673190366
# HAIR CARE                              32157                  970960158
# HARDWARE, TOOLS                        21631                  656469937
# HOUSEHOLD CLEANERS                     30358                  917098042
# JAMS, JELLIES, SPREADS                62703  62703
# JUICE, DRINKS - CANNED, BOTTLED       77561  77561
# JUICES, DRINKS-FROZEN                 22661  22661
# KITCHEN GADGETS                       48288  48288
# LAUNDRY SUPPLIES                      57568  57568
# LIGHT BULBS, ELECTRIC GOODS           36389  36389
# LIQUOR                                24969  24969
# MAGNET DATA                           15148  15148
# MEDICATIONS/REMEDIES/HEALTH AIDS      71190  71190
# MEN'S TOILETRIES                      11740  11740
# MILK                                  84578  84578
# NUTS                                  60277  60277
# ORAL HYGIENE                          61283  61283
# PACKAGED MEATS-DELI                   84085  84085
# PACKAGED MILK AND MODIFIERS           64075  64075
# PAPER PRODUCTS                        77080  77080
# PASTA                                 63488  63488
# PERSONAL SOAP AND BATH ADDITIVES      56245  56245
# PET CARE                              53899  53899
# PET FOOD                              69188  69188
# PHOTOGRAPHIC SUPPLIES                  6849   6849
# PICKLES, OLIVES, AND RELISH           61480  61480
# PIZZA/SNACKS/HORS DOEURVES-FRZN       64558  64558
# PREPARED FOOD-DRY MIXES               74247  74247
# PREPARED FOOD-READY-TO-SERVE          71240  71240
# PREPARED FOODS-FROZEN                 74201  74201
# PUDDING, DESSERTS-DAIRY               20963  20963
# SALAD DRESSINGS, MAYO, TOPPINGS       70389  70389
# SANITARY PROTECTION                   40572  40572
# SEAFOOD - CANNED                      52236  52236
# SEASONAL                               4963   4963
# SEWING NOTIONS                         6894   6894
# SHAVING NEEDS                         40375  40375
# SHOE CARE                              8612   8612
# SHORTENING, OIL                       59805  59805
# SKIN CARE PREPARATIONS                46571  46571
# SNACKS                                85029  85029
# SNACKS, SPREADS, DIPS-DAIRY           48240  48240
# SOFT DRINKS-NON-CARBONATED            70607  70607
# SOFT GOODS                            16135  16135
# SOUP                                  71998  71998
# SPICES, SEASONING, EXTRACTS           64223  64223
# STATIONERY, SCHOOL SUPPLIES           55916  55916
# SUGAR, SWEETENERS                     63808  63808
# TABLE SYRUPS, MOLASSES                39807  39807
# TEA                                   62047  62047
# TOBACCO & ACCESSORIES                 33771  33771
# TOYS & SPORTING GOODS                  1600   1600
# UNGROUPED ITEMS                       21911  21911
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN      79750  79750
# VEGETABLES - CANNED                   75880  75880
# VEGETABLES AND GRAINS - DRIED         50271  50271
# VEGETABLES-FROZEN                     72811  72811
# VITAMINS                              60582  60582
# WINE                                  33578  33578
# WRAPPING MATERIALS AND BAGS           63023  63023
# YEAST                                   233    233
# YOGURT                                67645  67645

# %% [markdown]
# ### Placebo 3

# %% [markdown]
# #### Without placebo

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

#density_path = r"C:\Users\inesn\Documents\Mines\2A\TR\econometrics\data_collection\plein_de_data\Average_Household_Size_and_Population_Density_-_County.csv"
#density = pd.read_csv(density_path)
#density = density[["GEOID", "B01001_calc_PopDensity"]]
#nielsen = pd.merge(nielsen, density,  how='inner', left_on='guessed_store_county_fips', right_on='GEOID')
#nielsen = nielsen.rename(columns={"B01001_calc_PopDensity": "Population density (people/km^2)"})

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
#movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
# Correction des effets de bord M12
movements = fandom[((fandom.Opening_date >= '2014-01-31') & (fandom.Opening_date <= '2018-01-31')) | ((fandom.Closing_date >= '2014-01-31') & (fandom.Closing_date <= '2018-01-31'))]

# %%
categories = [
    "BUTTER AND MARGARINE",
    "CANDY",]#SVD did not converge
categories = [
    "CONDIMENTS, GRAVIES, AND SAUCES",
    "COOKIES",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "CRACKERS",
    "DRESSINGS/SALADS/PREP FOODS-DELI",
    "MILK",
    "PAPER PRODUCTS",
    "PET FOOD",
    "PREPARED FOOD-DRY MIXES",
    "PREPARED FOOD-READY-TO-SERVE", 
    "PREPARED FOODS-FROZEN",
    "SNACKS",
    "SOFT DRINKS-NON CARBONATED",
    "SPICES, SEASONINGS, EXTRACTS",
    "UNPREP MEAT/POULTRY/SEAFOOD-FRZN",
    "VEGETABLES - CANNED", 
    "VEGETABLES-FROZEN",
    "WRAPPING MATERIALS AND BAGS",
]

# %%
# We choose to focus on milk prices
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]
    #product_group = pool
    #product_group = nielsen

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    #treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
    control['effects'] = list(zip(control.store_state, control.purchase_0))

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
    
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]
    
    if treatment.shape[0]>0 :
        # Final dataset for the regression :

        df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', 'purchase_0']]
        df = df[df.upc_price != 0]

        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
        results1 = reg1.fit()
        print("=========================================================")
        print(category)
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Post-treat interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"p_value : {results1.pvalues[2]}")
        print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
        print(f"nobs : {results1.nobs}")
        print(f"R squared : {results1.rsquared}")
# Out:
# Size of the control group: 1751.
# Size of the control group: 751.
# Size of the control group: 485.
# Size of the treatment group: 65.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Post-treat interaction Coef : 0.0386449801405353
# CI_up : 0.011307696667201439
# CI_down : 0.06672123462156976
# p_value : 0.005336698703478578
# Coef/err : 2.7865072707831806
# nobs : 12514.0
# R squared : 0.2400157848784633
# Size of the control group: 1692.
# Size of the control group: 532.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# COOKIES
# Post-treat interaction Coef : 0.07051781008655622
# CI_up : 0.042317667655870306
# CI_down : 0.09948091380801571
# p_value : 5.752124276851814e-07
# Coef/err : 5.003748954765205
# nobs : 8405.0
# R squared : 0.26455744255844094
# Size of the control group: 1692.
# Size of the control group: 579.
# Size of the control group: 320.
# Size of the treatment group: 65.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Post-treat interaction Coef : -0.05277273261922932
# CI_up : -0.07677811137074797
# CI_down : -0.02814317216653861
# p_value : 3.5065494099289224e-05
# Coef/err : 4.140289732421254
# nobs : 8513.0
# R squared : 0.3340369257875262
# Size of the control group: 1687.
# Size of the control group: 542.
# Size of the control group: 302.
# Size of the treatment group: 65.
# =========================================================
# CRACKERS
# Post-treat interaction Coef : 0.01837835129460985
# CI_up : -0.008782366027142108
# CI_down : 0.04628330937656222
# p_value : 0.18666934461390328
# Coef/err : 1.3206239448841537
# nobs : 8064.0
# R squared : 0.27500147666254693
# Size of the control group: 1721.
# Size of the control group: 751.
# Size of the control group: 492.
# Size of the treatment group: 65.
# =========================================================
# DRESSINGS/SALADS/PREP FOODS-DELI
# Post-treat interaction Coef : 0.05552631402140329
# CI_up : 0.022355217767171087
# CI_down : 0.0897736718406823
# p_value : 0.0009113551524972826
# Coef/err : 3.3174072128810663
# nobs : 12688.0
# R squared : 0.2010421944495906
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.
# =========================================================
# MILK
# Post-treat interaction Coef : -0.05878051728842326
# CI_up : -0.07715748688699864
# CI_down : -0.04003759899673032
# p_value : 1.7604645707657867e-09
# Coef/err : 6.022066269970587
# nobs : 16736.0
# R squared : 0.41269254705265446
# Size of the control group: 1699.
# Size of the control group: 648.
# Size of the control group: 393.
# Size of the treatment group: 65.
# =========================================================
# PAPER PRODUCTS
# Post-treat interaction Coef : 0.11887748777518814
# CI_up : 0.07532663620400615
# CI_down : 0.16419215380861596
# p_value : 3.0037113503959126e-08
# Coef/err : 5.545981797352828
# nobs : 10273.0
# R squared : 0.1833675753719446
# Size of the control group: 1525.
# Size of the control group: 475.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# PET FOOD
# Post-treat interaction Coef : 0.04143541903144787
# CI_up : -0.03872697624822963
# CI_down : 0.12828270971357303
# p_value : 0.32042956241392634
# Coef/err : 0.9936426001110198
# nobs : 8376.0
# R squared : 0.17299133150742863
# Size of the control group: 1704.
# Size of the control group: 594.
# Size of the control group: 338.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOOD-DRY MIXES
# Post-treat interaction Coef : 0.03776860755954159
# CI_up : 0.006356089011476662
# CI_down : 0.07016164019432702
# p_value : 0.01808599984953534
# Coef/err : 2.3643445864108568
# nobs : 8949.0
# R squared : 0.20835048255248645
# Size of the control group: 1692.
# Size of the control group: 502.
# Size of the control group: 269.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOOD-READY-TO-SERVE
# Post-treat interaction Coef : -0.05847217247503089
# CI_up : -0.09716820752097877
# CI_down : -0.01811759688947079
# p_value : 0.00490218849074322
# Coef/err : 2.814387729026263
# nobs : 7280.0
# R squared : 0.2714513338283753
# Size of the control group: 1690.
# Size of the control group: 613.
# Size of the control group: 388.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOODS-FROZEN
# Post-treat interaction Coef : -0.03261208645989411
# CI_up : -0.06509777693333507
# CI_down : 0.0010024066407077203
# p_value : 0.0571076089202763
# Coef/err : 1.9027275007244342
# nobs : 10139.0
# R squared : 0.17595452016849755
# Size of the control group: 1768.
# Size of the control group: 907.
# Size of the control group: 661.
# Size of the treatment group: 65.
# =========================================================
# SNACKS
# Post-treat interaction Coef : 0.043151860565601385
# CI_up : 0.01852880470535423
# CI_down : 0.06837018175079201
# p_value : 0.0005284940931212973
# Coef/err : 3.4666008242833657
# nobs : 16747.0
# R squared : 0.22129248927291434
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 1725.
# Size of the control group: 908.
# Size of the control group: 634.
# Size of the treatment group: 64.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Post-treat interaction Coef : -0.03511205974849507
# CI_up : -0.06133870121164675
# CI_down : -0.00815263349563855
# p_value : 0.01101973975601488
# Coef/err : 2.5423874361093945
# nobs : 16094.0
# R squared : 0.2179780833407139
# Size of the control group: 1727.
# Size of the control group: 627.
# Size of the control group: 372.
# Size of the treatment group: 65.
# =========================================================
# VEGETABLES - CANNED
# Post-treat interaction Coef : 0.02898104351908737
# CI_up : 0.0006089797418005194
# CI_down : 0.058157591384844
# p_value : 0.045217043660394154
# Coef/err : 2.0029158333518455
# nobs : 9782.0
# R squared : 0.22718208517593175
# Size of the control group: 1709.
# Size of the control group: 597.
# Size of the control group: 357.
# Size of the treatment group: 65.
# =========================================================
# VEGETABLES-FROZEN
# Post-treat interaction Coef : -0.040784150278660225
# CI_up : -0.06649183081193677
# CI_down : -0.014368511464766032
# p_value : 0.0026675502794795726
# Coef/err : 3.0045569050843746
# nobs : 9414.0
# R squared : 0.21773656435049615
# Size of the control group: 1603.
# Size of the control group: 339.
# Size of the control group: 177.
# Size of the treatment group: 65.
# =========================================================
# WRAPPING MATERIALS AND BAGS
# Post-treat interaction Coef : 0.051737044988713565
# CI_up : 0.0020221693179651723
# CI_down : 0.10391850167796401
# p_value : 0.04118237018603104
# Coef/err : 2.042340956106032
# nobs : 4967.0
# R squared : 0.3619837047355877

# %% [markdown]
# #### No placebo but clustered standard errors

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import datetime

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

#density_path = r"C:\Users\inesn\Documents\Mines\2A\TR\econometrics\data_collection\plein_de_data\Average_Household_Size_and_Population_Density_-_County.csv"
#density = pd.read_csv(density_path)
#density = density[["GEOID", "B01001_calc_PopDensity"]]
#nielsen = pd.merge(nielsen, density,  how='inner', left_on='guessed_store_county_fips', right_on='GEOID')
#nielsen = nielsen.rename(columns={"B01001_calc_PopDensity": "Population density (people/km^2)"})

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
#movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
# Correction des effets de bord M12
movements = fandom[((fandom.Opening_date >= '2014-01-31') & (fandom.Opening_date <= '2018-01-31')) | ((fandom.Closing_date >= '2014-01-31') & (fandom.Closing_date <= '2018-01-31'))]

# %%
categories = [
    "BUTTER AND MARGARINE",
    "CANDY",]#SVD did not converge
categories = [
    "CONDIMENTS, GRAVIES, AND SAUCES",
    "COOKIES",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "CRACKERS",
    "DRESSINGS/SALADS/PREP FOODS-DELI",
    "MILK",
    "PAPER PRODUCTS",
    "PET FOOD",
    "PREPARED FOOD-DRY MIXES",
    "PREPARED FOOD-READY-TO-SERVE", 
    "PREPARED FOODS-FROZEN",
    "SNACKS",
    "SOFT DRINKS-NON CARBONATED",
    "SPICES, SEASONINGS, EXTRACTS",
    "UNPREP MEAT/POULTRY/SEAFOOD-FRZN",
    "VEGETABLES - CANNED", 
    "VEGETABLES-FROZEN",
    "WRAPPING MATERIALS AND BAGS",
]

# %%
# We choose to focus on milk prices
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]
    #product_group = pool
    #product_group = nielsen

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    #treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
    control['effects'] = list(zip(control.store_state, control.purchase_0))

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
    
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]
    
    if treatment.shape[0]>0 :
        # Final dataset for the regression :

        df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', 'purchase_0','store_state']]
        df = df[df.upc_price != 0]

        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
        results1 = reg1.fit(cov_type="cluster", cov_kwds={"groups": df['store_state']})
        print("=========================================================")
        print(category)
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Post-treat interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"p_value : {results1.pvalues[2]}")
        print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
        print(f"nobs : {results1.nobs}")
        print(f"R squared : {results1.rsquared}")
# Out:
# Size of the control group: 1751.
# Size of the control group: 751.
# Size of the control group: 485.
# Size of the treatment group: 65.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Post-treat interaction Coef : 0.0386449801405353
# CI_up : -0.03156807728723643
# CI_down : 0.11394861060471229
# p_value : 0.2883511839428322
# Coef/err : 1.0617456177686513
# nobs : 12514.0
# R squared : 0.2400157848784633
# Size of the control group: 1692.
# Size of the control group: 532.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# COOKIES
# Post-treat interaction Coef : 0.07051781008655622
# CI_up : 0.027499551643439535
# CI_down : 0.11533711122260515
# p_value : 0.0011285381552363068
# Coef/err : 3.2563518296049625
# nobs : 8405.0
# R squared : 0.26455744255844094
# Size of the control group: 1692.
# Size of the control group: 579.
# Size of the control group: 320.
# Size of the treatment group: 65.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Post-treat interaction Coef : -0.05277273261922932
# CI_up : -0.10530003020783396
# CI_down : 0.0028384110464048096
# p_value : 0.06252011304824709
# Coef/err : 1.8625890007159154
# nobs : 8513.0
# R squared : 0.3340369257875262
# Size of the control group: 1687.
# Size of the control group: 542.
# Size of the control group: 302.
# Size of the treatment group: 65.
# =========================================================
# CRACKERS
# Post-treat interaction Coef : 0.01837835129460985
# CI_up : -0.04940129756484324
# CI_down : 0.09099082896788535
# p_value : 0.6042884664033574
# Coef/err : 0.5182433875217843
# nobs : 8064.0
# R squared : 0.27500147666254693
# Size of the control group: 1721.
# Size of the control group: 751.
# Size of the control group: 492.
# Size of the treatment group: 65.
# =========================================================
# DRESSINGS/SALADS/PREP FOODS-DELI
# Post-treat interaction Coef : 0.05552631402140329
# CI_up : -0.036514616184656234
# CI_down : 0.15635983514321716
# p_value : 0.24569184205896277
# Coef/err : 1.1608772002246952
# nobs : 12688.0
# R squared : 0.2010421944495906
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.
# =========================================================
# MILK
# Post-treat interaction Coef : -0.05878051728842326
# CI_up : -0.09928881348291752
# CI_down : -0.016450413965135358
# p_value : 0.0069553338313375086
# Coef/err : 2.698975300273032
# nobs : 16736.0
# R squared : 0.41269254705265446
# Size of the control group: 1699.
# Size of the control group: 648.
# Size of the control group: 393.
# Size of the treatment group: 65.
# =========================================================
# PAPER PRODUCTS
# Post-treat interaction Coef : 0.11887748777518814
# CI_up : 0.017511451764043118
# CI_down : 0.23034176222757985
# p_value : 0.020435876048654125
# Coef/err : 2.3182474598040854
# nobs : 10273.0
# R squared : 0.1833675753719446
# Size of the control group: 1525.
# Size of the control group: 475.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# PET FOOD
# Post-treat interaction Coef : 0.04143541903144787
# CI_up : -0.15011395359978774
# CI_down : 0.27615665253842003
# p_value : 0.6954242563866526
# Coef/err : 0.3915046443547503
# nobs : 8376.0
# R squared : 0.17299133150742863
# Size of the control group: 1704.
# Size of the control group: 594.
# Size of the control group: 338.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOOD-DRY MIXES
# Post-treat interaction Coef : 0.03776860755954159
# CI_up : -0.0532633442757976
# CI_down : 0.1375535914073709
# p_value : 0.42867723096658694
# Coef/err : 0.7914572197111976
# nobs : 8949.0
# R squared : 0.20835048255248645
# Size of the control group: 1692.
# Size of the control group: 502.
# Size of the control group: 269.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOOD-READY-TO-SERVE
# Post-treat interaction Coef : -0.05847217247503089
# CI_up : -0.16087846352526547
# CI_down : 0.056431769977076884
# p_value : 0.30510319446112966
# Coef/err : 1.0255511692113244
# nobs : 7280.0
# R squared : 0.2714513338283753
# Size of the control group: 1690.
# Size of the control group: 613.
# Size of the control group: 388.
# Size of the treatment group: 65.
# =========================================================
# PREPARED FOODS-FROZEN
# Post-treat interaction Coef : -0.03261208645989411
# CI_up : -0.11799808221704022
# CI_down : 0.061040068502172584
# p_value : 0.4819003045235709
# Coef/err : 0.703249454168626
# nobs : 10139.0
# R squared : 0.17595452016849755
# Size of the control group: 1768.
# Size of the control group: 907.
# Size of the control group: 661.
# Size of the treatment group: 65.
# =========================================================
# SNACKS
# Post-treat interaction Coef : 0.043151860565601385
# CI_up : -0.03421391964035825
# CI_down : 0.12671514565240183
# p_value : 0.2825898761900776
# Coef/err : 1.0745195749833834
# nobs : 16747.0
# R squared : 0.22129248927291434
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the control group: 0.
# Size of the treatment group: 0.
# Size of the control group: 1725.
# Size of the control group: 908.
# Size of the control group: 634.
# Size of the treatment group: 64.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Post-treat interaction Coef : -0.03511205974849507
# CI_up : -0.09357186309261789
# CI_down : 0.027118090595990907
# p_value : 0.2623365470752387
# Coef/err : 1.120885633085967
# nobs : 16094.0
# R squared : 0.2179780833407139
# Size of the control group: 1727.
# Size of the control group: 627.
# Size of the control group: 372.
# Size of the treatment group: 65.
# =========================================================
# VEGETABLES - CANNED
# Post-treat interaction Coef : 0.02898104351908737
# CI_up : -0.04416888347488257
# CI_down : 0.10772914756202812
# p_value : 0.44766367937325957
# Coef/err : 0.759315781307588
# nobs : 9782.0
# R squared : 0.22718208517593175
# Size of the control group: 1709.
# Size of the control group: 597.
# Size of the control group: 357.
# Size of the treatment group: 65.
# =========================================================
# VEGETABLES-FROZEN
# Post-treat interaction Coef : -0.040784150278660225
# CI_up : -0.12029313874262582
# CI_down : 0.04591095838621784
# p_value : 0.3455868569592482
# Coef/err : 0.9431838805195502
# nobs : 9414.0
# R squared : 0.21773656435049615
# Size of the control group: 1603.
# Size of the control group: 339.
# Size of the control group: 177.
# Size of the treatment group: 65.
# =========================================================
# WRAPPING MATERIALS AND BAGS
# Post-treat interaction Coef : 0.051737044988713565
# CI_up : -0.07325614260598945
# CI_down : 0.19358850126298144
# p_value : 0.43455309123076624
# Coef/err : 0.7814241170472789
# nobs : 4967.0
# R squared : 0.3619837047355877

# %% [markdown]
# #### With placebo

# %%
categories = [
    "BUTTER AND MARGARINE",
    "CANDY",]#SVD did not converge
categories2 = [
    "COOKIES",
    "CRACKERS",
    "PAPER PRODUCTS",
    "PET FOOD",
    "VEGETABLES-FROZEN",
    "WRAPPING MATERIALS AND BAGS",
]

# %%
# We choose to focus on milk prices
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]
    #product_group = pool
    #product_group = nielsen

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
    control['effects'] = list(zip(control.store_state, control.purchase_0))

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
    treatment['opening_0'] = (treatment['opening_0'] - 12)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
    
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]
    
    if treatment.shape[0]>0 :
        # Final dataset for the regression :

        df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', 'purchase_0']]
        df = df[df.upc_price != 0]

        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
        results1 = reg1.fit()
        print("=========================================================")
        print(category)
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Post-treat interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"p_value : {results1.pvalues[2]}")
        print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
        print(f"nobs : {results1.nobs}")
        print(f"R squared : {results1.rsquared}")
# Out:
# Size of the control group: 1695.
# Size of the control group: 558.
# Size of the control group: 289.
# Size of the treatment group: 65.
# =========================================================
# BUTTER AND MARGARINE
# Post-treat interaction Coef : 0.05830317322677114
# CI_up : 0.0009015983912639136
# CI_down : 0.11899672081853341
# p_value : 0.04641180915050248
# Coef/err : 1.9919840895975647
# nobs : 8012.0
# R squared : 0.34879886762180556
# Size of the control group: 1751.
# Size of the control group: 701.
# Size of the control group: 460.
# Size of the treatment group: 65.
# =========================================================
# CANDY
# Post-treat interaction Coef : 0.019115323022838027
# CI_up : -0.04822857861156793
# CI_down : 0.09122423544179603
# p_value : 0.5872066118651752
# Coef/err : 0.5429042910963495
# nobs : 12145.0
# R squared : 0.25144313206654423

# %% [markdown]
# #### With clustered standard errors

# %%
categories = [
    "COOKIES",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "MILK",
    "PAPER PRODUCTS",
]

# %%
# We choose to focus on milk prices
for category in categories :
    product_group = nielsen[nielsen.product_group_descr == category]
    #product_group = pool
    #product_group = nielsen

    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # We keep in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015)
    control['effects'] = list(zip(control.store_state, control.purchase_0))

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015)
    treatment['opening_0'] = (treatment['opening_0'] - 12)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0))
    
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) >= 6]
    
    if treatment.shape[0]>0 :
        # Final dataset for the regression :

        df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects', 'purchase_0','store_state']]
        df = df[df.upc_price != 0]

        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
        results1 = reg1.fit(cov_type="cluster", cov_kwds={"groups": df['store_state']})
        print("=========================================================")
        print(category)
        if True :
        #abs(results1.params[2] / results1.bse[2]) >= 2.:
            print(f"Post-treat interaction Coef : {np.exp(results1.params[2])-1}")
            print(f"CI_up : {np.exp(results1.conf_int(alpha=0.05)[0][2])-1}")
            print(f"CI_down : {np.exp(results1.conf_int(alpha=0.05)[1][2])-1}")
        print(f"p_value : {results1.pvalues[2]}")
        print(f"Coef/err : {abs(results1.params[2] / results1.bse[2])}")
        print(f"nobs : {results1.nobs}")
        print(f"R squared : {results1.rsquared}")
# Out:
# Size of the control group: 1692.
# Size of the control group: 532.
# Size of the control group: 316.
# Size of the treatment group: 65.
# =========================================================
# COOKIES
# Post-treat interaction Coef : 0.043676345439091824
# CI_up : -0.042809068418461216
# CI_down : 0.137976006761102
# p_value : 0.33273516088864397
# Coef/err : 0.9686193186774792
# nobs : 8643.0
# R squared : 0.26245421539502944
# Size of the control group: 1692.
# Size of the control group: 579.
# Size of the control group: 320.
# Size of the treatment group: 65.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Post-treat interaction Coef : -0.014731836330315828
# CI_up : -0.08452677995547009
# CI_down : 0.0603842177860896
# p_value : 0.6921707104008146
# Coef/err : 0.3959109667978895
# nobs : 8752.0
# R squared : 0.3435700843191568
# Size of the control group: 1753.
# Size of the control group: 974.
# Size of the control group: 660.
# Size of the treatment group: 65.
# =========================================================
# MILK
# Post-treat interaction Coef : -0.09082993790842486
# CI_up : -0.1720816439271684
# CI_down : -0.0016042092308871103
# p_value : 0.04619836340958538
# Coef/err : 1.9935764290456295
# nobs : 16990.0
# R squared : 0.4117488910960363
# Size of the control group: 1699.
# Size of the control group: 648.
# Size of the control group: 393.
# Size of the treatment group: 65.
# =========================================================
# PAPER PRODUCTS
# Post-treat interaction Coef : -0.014910646997075339
# CI_up : -0.13173964284890705
# CI_down : 0.1176383044640763
# p_value : 0.8155749835319098
# Coef/err : 0.23324008139711158
# nobs : 10527.0
# R squared : 0.17357822051257277
