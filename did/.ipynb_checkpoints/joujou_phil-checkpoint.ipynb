# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_milk_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_milk_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

# %%
nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

# %%
## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
#movements['year'] = movements.Opening_date.dt.year
#movements['month'] = movements.Opening_date.dt.month

# %% [markdown]
# ## FIRST MODEL : one month

# %% [markdown]
# Regression model :
# $$ Price_{i, t} = \alpha + \beta \cdot treat_i + \gamma \cdot post_t + \delta \cdot treat_i \cdot post_{t} + \varepsilon_{i, t}$$

# %%
year = 2016
month = 1

# %%
# We choose to focus on milk prices
milk = nielsen[nielsen.product_group_descr == 'MILK']


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = milk[~np.isin(milk.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in august 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index)) & (movements.Opening_date.dt.year == year) & (movements.Opening_date.dt.month == month)]

treatment = milk[np.isin(milk.guessed_store_county_fips, treatment_movements.County_fips )].copy()
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['post'] = (control.purchase_month > month) & (control.purchase_year == year)
treatment['treat'] = True
treatment['post'] = (treatment.purchase_month > month) & (treatment.purchase_year == year)


# Final dataset for the regression :

df = pd.concat((control, treatment))[['price_per_gal', 'treat', 'post']]
df = df[df.price_per_gal != 0]
# Out:
# Size of the control group: 2279.
# Size of the treatment group: 15.

# %%
reg = smf.ols(formula='np.log(price_per_gal) ~ treat * post', data=df)
results = reg.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(price_per_gal)   R-squared:                       0.001
# Model:                               OLS   Adj. R-squared:                  0.001
# Method:                    Least Squares   F-statistic:                     22.24
# Date:                   Fri, 28 Oct 2022   Prob (F-statistic):           2.20e-14
# Time:                           14:03:30   Log-Likelihood:                -18078.
# No. Observations:                  44561   AIC:                         3.616e+04
# Df Residuals:                      44557   BIC:                         3.620e+04
# Df Model:                              3
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      1.5304      0.002    654.187      0.000       1.526       1.535
# treat[T.True]                  0.0045      0.026      0.171      0.864      -0.047       0.056
# post[T.True]                  -0.0277      0.003     -7.987      0.000      -0.034      -0.021
# treat[T.True]:post[T.True]    -0.0341      0.039     -0.885      0.376      -0.110       0.042
# ==============================================================================
# Omnibus:                     2927.219   Durbin-Watson:                   0.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5618.718
# Skew:                           0.474   Prob(JB):                         0.00
# Kurtosis:                       4.459   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## SECOND MODEL : all months

# %% [markdown]
# Regression model :
# $$ Price_{i, t} = \alpha + \beta \cdot treat_i + \delta \cdot treat_i \cdot post_{t} + \varepsilon_{i, t}$$

# %%
# We choose to focus on milk prices
milk = nielsen[nielsen.product_group_descr == 'MILK']


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = milk[~np.isin(milk.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatment = milk[np.isin(milk.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = False
treatment['treat'] = True
treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)


# Final dataset for the regression :

df = pd.concat((control, treatment))[['price_per_gal', 'treat', 'interaction']]
df = df[df.price_per_gal != 0]
# Out:
# Size of the control group: 2279.
# Size of the treatment group: 89.

# %%
reg = smf.ols(formula='np.log(price_per_gal) ~ treat + interaction', data=df)
results = reg.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(price_per_gal)   R-squared:                       0.001
# Model:                               OLS   Adj. R-squared:                  0.001
# Method:                    Least Squares   F-statistic:                     28.95
# Date:                   Fri, 28 Oct 2022   Prob (F-statistic):           2.72e-13
# Time:                           14:03:49   Log-Likelihood:                -18513.
# No. Observations:                  46318   AIC:                         3.703e+04
# Df Residuals:                      46315   BIC:                         3.706e+04
# Df Model:                              2
# Covariance Type:               nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               1.5178      0.002    884.247      0.000       1.514       1.521
# treat[T.True]           0.0663      0.010      6.771      0.000       0.047       0.085
# interaction[T.True]    -0.0170      0.017     -1.024      0.306      -0.050       0.016
# ==============================================================================
# Omnibus:                     2975.617   Durbin-Watson:                   0.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5919.912
# Skew:                           0.454   Prob(JB):                         0.00
# Kurtosis:                       4.497   Cond. No.                         10.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
np.exp(results.params[2])-1
# Out:
# -0.01684309250910787

# %% [markdown]
# ## THIRD MODEL : adding time fixed effects

# %% [markdown]
# Regression model :
# $$ Price_{i, t} = \alpha + \beta \cdot treat_i + \delta \cdot treat_i \cdot post_{t} + \sum_{\tau=Janv15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau) + \varepsilon_{i, t}$$

# %%
# We choose to focus on milk prices
milk = nielsen[nielsen.product_group_descr == 'MILK']


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = milk[~np.isin(milk.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatment = milk[np.isin(milk.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = False
control['time_fixed_effects'] = list(zip(control.purchase_year, control.purchase_month))
treatment['treat'] = True
treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)
treatment['time_fixed_effects'] = list(zip(treatment.purchase_year, treatment.purchase_month))


# Final dataset for the regression :

df = pd.concat((control, treatment))[['price_per_gal', 'treat', 'interaction', 'time_fixed_effects']]
df = df[df.price_per_gal != 0]
# Out:
# Size of the control group: 2279.
# Size of the treatment group: 89.

# %%
reg = smf.ols(formula='np.log(price_per_gal) ~ treat + interaction + C(time_fixed_effects)', data=df)
results = reg.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(price_per_gal)   R-squared:                       0.020
# Model:                               OLS   Adj. R-squared:                  0.019
# Method:                    Least Squares   F-statistic:                     37.59
# Date:                   Fri, 28 Oct 2022   Prob (F-statistic):          3.17e-180
# Time:                           14:04:06   Log-Likelihood:                -18076.
# No. Observations:                  46318   AIC:                         3.620e+04
# Df Residuals:                      46292   BIC:                         3.643e+04
# Df Model:                             25
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               1.5695      0.008    194.177      0.000       1.554       1.585
# treat[T.True]                           0.0709      0.010      7.288      0.000       0.052       0.090
# interaction[T.True]                    -0.0304      0.017     -1.836      0.066      -0.063       0.002
# C(time_fixed_effects)[T.(2015, 2)]     -0.0241      0.011     -2.113      0.035      -0.046      -0.002
# C(time_fixed_effects)[T.(2015, 3)]     -0.0309      0.011     -2.709      0.007      -0.053      -0.009
# C(time_fixed_effects)[T.(2015, 4)]     -0.0491      0.011     -4.284      0.000      -0.072      -0.027
# C(time_fixed_effects)[T.(2015, 5)]     -0.0621      0.011     -5.413      0.000      -0.085      -0.040
# C(time_fixed_effects)[T.(2015, 6)]     -0.0754      0.011     -6.594      0.000      -0.098      -0.053
# C(time_fixed_effects)[T.(2015, 7)]     -0.0623      0.011     -5.439      0.000      -0.085      -0.040
# C(time_fixed_effects)[T.(2015, 8)]     -0.0665      0.011     -5.817      0.000      -0.089      -0.044
# C(time_fixed_effects)[T.(2015, 9)]     -0.0590      0.011     -5.149      0.000      -0.081      -0.037
# C(time_fixed_effects)[T.(2015, 10)]    -0.0421      0.011     -3.676      0.000      -0.065      -0.020
# C(time_fixed_effects)[T.(2015, 11)]    -0.0033      0.011     -0.291      0.771      -0.026       0.019
# C(time_fixed_effects)[T.(2015, 12)]     0.0417      0.011      3.639      0.000       0.019       0.064
# C(time_fixed_effects)[T.(2016, 1)]     -0.0755      0.011     -6.590      0.000      -0.098      -0.053
# C(time_fixed_effects)[T.(2016, 2)]     -0.0975      0.011     -8.490      0.000      -0.120      -0.075
# C(time_fixed_effects)[T.(2016, 3)]     -0.0847      0.011     -7.382      0.000      -0.107      -0.062
# C(time_fixed_effects)[T.(2016, 4)]     -0.1065      0.011     -9.280      0.000      -0.129      -0.084
# C(time_fixed_effects)[T.(2016, 5)]     -0.0854      0.011     -7.441      0.000      -0.108      -0.063
# C(time_fixed_effects)[T.(2016, 6)]     -0.1093      0.011     -9.525      0.000      -0.132      -0.087
# C(time_fixed_effects)[T.(2016, 7)]     -0.1064      0.011     -9.262      0.000      -0.129      -0.084
# C(time_fixed_effects)[T.(2016, 8)]     -0.0947      0.012     -8.233      0.000      -0.117      -0.072
# C(time_fixed_effects)[T.(2016, 9)]     -0.0846      0.012     -7.355      0.000      -0.107      -0.062
# C(time_fixed_effects)[T.(2016, 10)]    -0.0462      0.012     -4.012      0.000      -0.069      -0.024
# C(time_fixed_effects)[T.(2016, 11)]    -0.0239      0.012     -2.076      0.038      -0.046      -0.001
# C(time_fixed_effects)[T.(2016, 12)]     0.1047      0.011      9.112      0.000       0.082       0.127
# ==============================================================================
# Omnibus:                     3182.060   Durbin-Watson:                   0.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6437.340
# Skew:                           0.476   Prob(JB):                         0.00
# Kurtosis:                       4.558   Cond. No.                         24.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
np.exp(results.params[2])-1
# Out:
# -0.02996959651819109

# %% [markdown]
# ## THIRD MODEL : adding entity effects

# %% [markdown]
# Regression model :
# $$ Price_{i, t} = \alpha + \beta \cdot treat_i + \delta \cdot treat_i \cdot post_{t} + \sum_{\tau=Janv15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau) + \sum_{s \in USStates}\gamma_{s} \cdot \mathbb{1}(state = s) + \varepsilon_{i, t}$$

# %%
# We choose to focus on milk prices
milk = nielsen[nielsen.product_group_descr == 'MILK']


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = milk[~np.isin(milk.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatment = milk[np.isin(milk.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = False
control['time_fixed_effects'] = list(zip(control.purchase_month, control.purchase_year))
treatment['treat'] = True
treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)
treatment['time_fixed_effects'] = list(zip(treatment.purchase_month, treatment.purchase_year))


# Final dataset for the regression :

df = pd.concat((control, treatment))[['price_per_gal', 'treat', 'interaction', 'time_fixed_effects', 'store_state']]
df = df[df.price_per_gal != 0]
# Out:
# Size of the control group: 2279.
# Size of the treatment group: 89.

# %%
reg = smf.ols(formula='np.log(price_per_gal) ~ treat + interaction + C(time_fixed_effects) + C(store_state)', data=df)
results = reg.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     np.log(price_per_gal)   R-squared:                       0.207
# Model:                               OLS   Adj. R-squared:                  0.206
# Method:                    Least Squares   F-statistic:                     165.2
# Date:                   Fri, 28 Oct 2022   Prob (F-statistic):               0.00
# Time:                           14:04:37   Log-Likelihood:                -13176.
# No. Observations:                  46318   AIC:                         2.650e+04
# Df Residuals:                      46244   BIC:                         2.715e+04
# Df Model:                             73
# Covariance Type:               nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               1.6635      0.013    132.758      0.000       1.639       1.688
# treat[T.True]                           0.0467      0.009      5.141      0.000       0.029       0.065
# interaction[T.True]                    -0.0090      0.015     -0.601      0.548      -0.038       0.020
# C(time_fixed_effects)[T.(1, 2016)]     -0.0755      0.010     -7.324      0.000      -0.096      -0.055
# C(time_fixed_effects)[T.(2, 2015)]     -0.0243      0.010     -2.361      0.018      -0.044      -0.004
# C(time_fixed_effects)[T.(2, 2016)]     -0.0985      0.010     -9.525      0.000      -0.119      -0.078
# C(time_fixed_effects)[T.(3, 2015)]     -0.0319      0.010     -3.105      0.002      -0.052      -0.012
# C(time_fixed_effects)[T.(3, 2016)]     -0.0863      0.010     -8.361      0.000      -0.107      -0.066
# C(time_fixed_effects)[T.(4, 2015)]     -0.0490      0.010     -4.748      0.000      -0.069      -0.029
# C(time_fixed_effects)[T.(4, 2016)]     -0.1073      0.010    -10.384      0.000      -0.128      -0.087
# C(time_fixed_effects)[T.(5, 2015)]     -0.0628      0.010     -6.079      0.000      -0.083      -0.043
# C(time_fixed_effects)[T.(5, 2016)]     -0.0876      0.010     -8.481      0.000      -0.108      -0.067
# C(time_fixed_effects)[T.(6, 2015)]     -0.0754      0.010     -7.324      0.000      -0.096      -0.055
# C(time_fixed_effects)[T.(6, 2016)]     -0.1124      0.010    -10.883      0.000      -0.133      -0.092
# C(time_fixed_effects)[T.(7, 2015)]     -0.0624      0.010     -6.054      0.000      -0.083      -0.042
# C(time_fixed_effects)[T.(7, 2016)]     -0.1091      0.010    -10.552      0.000      -0.129      -0.089
# C(time_fixed_effects)[T.(8, 2015)]     -0.0661      0.010     -6.425      0.000      -0.086      -0.046
# C(time_fixed_effects)[T.(8, 2016)]     -0.0972      0.010     -9.382      0.000      -0.117      -0.077
# C(time_fixed_effects)[T.(9, 2015)]     -0.0592      0.010     -5.737      0.000      -0.079      -0.039
# C(time_fixed_effects)[T.(9, 2016)]     -0.0858      0.010     -8.291      0.000      -0.106      -0.066
# C(time_fixed_effects)[T.(10, 2015)]    -0.0419      0.010     -4.067      0.000      -0.062      -0.022
# C(time_fixed_effects)[T.(10, 2016)]    -0.0484      0.010     -4.667      0.000      -0.069      -0.028
# C(time_fixed_effects)[T.(11, 2015)]    -0.0045      0.010     -0.433      0.665      -0.025       0.016
# C(time_fixed_effects)[T.(11, 2016)]    -0.0271      0.010     -2.616      0.009      -0.047      -0.007
# C(time_fixed_effects)[T.(12, 2015)]     0.0422      0.010      4.085      0.000       0.022       0.062
# C(time_fixed_effects)[T.(12, 2016)]     0.1024      0.010      9.899      0.000       0.082       0.123
# C(store_state)[T.AR]                   -0.1292      0.015     -8.452      0.000      -0.159      -0.099
# C(store_state)[T.AZ]                   -0.2062      0.021    -10.020      0.000      -0.246      -0.166
# C(store_state)[T.CA]                    0.2544      0.014     18.527      0.000       0.228       0.281
# C(store_state)[T.CO]                   -0.0217      0.015     -1.402      0.161      -0.052       0.009
# C(store_state)[T.CT]                    0.3276      0.029     11.400      0.000       0.271       0.384
# C(store_state)[T.DC]                    0.3674      0.067      5.491      0.000       0.236       0.499
# C(store_state)[T.DE]                    0.1037      0.039      2.639      0.008       0.027       0.181
# C(store_state)[T.FL]                    0.0829      0.014      5.863      0.000       0.055       0.111
# C(store_state)[T.GA]                   -0.0369      0.012     -2.957      0.003      -0.061      -0.012
# C(store_state)[T.IA]                   -0.2428      0.013    -18.499      0.000      -0.269      -0.217
# C(store_state)[T.ID]                   -0.2904      0.016    -17.602      0.000      -0.323      -0.258
# C(store_state)[T.IL]                   -0.3276      0.013    -25.234      0.000      -0.353      -0.302
# C(store_state)[T.IN]                   -0.3906      0.013    -30.554      0.000      -0.416      -0.366
# C(store_state)[T.KS]                   -0.2047      0.014    -14.637      0.000      -0.232      -0.177
# C(store_state)[T.KY]                   -0.2801      0.013    -21.787      0.000      -0.305      -0.255
# C(store_state)[T.LA]                    0.1122      0.015      7.713      0.000       0.084       0.141
# C(store_state)[T.MA]                    0.2821      0.021     13.290      0.000       0.240       0.324
# C(store_state)[T.MD]                    0.0314      0.018      1.765      0.078      -0.003       0.066
# C(store_state)[T.ME]                    0.2103      0.019     10.812      0.000       0.172       0.248
# C(store_state)[T.MI]                   -0.1590      0.013    -12.188      0.000      -0.185      -0.133
# C(store_state)[T.MN]                   -0.0528      0.013     -3.948      0.000      -0.079      -0.027
# C(store_state)[T.MO]                   -0.1220      0.013     -9.236      0.000      -0.148      -0.096
# C(store_state)[T.MS]                   -0.0921      0.015     -6.229      0.000      -0.121      -0.063
# C(store_state)[T.MT]                   -0.0104      0.017     -0.601      0.548      -0.044       0.023
# C(store_state)[T.NC]                   -0.0904      0.013     -6.825      0.000      -0.116      -0.064
# C(store_state)[T.ND]                    0.0949      0.020      4.802      0.000       0.056       0.134
# C(store_state)[T.NE]                   -0.1698      0.015    -11.185      0.000      -0.200      -0.140
# C(store_state)[T.NH]                    0.1190      0.024      5.035      0.000       0.073       0.165
# C(store_state)[T.NJ]                    0.3261      0.018     18.381      0.000       0.291       0.361
# C(store_state)[T.NM]                   -0.0617      0.018     -3.378      0.001      -0.098      -0.026
# C(store_state)[T.NV]                    0.0891      0.026      3.459      0.001       0.039       0.140
# C(store_state)[T.NY]                    0.0960      0.013      7.156      0.000       0.070       0.122
# C(store_state)[T.OH]                   -0.2936      0.013    -23.105      0.000      -0.318      -0.269
# C(store_state)[T.OK]                   -0.1372      0.015     -8.909      0.000      -0.167      -0.107
# C(store_state)[T.OR]                   -0.1384      0.017     -8.362      0.000      -0.171      -0.106
# C(store_state)[T.PA]                    0.0020      0.013      0.152      0.879      -0.024       0.028
# C(store_state)[T.RI]                    0.3374      0.031     10.837      0.000       0.276       0.398
# C(store_state)[T.SC]                   -0.0306      0.016     -1.931      0.053      -0.062       0.000
# C(store_state)[T.SD]                   -0.1029      0.018     -5.772      0.000      -0.138      -0.068
# C(store_state)[T.TN]                   -0.1131      0.013     -8.491      0.000      -0.139      -0.087
# C(store_state)[T.TX]                   -0.0220      0.012     -1.852      0.064      -0.045       0.001
# C(store_state)[T.UT]                   -0.3171      0.020    -15.977      0.000      -0.356      -0.278
# C(store_state)[T.VA]                   -0.0875      0.013     -6.985      0.000      -0.112      -0.063
# C(store_state)[T.VT]                    0.1542      0.022      7.133      0.000       0.112       0.197
# C(store_state)[T.WA]                   -0.0366      0.016     -2.310      0.021      -0.068      -0.006
# C(store_state)[T.WI]                   -0.1401      0.013    -10.464      0.000      -0.166      -0.114
# C(store_state)[T.WV]                   -0.2137      0.015    -13.831      0.000      -0.244      -0.183
# C(store_state)[T.WY]                   -0.1337      0.020     -6.725      0.000      -0.173      -0.095
# ==============================================================================
# Omnibus:                     6447.646   Durbin-Watson:                   1.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20082.135
# Skew:                           0.727   Prob(JB):                         0.00
# Kurtosis:                       5.879   Cond. No.                         52.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## THIRD MODEL : adding entity effects

# %% [markdown]
# Regression model :
# $$
# \begin{align}
# Price_{i, t} &= \alpha + \beta \cdot treat_i + \sum_{\tau=Feb15}^{Dec16} \delta_{\tau} \cdot treat_i \cdot \mathbb{1}(t=\tau)  + \sum_{\tau=Feb15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau) + \sum_{s \in USStates}\gamma_{s} \cdot \mathbb{1}(state = s) + \varepsilon_{i, t}\\
# &= \beta_i + \sum_{\tau=Feb15}^{Dec16} \delta_{\tau} \cdot treat_i \cdot \mathbb{1}(t=\tau)  + \rho_t + \varepsilon_{i, t}
# \end{align}
# $$

# %%
# We choose to focus on milk prices
milk = nielsen[nielsen.product_group_descr == 'MILK']


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = milk[~np.isin(milk.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatment = milk[np.isin(milk.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = 0
control['time_fixed_effects'] = list(zip(control.purchase_month, control.purchase_year))

treatment['treat'] = True
treatment['purchase_0'] = treatment.purchase_month * (treatment.purchase_year == 2015) + (treatment.purchase_month +12) * (treatment.purchase_year == 2016)
treatment['opening_0'] = treatment.Opening_date.dt.month * (treatment.Opening_date.dt.year == 2015) + (treatment.Opening_date.dt.month +12) * (treatment.Opening_date.dt.year == 2016)
treatment['interaction'] = treatment.purchase_0 - treatment.opening_0
treatment = treatment[abs(treatment.interaction) <=5]
treatment['time_fixed_effects'] = list(zip(treatment.purchase_month, treatment.purchase_year))


# Final dataset for the regression :

df = pd.concat((control, treatment))[['price_per_gal', 'treat', 'interaction', 'time_fixed_effects', 'store_state']]
df = df[df.price_per_gal != 0]
# Out:
# Size of the control group: 1822.
# Size of the treatment group: 89.

# %%
reg = smf.ols(formula='np.log(price_per_gal) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state)', data=df)
results = reg.fit()

# %%
results.summary()

# %%
hoho = treatment.groupby('interaction').mean()

# %%
wm15[wm15.is_walmart]
# Out:
#        is_walmart store_state guessed_store_county  guessed_store_county_fips  \
# 24406        True          AL              AUTAUGA                       1001
# 24407        True          AL              AUTAUGA                       1001
# 24408        True          AL              AUTAUGA                       1001
# 24409        True          AL              AUTAUGA                       1001
# 24410        True          AL              AUTAUGA                       1001
# ...           ...         ...                  ...                        ...
# 42307        True          WY                UINTA                      56041
# 42308        True          WY                UINTA                      56041
# 42309        True          WY                UINTA                      56041
# 42310        True          WY                UINTA                      56041
# 42311        True          WY                UINTA                      56041
#
#        purchase_year  purchase_month product_group_descr  price_per_gal  \
# 24406           2015               1                MILK       7.760000
# 24407           2015               2                MILK       4.926667
# 24408           2015               3                MILK       4.873333
# 24409           2015               4                MILK       4.973333
# 24410           2015               5                MILK       4.692500
# ...              ...             ...                 ...            ...
# 42307           2015               8                MILK       3.340526
# 42308           2015               9                MILK       3.970000
# 42309           2015              10                MILK       3.050000
# 42310           2015              11                MILK       3.328889
# 42311           2015              12                MILK       3.790000
#
#        price_std  nb_of_obs  year
# 24406   0.282843          2  2015
# 24407   1.040064          3  2015
# 24408   2.331552          3  2015
# 24409   2.240119          3  2015
# 24410   1.972838          4  2015
# ...          ...        ...   ...
# 42307   2.001737         19  2015
# 42308   2.541375         14  2015
# 42309   0.841804          7  2015
# 42310   2.914878          9  2015
# 42311   2.616746          6  2015
#
# [17906 rows x 11 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
wm15 = pd.read_csv('../../Nielsen/aggregated_nielsen_milk_2015.csv')
wm16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_milk_2016.csv')
wm15['year'] = 2015
wm16['year'] = 2016
wm = pd.concat((wm15, wm16))
wm = wm[wm.is_walmart]


## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes still remain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
wm = wm[~np.isin(wm.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]


# We choose to focus on milk prices
milkwm = wm[wm.product_group_descr == 'MILK']


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatmentwm = milkwm[np.isin(milkwm.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatmentwm = treatmentwm.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatmentwm.guessed_store_county_fips.unique())}.")

treatmentwm['treat'] = True
treatmentwm['purchase_0'] = treatmentwm.purchase_month * (treatmentwm.purchase_year == 2015) + (treatmentwm.purchase_month + 12) * (treatmentwm.purchase_year == 2016)
treatmentwm['opening_0'] = treatmentwm.Opening_date.dt.month * (treatmentwm.Opening_date.dt.year == 2015) + (treatmentwm.Opening_date.dt.month + 12) * (treatmentwm.Opening_date.dt.year == 2016)
treatmentwm['interaction'] = treatmentwm.purchase_0 - treatmentwm.opening_0
treatmentwm = treatmentwm[abs(treatmentwm.interaction) <=5]
treatmentwm['time_fixed_effects'] = list(zip(treatmentwm.purchase_month, treatmentwm.purchase_year))

hohowm = treatmentwm.groupby('interaction').mean()
# Out:
# Size of the treatment group: 81.

# %%
huhu = treatmentwm.loc[treatmentwm.index.repeat(treatmentwm.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
hihi = treatment.loc[treatment.index.repeat(treatment.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()

# %%
plt.plot(hohowm.index, hohowm.price_per_gal, '-+', color='green', label='WM')
plt.plot(huhu.index, huhu.price_per_gal, '-+', color='lightgreen', label='WM')
plt.plot(hoho.index, hoho.price_per_gal, '-+', color='red', label='others')
plt.plot(hihi.index, hihi.price_per_gal, '-+', color='pink', label='others')
plt.title('Milk price evolution before and after a WM entry')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Milk price ($/gal)')
#plt.ylim((0,6))
plt.vlines(0, 0, 6, linestyles='-.');

# %%
plt.figure(figsize=(20,10))
#plt.plot(hohowm.index, hohowm.price_per_gal, '-+', color='green', label='WM')
plt.plot(huhu.index, huhu.price_per_gal, '-+', color='lightgreen', label='WM')
#plt.plot(hoho.index, hoho.price_per_gal, '-+', color='red', label='others')
plt.title('Milk price evolution before and after a WM entry')
plt.plot(hihi.index, hihi.price_per_gal, '-+', color='pink', label='others')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Milk price ($/gal)')
plt.ylim((4.5,6))
plt.vlines(0, 0, 6, linestyles='-.');

# %%
plt.figure(figsize=(20,10))
#plt.errorbar(hohowm.index, hohowm.price_per_gal, yerr=hohowm.price_per_gal.std(), color='green', label='WM', capsize=3)
plt.errorbar(huhu.index, huhu.price_per_gal, yerr=huhu.price_per_gal.std(), color='lightgreen', label='WM', capsize=3)
#plt.errorbar(hoho.index, hoho.price_per_gal, yerr=hoho.price_per_gal.std(), color='red', label='others', capsize=3)
plt.errorbar(hihi.index, hihi.price_per_gal, yerr=hihi.price_per_gal.std(), color='pink', label='others', capsize=3)
plt.title('Milk price evolution before and after a WM entry')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Milk price ($/gal)')
plt.ylim((4.5,6))
plt.vlines(0, 0, 6, linestyles='-.');

# %%
plt.plot(hoho.index, (hoho.price_per_gal-hoho.price_per_gal.iloc[1])/hoho.price_per_gal.iloc[1], '-+', color='red')
plt.plot(np.linspace(-4.5, 4.5, 2), [0, 0] , '--', color='grey')
plt.title('Milk price evolution before and after a WM entry')
plt.xlabel('Months before/after the entry')
plt.ylabel('Milk price ($/gal)')
plt.xlim((-4.5, 4.5))
plt.ylim((-0.1,0.1))
plt.vlines(0, -0.1, 0.1, linestyles='-.');
