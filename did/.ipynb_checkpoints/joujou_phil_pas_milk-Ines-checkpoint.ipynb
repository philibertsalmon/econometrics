# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016
nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]
density_path = r"C:\Users\inesn\Documents\Mines\2A\TR\econometrics\data_collection\plein_de_data\Average_Household_Size_and_Population_Density_-_County.csv"
density = pd.read_csv(density_path)
density = density[["GEOID", "B01001_calc_PopDensity"]]
nielsen = pd.merge(nielsen, density,  how='inner', left_on='guessed_store_county_fips', right_on='GEOID')

## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
movements['year'] = movements.Opening_date.dt.year
movements['month'] = movements.Opening_date.dt.month

nielsen.groupby('product_group_descr').count().sort_values('upc_price', ascending=False).head(20)
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_4932\479141500.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movements['year'] = movements.Opening_date.dt.year
# C:\Users\inesn\AppData\Local\Temp\ipykernel_4932\479141500.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movements['month'] = movements.Opening_date.dt.month
#                                   is_walmart  store_state  \
# product_group_descr
# FRESH PRODUCE                          42329        42329
# BREAD AND BAKED GOODS                  41725        41725
# MILK                                   40079        40079
# SNACKS                                 39978        39978
# PACKAGED MEATS-DELI                    39929        39929
# CHEESE                                 39595        39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN       39240        39240
# CARBONATED BEVERAGES                   37764        37764
# CONDIMENTS, GRAVIES, AND SAUCES        37701        37701
# DRESSINGS/SALADS/PREP FOODS-DELI       37008        37008
# CANDY                                  35877        35877
# JUICE, DRINKS - CANNED, BOTTLED        35694        35694
# EGGS                                   35616        35616
# VEGETABLES - CANNED                    35279        35279
# ICE CREAM, NOVELTIES                   34590        34590
# CEREAL                                 34333        34333
# VEGETABLES-FROZEN                      34296        34296
# PREPARED FOOD-DRY MIXES                34035        34035
# PAPER PRODUCTS                         33956        33956
# PREPARED FOODS-FROZEN                  33906        33906
#
#                                   guessed_store_county  \
# product_group_descr
# FRESH PRODUCE                                    42329
# BREAD AND BAKED GOODS                            41725
# MILK                                             40079
# SNACKS                                           39978
# PACKAGED MEATS-DELI                              39929
# CHEESE                                           39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN                 39240
# CARBONATED BEVERAGES                             37764
# CONDIMENTS, GRAVIES, AND SAUCES                  37701
# DRESSINGS/SALADS/PREP FOODS-DELI                 37008
# CANDY                                            35877
# JUICE, DRINKS - CANNED, BOTTLED                  35694
# EGGS                                             35616
# VEGETABLES - CANNED                              35279
# ICE CREAM, NOVELTIES                             34590
# CEREAL                                           34333
# VEGETABLES-FROZEN                                34296
# PREPARED FOOD-DRY MIXES                          34035
# PAPER PRODUCTS                                   33956
# PREPARED FOODS-FROZEN                            33906
#
#                                   guessed_store_county_fips  purchase_year  \
# product_group_descr
# FRESH PRODUCE                                         42329          42329
# BREAD AND BAKED GOODS                                 41725          41725
# MILK                                                  40079          40079
# SNACKS                                                39978          39978
# PACKAGED MEATS-DELI                                   39929          39929
# CHEESE                                                39595          39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN                      39240          39240
# CARBONATED BEVERAGES                                  37764          37764
# CONDIMENTS, GRAVIES, AND SAUCES                       37701          37701
# DRESSINGS/SALADS/PREP FOODS-DELI                      37008          37008
# CANDY                                                 35877          35877
# JUICE, DRINKS - CANNED, BOTTLED                       35694          35694
# EGGS                                                  35616          35616
# VEGETABLES - CANNED                                   35279          35279
# ICE CREAM, NOVELTIES                                  34590          34590
# CEREAL                                                34333          34333
# VEGETABLES-FROZEN                                     34296          34296
# PREPARED FOOD-DRY MIXES                               34035          34035
# PAPER PRODUCTS                                        33956          33956
# PREPARED FOODS-FROZEN                                 33906          33906
#
#                                   purchase_month  upc_price  upc_price_std  \
# product_group_descr
# FRESH PRODUCE                              42329      42329          40500
# BREAD AND BAKED GOODS                      41725      41725          38980
# MILK                                       40079      40079          36097
# SNACKS                                     39978      39978          36697
# PACKAGED MEATS-DELI                        39929      39929          36608
# CHEESE                                     39595      39595          36234
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN           39240      39240          36505
# CARBONATED BEVERAGES                       37764      37764          33777
# CONDIMENTS, GRAVIES, AND SAUCES            37701      37701          33389
# DRESSINGS/SALADS/PREP FOODS-DELI           37008      37008          32648
# CANDY                                      35877      35877          31653
# JUICE, DRINKS - CANNED, BOTTLED            35694      35694          31029
# EGGS                                       35616      35616          29230
# VEGETABLES - CANNED                        35279      35279          31325
# ICE CREAM, NOVELTIES                       34590      34590          29502
# CEREAL                                     34333      34333          30045
# VEGETABLES-FROZEN                          34296      34296          29332
# PREPARED FOOD-DRY MIXES                    34035      34035          29041
# PAPER PRODUCTS                             33956      33956          28978
# PREPARED FOODS-FROZEN                      33906      33906          29665
#
#                                   nb_of_obs   year  GEOID  \
# product_group_descr
# FRESH PRODUCE                         42329  42329  42329
# BREAD AND BAKED GOODS                 41725  41725  41725
# MILK                                  40079  40079  40079
# SNACKS                                39978  39978  39978
# PACKAGED MEATS-DELI                   39929  39929  39929
# CHEESE                                39595  39595  39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN      39240  39240  39240
# CARBONATED BEVERAGES                  37764  37764  37764
# CONDIMENTS, GRAVIES, AND SAUCES       37701  37701  37701
# DRESSINGS/SALADS/PREP FOODS-DELI      37008  37008  37008
# CANDY                                 35877  35877  35877
# JUICE, DRINKS - CANNED, BOTTLED       35694  35694  35694
# EGGS                                  35616  35616  35616
# VEGETABLES - CANNED                   35279  35279  35279
# ICE CREAM, NOVELTIES                  34590  34590  34590
# CEREAL                                34333  34333  34333
# VEGETABLES-FROZEN                     34296  34296  34296
# PREPARED FOOD-DRY MIXES               34035  34035  34035
# PAPER PRODUCTS                        33956  33956  33956
# PREPARED FOODS-FROZEN                 33906  33906  33906
#
#                                   B01001_calc_PopDensity
# product_group_descr
# FRESH PRODUCE                                      42329
# BREAD AND BAKED GOODS                              41725
# MILK                                               40079
# SNACKS                                             39978
# PACKAGED MEATS-DELI                                39929
# CHEESE                                             39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN                   39240
# CARBONATED BEVERAGES                               37764
# CONDIMENTS, GRAVIES, AND SAUCES                    37701
# DRESSINGS/SALADS/PREP FOODS-DELI                   37008
# CANDY                                              35877
# JUICE, DRINKS - CANNED, BOTTLED                    35694
# EGGS                                               35616
# VEGETABLES - CANNED                                35279
# ICE CREAM, NOVELTIES                               34590
# CEREAL                                             34333
# VEGETABLES-FROZEN                                  34296
# PREPARED FOOD-DRY MIXES                            34035
# PAPER PRODUCTS                                     33956
# PREPARED FOODS-FROZEN                              33906

# %% [markdown]
# ## FRESH PRODUCE

# %% [markdown]
# ## THIRD MODEL : adding entity effects

# %%
# We choose to focus on fresh produce
category = 'FRESH PRODUCE'
product_group = nielsen[nielsen.product_group_descr == category]


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = 0
control['time_fixed_effects'] = list(zip(control.purchase_month, control.purchase_year))

treatment['treat'] = True
treatment['purchase_0'] = treatment.purchase_month * (treatment.purchase_year == 2015) + (treatment.purchase_month +12) * (treatment.purchase_year == 2016)
treatment['opening_0'] = treatment.Opening_date.dt.month * (treatment.Opening_date.dt.year == 2015) + (treatment.Opening_date.dt.month +12) * (treatment.Opening_date.dt.year == 2016)
treatment['interaction'] = treatment.purchase_0 - treatment.opening_0
treatment = treatment[abs(treatment.interaction-2) <=9]
treatment['time_fixed_effects'] = list(zip(treatment.purchase_month, treatment.purchase_year))
# Out:
# Size of the control group: 1831.
# Size of the treatment group: 89.

# %% [markdown]
# ### Low density regression

# %%
# Final dataset for the regression :
treatment_ld = treatment[(treatment.B01001_calc_PopDensity<=300)&(treatment.B01001_calc_PopDensity>=200)]
control_ld = control[(control.B01001_calc_PopDensity<=300)&(control.B01001_calc_PopDensity>=200)]

print(f"Size of the control group: {len(control_ld.guessed_store_county_fips.unique())}.")
print(f"Size of the treatment group: {len(treatment_ld.guessed_store_county_fips.unique())}.")
# .guessed_store_county_fips.unique()

df = pd.concat((control_ld, treatment_ld))[['upc_price', 'treat', 'interaction', 'time_fixed_effects',
                                            'store_state', "B01001_calc_PopDensity"]]
df = df[df.upc_price != 0]
# Out:
# Size of the control group: 41.
# Size of the treatment group: 6.

# %%
wm15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
wm16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
wm15['year'] = 2015
wm16['year'] = 2016
wm = pd.concat((wm15, wm16))
wm = wm[wm.is_walmart]
wm = pd.merge(wm, density,  how='inner', left_on='guessed_store_county_fips', right_on='GEOID')


## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes still remain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
wm = wm[~np.isin(wm.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]


# We choose to focus on milk prices
product_groupwm = wm[wm.product_group_descr == category]

# The control group is composed by all states where nothing (no entry nor exit) happened.
controlwm = product_groupwm[~np.isin(product_groupwm.guessed_store_county_fips, movements)].copy()


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatmentwm = product_groupwm[np.isin(product_groupwm.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatmentwm = treatmentwm.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')


treatmentwm['treat'] = True
treatmentwm['purchase_0'] = treatmentwm.purchase_month * (treatmentwm.purchase_year == 2015) + (treatmentwm.purchase_month + 12) * (treatmentwm.purchase_year == 2016)
treatmentwm['opening_0'] = treatmentwm.Opening_date.dt.month * (treatmentwm.Opening_date.dt.year == 2015) + (treatmentwm.Opening_date.dt.month + 12) * (treatmentwm.Opening_date.dt.year == 2016)
treatmentwm['interaction'] = treatmentwm.purchase_0 - treatmentwm.opening_0
treatmentwm = treatmentwm[abs(treatmentwm.interaction-2) <=9]
treatmentwm['time_fixed_effects'] = list(zip(treatmentwm.purchase_month, treatmentwm.purchase_year))

print(f"Size of the control group: {len(controlwm.guessed_store_county_fips.unique())}.")
print(f"Size of the treatment group: {len(treatmentwm.guessed_store_county_fips.unique())}.")

treatmentwm_ld = treatmentwm[(treatmentwm.B01001_calc_PopDensity<=300)&(treatmentwm.B01001_calc_PopDensity>=200)]
controlwm_ld = controlwm[(controlwm.B01001_calc_PopDensity<=300)&(controlwm.B01001_calc_PopDensity>=200)]
print(f"Size of the control group: {len(controlwm_ld.guessed_store_county_fips.unique())}.")
print(f"Size of the treatment group: {len(treatmentwm_ld.guessed_store_county_fips.unique())}.")
dfwm = pd.concat((controlwm_ld, treatmentwm_ld))[['upc_price', 'treat', 'interaction', 'time_fixed_effects', 'store_state', "B01001_calc_PopDensity"]]
dfwm = dfwm[dfwm.upc_price != 0]
# Out:
# Size of the control group: 1182.
# Size of the treatment group: 81.
# Size of the control group: 40.
# Size of the treatment group: 6.

# %%
huhu = treatmentwm_ld.loc[treatmentwm_ld.index.repeat(treatmentwm_ld.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
hihi = treatment_ld.loc[treatment_ld.index.repeat(treatment_ld.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_4932\3593605051.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   huhu = treatmentwm_ld.loc[treatmentwm_ld.index.repeat(treatmentwm_ld.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
# C:\Users\inesn\AppData\Local\Temp\ipykernel_4932\3593605051.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hihi = treatment_ld.loc[treatment_ld.index.repeat(treatment_ld.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()

# %%
treatment_ld.loc[treatment_ld.index.repeat(treatment_ld.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby("interaction").count()
# Out:
#              is_walmart  store_state  guessed_store_county  \
# interaction
# -7                 2762         2762                  2762
# -6                 3302         3302                  3302
# -5                 3315         3315                  3315
# -4                 3196         3196                  3196
# -3                 3097         3097                  3097
# -2                 3135         3135                  3135
# -1                 2982         2982                  2982
#  0                 3099         3099                  3099
#  1                 3086         3086                  3086
#  2                 3272         3272                  3272
#  3                 3152         3152                  3152
#  4                 3283         3283                  3283
#  5                 3169         3169                  3169
#  6                 3486         3486                  3486
#  7                 3262         3262                  3262
#  8                 3219         3219                  3219
#  9                 3123         3123                  3123
#  10                2820         2820                  2820
#  11                2722         2722                  2722
#
#              guessed_store_county_fips  purchase_year  purchase_month  \
# interaction
# -7                                2762           2762            2762
# -6                                3302           3302            3302
# -5                                3315           3315            3315
# -4                                3196           3196            3196
# -3                                3097           3097            3097
# -2                                3135           3135            3135
# -1                                2982           2982            2982
#  0                                3099           3099            3099
#  1                                3086           3086            3086
#  2                                3272           3272            3272
#  3                                3152           3152            3152
#  4                                3283           3283            3283
#  5                                3169           3169            3169
#  6                                3486           3486            3486
#  7                                3262           3262            3262
#  8                                3219           3219            3219
#  9                                3123           3123            3123
#  10                               2820           2820            2820
#  11                               2722           2722            2722
#
#              product_group_descr  upc_price  upc_price_std  year  ...  \
# interaction                                                       ...
# -7                          2762       2762           2762  2762  ...
# -6                          3302       3302           3302  3302  ...
# -5                          3315       3315           3315  3315  ...
# -4                          3196       3196           3196  3196  ...
# -3                          3097       3097           3097  3097  ...
# -2                          3135       3135           3135  3135  ...
# -1                          2982       2982           2982  2982  ...
#  0                          3099       3099           3099  3099  ...
#  1                          3086       3086           3086  3086  ...
#  2                          3272       3272           3272  3272  ...
#  3                          3152       3152           3152  3152  ...
#  4                          3283       3283           3283  3283  ...
#  5                          3169       3169           3169  3169  ...
#  6                          3486       3486           3486  3486  ...
#  7                          3262       3262           3262  3262  ...
#  8                          3219       3219           3219  3219  ...
#  9                          3123       3123           3123  3123  ...
#  10                         2820       2820           2820  2820  ...
#  11                         2722       2722           2722  2722  ...
#
#              B01001_calc_PopDensity  State  County_name  County_fips  \
# interaction
# -7                             2762   2762         2762         2762
# -6                             3302   3302         3302         3302
# -5                             3315   3315         3315         3315
# -4                             3196   3196         3196         3196
# -3                             3097   3097         3097         3097
# -2                             3135   3135         3135         3135
# -1                             2982   2982         2982         2982
#  0                             3099   3099         3099         3099
#  1                             3086   3086         3086         3086
#  2                             3272   3272         3272         3272
#  3                             3152   3152         3152         3152
#  4                             3283   3283         3283         3283
#  5                             3169   3169         3169         3169
#  6                             3486   3486         3486         3486
#  7                             3262   3262         3262         3262
#  8                             3219   3219         3219         3219
#  9                             3123   3123         3123         3123
#  10                            2820   2820         2820         2820
#  11                            2722   2722         2722         2722
#
#              Opening_date  Closing_date  treat  purchase_0  opening_0  \
# interaction
# -7                   2762             0   2762        2762       2762
# -6                   3302             0   3302        3302       3302
# -5                   3315             0   3315        3315       3315
# -4                   3196             0   3196        3196       3196
# -3                   3097             0   3097        3097       3097
# -2                   3135             0   3135        3135       3135
# -1                   2982             0   2982        2982       2982
#  0                   3099             0   3099        3099       3099
#  1                   3086             0   3086        3086       3086
#  2                   3272             0   3272        3272       3272
#  3                   3152             0   3152        3152       3152
#  4                   3283             0   3283        3283       3283
#  5                   3169             0   3169        3169       3169
#  6                   3486             0   3486        3486       3486
#  7                   3262             0   3262        3262       3262
#  8                   3219             0   3219        3219       3219
#  9                   3123             0   3123        3123       3123
#  10                  2820             0   2820        2820       2820
#  11                  2722             0   2722        2722       2722
#
#              time_fixed_effects
# interaction
# -7                         2762
# -6                         3302
# -5                         3315
# -4                         3196
# -3                         3097
# -2                         3135
# -1                         2982
#  0                         3099
#  1                         3086
#  2                         3272
#  3                         3152
#  4                         3283
#  5                         3169
#  6                         3486
#  7                         3262
#  8                         3219
#  9                         3123
#  10                        2820
#  11                        2722
#
# [19 rows x 21 columns]

# %%
plt.figure(figsize=(20,10))
#plt.plot(hohowm.index, hohowm.upc_price, '-+', color='green', label='WM')
plt.plot(huhu.index, huhu.upc_price, '-+', color='lightgreen', label='WM')
#plt.plot(hoho.index, hoho.upc_price, '-+', color='red', label='others')
plt.title('Fresh produce price evolution before/after a WM entry (200-300 p/km^2 counties)')
plt.plot(hihi.index, hihi.upc_price, '-+', color='pink', label='others')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Average price of items ($)')
plt.vlines(0, 2, 2.3, linestyles='-.');
plt.savefig("../../results_summary/descr_freshp_d=200-300.png")

# %% [markdown]
# Regression model :
# $$ Price_{i, t} = \alpha + \beta \cdot treat_i + \delta \cdot treat_i \cdot post_{t} + \sum_{\tau=Janv15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau) + \sum_{s \in USStates}\gamma_{s} \cdot \mathbb{1}(state = s) + \varepsilon_{i, t}$$

# %%
reg0 = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction)',
    data=df)
results0 = reg0.fit()

reg1 = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects)',
    data=df)
results1 = reg1.fit()

reg2 = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
    data=df)
results2 = reg2.fit()
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(upc_price)   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     2.549
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           1.21e-27
# Time:                        22:35:14   Log-Likelihood:                 1457.8
# No. Observations:                1095   AIC:                            -1890.
# Df Residuals:                     582   BIC:                             674.6
# Df Model:                         512
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    0.5906      0.121      4.901      0.000       0.354       0.827
# treat[T.True]                                                0.0618      0.053      1.162      0.246      -0.043       0.166
# C(interaction)[T.-6]                                         0.0690      0.083      0.834      0.404      -0.093       0.231
# C(interaction)[T.-5]                                         0.0956      0.083      1.156      0.248      -0.067       0.258
# C(interaction)[T.-4]                                         0.1168      0.083      1.412      0.158      -0.046       0.279
# C(interaction)[T.-3]                                         0.0438      0.083      0.530      0.596      -0.119       0.206
# C(interaction)[T.-2]                                         0.1075      0.083      1.300      0.194      -0.055       0.270
# C(interaction)[T.-1]                                         0.1493      0.083      1.805      0.072      -0.013       0.312
# C(interaction)[T.0]                                          0.0734      0.083      0.888      0.375      -0.089       0.236
# C(interaction)[T.1]                                          0.0156      0.083      0.189      0.850      -0.147       0.178
# C(interaction)[T.2]                                          0.0603      0.083      0.729      0.466      -0.102       0.223
# C(interaction)[T.3]                                          0.0363      0.083      0.439      0.661      -0.126       0.199
# C(interaction)[T.4]                                          0.0622      0.083      0.752      0.452      -0.100       0.225
# C(interaction)[T.5]                                          0.0686      0.083      0.829      0.407      -0.094       0.231
# C(interaction)[T.6]                                          0.0937      0.083      1.133      0.258      -0.069       0.256
# C(interaction)[T.7]                                          0.0565      0.083      0.683      0.495      -0.106       0.219
# C(interaction)[T.8]                                          0.0419      0.083      0.507      0.613      -0.121       0.204
# C(interaction)[T.9]                                          0.0431      0.083      0.521      0.602      -0.119       0.206
# C(interaction)[T.10]                                         0.1669      0.088      1.895      0.059      -0.006       0.340
# C(interaction)[T.11]                                         0.0707      0.088      0.803      0.423      -0.102       0.244
# C(time_fixed_effects)[T.(1, 2016)]                           0.0201      0.124      0.162      0.871      -0.223       0.264
# C(time_fixed_effects)[T.(2, 2015)]                           0.0022      0.124      0.018      0.986      -0.241       0.246
# C(time_fixed_effects)[T.(2, 2016)]                           0.0580      0.124      0.468      0.640      -0.185       0.302
# C(time_fixed_effects)[T.(3, 2015)]                          -0.1008      0.124     -0.813      0.417      -0.344       0.143
# C(time_fixed_effects)[T.(3, 2016)]                           0.0238      0.124      0.192      0.848      -0.220       0.267
# C(time_fixed_effects)[T.(4, 2015)]                          -0.0462      0.124     -0.372      0.710      -0.290       0.197
# C(time_fixed_effects)[T.(4, 2016)]                          -0.0223      0.124     -0.180      0.857      -0.266       0.221
# C(time_fixed_effects)[T.(5, 2015)]                           0.0265      0.124      0.214      0.831      -0.217       0.270
# C(time_fixed_effects)[T.(5, 2016)]                           0.0183      0.124      0.148      0.883      -0.225       0.262
# C(time_fixed_effects)[T.(6, 2015)]                           0.1117      0.124      0.901      0.368      -0.132       0.355
# C(time_fixed_effects)[T.(6, 2016)]                           0.0203      0.124      0.164      0.870      -0.223       0.264
# C(time_fixed_effects)[T.(7, 2015)]                           0.0446      0.124      0.359      0.719      -0.199       0.288
# C(time_fixed_effects)[T.(7, 2016)]                           0.0275      0.124      0.222      0.824      -0.216       0.271
# C(time_fixed_effects)[T.(8, 2015)]                           0.0240      0.124      0.194      0.847      -0.219       0.267
# C(time_fixed_effects)[T.(8, 2016)]                          -0.0027      0.124     -0.022      0.982      -0.246       0.241
# C(time_fixed_effects)[T.(9, 2015)]                          -0.0125      0.124     -0.101      0.920      -0.256       0.231
# C(time_fixed_effects)[T.(9, 2016)]                           0.0006      0.124      0.005      0.996      -0.243       0.244
# C(time_fixed_effects)[T.(10, 2015)]                         -0.0688      0.124     -0.555      0.579      -0.312       0.175
# C(time_fixed_effects)[T.(10, 2016)]                         -0.0200      0.124     -0.162      0.872      -0.264       0.223
# C(time_fixed_effects)[T.(11, 2015)]                          0.0068      0.124      0.055      0.956      -0.237       0.250
# C(time_fixed_effects)[T.(11, 2016)]                          0.0093      0.124      0.075      0.940      -0.234       0.253
# C(time_fixed_effects)[T.(12, 2015)]                          0.0274      0.124      0.221      0.825      -0.216       0.271
# C(time_fixed_effects)[T.(12, 2016)]                         -0.0070      0.124     -0.056      0.955      -0.250       0.237
# C(store_state)[T.FL]                                         0.1109      0.107      1.033      0.302      -0.100       0.322
# C(store_state)[T.IL]                                        -0.0189      0.124     -0.153      0.879      -0.262       0.225
# C(store_state)[T.IN]                                         0.0415      0.101      0.410      0.682      -0.157       0.240
# C(store_state)[T.KY]                                         0.0327      0.107      0.304      0.761      -0.178       0.244
# C(store_state)[T.MA]                                         0.1215      0.101      1.200      0.231      -0.077       0.320
# C(store_state)[T.MD]                                         0.1829      0.124      1.475      0.141      -0.061       0.426
# C(store_state)[T.MI]                                         0.0958      0.098      0.978      0.329      -0.097       0.288
# C(store_state)[T.MN]                                         0.0279      0.107      0.260      0.795      -0.183       0.239
# C(store_state)[T.MO]                                         0.0544      0.124      0.438      0.661      -0.189       0.298
# C(store_state)[T.NC]                                         0.0898      0.107      0.836      0.403      -0.121       0.301
# C(store_state)[T.NE]                                         0.0204      0.124      0.165      0.869      -0.223       0.264
# C(store_state)[T.NJ]                                         0.1983      0.124      1.600      0.110      -0.045       0.442
# C(store_state)[T.NM]                                        -0.1021      0.030     -3.459      0.001      -0.160      -0.044
# C(store_state)[T.NY]                                         0.2074      0.101      2.049      0.041       0.009       0.406
# C(store_state)[T.OH]                                         0.0362      0.098      0.369      0.712      -0.156       0.229
# C(store_state)[T.PA]                                         0.2699      0.101      2.667      0.008       0.071       0.469
# C(store_state)[T.SC]                                        -0.0059      0.030     -0.198      0.843      -0.064       0.052
# C(store_state)[T.VA]                                         0.1107      0.097      1.145      0.253      -0.079       0.300
# C(store_state)[T.WA]                                         0.0998      0.124      0.805      0.421      -0.144       0.343
# C(store_state)[T.WI]                                         0.0584      0.107      0.544      0.586      -0.152       0.269
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.FL]      0.0286      0.149      0.192      0.847      -0.263       0.320
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.FL]     -0.0127      0.152     -0.083      0.934      -0.311       0.286
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.FL]     -0.0525      0.149     -0.353      0.724      -0.344       0.239
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.FL]      0.1040      0.152      0.685      0.494      -0.194       0.402
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.FL]      0.0035      0.149      0.024      0.981      -0.288       0.295
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.FL]      0.0733      0.152      0.483      0.629      -0.225       0.372
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.FL]      0.0652      0.149      0.439      0.661      -0.227       0.357
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.FL]      0.0174      0.152      0.114      0.909      -0.281       0.316
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.FL]      0.0305      0.149      0.205      0.837      -0.261       0.322
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.FL]     -0.0541      0.152     -0.356      0.722      -0.352       0.244
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.FL]      0.0180      0.149      0.121      0.904      -0.274       0.310
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.FL]     -0.0109      0.152     -0.072      0.943      -0.309       0.287
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.FL]      0.0104      0.149      0.070      0.944      -0.282       0.302
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.FL]      0.0521      0.149      0.349      0.727      -0.241       0.345
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.FL]      0.0386      0.149      0.260      0.795      -0.253       0.330
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.FL]      0.0405      0.149      0.273      0.785      -0.251       0.332
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.FL]     -0.0126      0.149     -0.085      0.933      -0.304       0.279
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.FL]     0.1039      0.149      0.699      0.485      -0.188       0.396
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.FL]     0.0517      0.149      0.348      0.728      -0.240       0.344
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.FL]     0.0071      0.149      0.048      0.962      -0.285       0.299
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.FL]     0.0175      0.149      0.118      0.906      -0.274       0.309
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.FL]     0.0076      0.149      0.051      0.959      -0.284       0.299
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.FL]     0.0319      0.149      0.214      0.830      -0.260       0.324
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.IL]      0.0168      0.175      0.096      0.924      -0.328       0.361
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.IL]     -0.0142      0.175     -0.081      0.936      -0.359       0.330
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.IL]     -0.0686      0.175     -0.391      0.696      -0.413       0.276
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.IL]      0.1218      0.175      0.695      0.487      -0.223       0.466
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.IL]      0.0339      0.175      0.193      0.847      -0.310       0.378
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.IL]      0.0734      0.175      0.418      0.676      -0.271       0.418
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.IL]      0.0271      0.175      0.154      0.877      -0.317       0.371
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.IL]      0.0603      0.175      0.344      0.731      -0.284       0.405
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.IL]      0.0020      0.175      0.011      0.991      -0.342       0.346
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.IL]     -0.1054      0.175     -0.601      0.548      -0.450       0.239
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.IL]      0.0227      0.175      0.129      0.897      -0.322       0.367
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.IL]      0.0030      0.175      0.017      0.987      -0.341       0.347
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.IL]     -0.0108      0.175     -0.062      0.951      -0.355       0.334
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.IL]     -0.1173      0.175     -0.669      0.504      -0.462       0.227
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.IL]     -0.0159      0.175     -0.091      0.928      -0.360       0.328
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.IL]     -0.0546      0.175     -0.312      0.755      -0.399       0.290
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.IL]     -0.0921      0.175     -0.525      0.600      -0.436       0.252
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.IL]    -0.0449      0.175     -0.256      0.798      -0.389       0.299
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.IL]     0.0106      0.175      0.061      0.952      -0.334       0.355
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.IL]     0.0230      0.175      0.131      0.896      -0.321       0.367
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.IL]     0.0897      0.175      0.512      0.609      -0.255       0.434
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.IL]     0.0787      0.175      0.449      0.654      -0.266       0.423
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.IL]    -0.0299      0.175     -0.171      0.865      -0.374       0.314
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.IN]     -0.0726      0.142     -0.513      0.608      -0.351       0.205
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.IN]      0.0213      0.143      0.149      0.882      -0.260       0.302
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.IN]     -0.0988      0.142     -0.698      0.486      -0.377       0.179
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.IN]      0.0835      0.143      0.583      0.560      -0.198       0.365
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.IN]     -0.0605      0.142     -0.428      0.669      -0.338       0.217
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.IN]     -0.0154      0.143     -0.108      0.914      -0.297       0.266
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.IN]      0.0060      0.142      0.042      0.966      -0.272       0.284
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.IN]     -0.0219      0.143     -0.153      0.879      -0.303       0.259
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.IN]     -0.0146      0.142     -0.103      0.918      -0.293       0.263
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.IN]     -0.1150      0.142     -0.811      0.418      -0.393       0.163
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.IN]     -0.0952      0.142     -0.673      0.501      -0.373       0.183
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.IN]     -0.1360      0.142     -0.961      0.337      -0.414       0.142
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.IN]     -0.1444      0.142     -1.020      0.308      -0.422       0.134
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.IN]     -0.0559      0.142     -0.395      0.693      -0.334       0.222
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.IN]     -0.1098      0.142     -0.776      0.438      -0.388       0.168
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.IN]     -0.0637      0.142     -0.450      0.653      -0.342       0.214
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.IN]     -0.0731      0.142     -0.516      0.606      -0.351       0.205
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.IN]     0.0870      0.142      0.615      0.539      -0.191       0.365
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.IN]    -0.0114      0.142     -0.080      0.936      -0.289       0.267
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.IN]    -0.0603      0.142     -0.426      0.670      -0.338       0.218
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.IN]    -0.0758      0.142     -0.535      0.593      -0.354       0.203
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.IN]    -0.0712      0.142     -0.503      0.615      -0.349       0.207
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.IN]    -0.0474      0.142     -0.334      0.738      -0.326       0.231
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.KY]      0.0712      0.152      0.469      0.639      -0.227       0.369
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.KY]      0.0186      0.152      0.122      0.903      -0.280       0.317
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.KY]      0.0146      0.152      0.096      0.923      -0.284       0.313
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.KY]      0.0565      0.152      0.372      0.710      -0.242       0.355
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.KY]      0.0308      0.152      0.203      0.839      -0.267       0.329
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.KY]     -0.0533      0.152     -0.351      0.726      -0.352       0.245
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.KY]      0.0592      0.152      0.390      0.697      -0.239       0.357
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.KY]      0.0323      0.152      0.213      0.831      -0.266       0.331
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.KY]      0.0111      0.152      0.073      0.942      -0.287       0.309
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.KY]     -0.1771      0.152     -1.166      0.244      -0.475       0.121
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.KY]      0.0025      0.152      0.017      0.987      -0.296       0.301
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.KY]     -0.1532      0.152     -1.009      0.314      -0.451       0.145
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.KY]     -0.0245      0.152     -0.161      0.872      -0.323       0.274
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.KY]     -0.0015      0.152     -0.010      0.992      -0.300       0.297
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.KY]     -0.0824      0.152     -0.543      0.588      -0.381       0.216
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.KY]      0.0194      0.152      0.128      0.898      -0.279       0.318
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.KY]     -0.0219      0.152     -0.144      0.886      -0.320       0.276
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.KY]     0.0458      0.152      0.301      0.763      -0.252       0.344
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.KY]    -0.0207      0.152     -0.136      0.892      -0.319       0.278
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.KY]     0.1100      0.152      0.724      0.469      -0.188       0.408
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.KY]    -0.0362      0.152     -0.239      0.812      -0.334       0.262
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.KY]    -0.0110      0.152     -0.073      0.942      -0.309       0.287
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.KY]     0.0121      0.152      0.080      0.936      -0.286       0.310
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MA]      0.0683      0.143      0.477      0.633      -0.213       0.349
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MA]      0.0423      0.143      0.295      0.768      -0.239       0.323
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MA]      0.0275      0.143      0.192      0.848      -0.254       0.309
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MA]      0.1810      0.143      1.265      0.207      -0.100       0.462
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MA]      0.0674      0.143      0.471      0.638      -0.214       0.349
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.MA]      0.0827      0.143      0.578      0.564      -0.198       0.364
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.MA]      0.0532      0.143      0.371      0.710      -0.228       0.334
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.MA]      0.0119      0.143      0.083      0.934      -0.269       0.293
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.MA]      0.0444      0.143      0.310      0.756      -0.237       0.326
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.MA]     -0.0432      0.143     -0.302      0.763      -0.324       0.238
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.MA]      0.0769      0.143      0.537      0.591      -0.204       0.358
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.MA]      0.0091      0.143      0.064      0.949      -0.272       0.290
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.MA]      0.0969      0.143      0.677      0.499      -0.184       0.378
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.MA]      0.0119      0.143      0.083      0.934      -0.269       0.293
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.MA]      0.1101      0.143      0.769      0.442      -0.171       0.391
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.MA]      0.0472      0.143      0.330      0.742      -0.234       0.328
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.MA]      0.0610      0.143      0.426      0.670      -0.220       0.342
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.MA]     0.1237      0.143      0.864      0.388      -0.157       0.405
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.MA]     0.0730      0.143      0.510      0.610      -0.208       0.354
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.MA]     0.0150      0.143      0.105      0.917      -0.266       0.296
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.MA]     0.0471      0.143      0.329      0.742      -0.234       0.328
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.MA]     0.0365      0.143      0.255      0.799      -0.245       0.318
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.MA]     0.0407      0.143      0.284      0.776      -0.240       0.322
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MD]      0.0684      0.175      0.390      0.696      -0.276       0.413
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MD]     -0.0894      0.175     -0.510      0.610      -0.434       0.255
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MD]      0.1277      0.175      0.728      0.467      -0.217       0.472
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MD]      0.0668      0.175      0.381      0.704      -0.278       0.411
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MD]      0.0122      0.175      0.070      0.945      -0.332       0.357
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.MD]      0.0684      0.175      0.390      0.697      -0.276       0.413
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.MD]      0.0377      0.175      0.215      0.830      -0.307       0.382
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.MD]      0.0636      0.175      0.363      0.717      -0.281       0.408
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.MD]      0.0465      0.175      0.265      0.791      -0.298       0.391
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.MD]     -0.0803      0.175     -0.458      0.647      -0.425       0.264
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.MD]      0.0756      0.175      0.431      0.667      -0.269       0.420
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.MD]     -0.0123      0.175     -0.070      0.944      -0.357       0.332
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.MD]      0.0304      0.175      0.174      0.862      -0.314       0.375
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.MD]     -0.0058      0.175     -0.033      0.974      -0.350       0.339
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.MD]      0.0129      0.175      0.073      0.942      -0.331       0.357
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.MD]     -0.0244      0.175     -0.139      0.889      -0.369       0.320
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.MD]     -0.0568      0.175     -0.324      0.746      -0.401       0.288
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.MD]     0.0041      0.175      0.023      0.982      -0.340       0.348
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.MD]     0.0188      0.175      0.107      0.915      -0.326       0.363
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.MD]    -0.0109      0.175     -0.062      0.950      -0.355       0.333
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.MD]     0.0639      0.175      0.364      0.716      -0.280       0.408
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.MD]    -0.0308      0.175     -0.175      0.861      -0.375       0.314
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.MD]     0.0320      0.175      0.182      0.855      -0.312       0.376
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MI]     -0.0352      0.139     -0.254      0.800      -0.307       0.237
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MI]     -0.0241      0.139     -0.174      0.862      -0.296       0.248
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MI]     -0.0490      0.139     -0.354      0.724      -0.321       0.223
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MI]      0.0323      0.139      0.233      0.816      -0.240       0.305
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MI]     -0.0695      0.139     -0.502      0.616      -0.342       0.203
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.MI]     -0.0006      0.139     -0.004      0.996      -0.273       0.272
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.MI]     -0.0221      0.139     -0.159      0.873      -0.294       0.250
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.MI]     -0.0494      0.139     -0.356      0.722      -0.322       0.223
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.MI]     -0.0402      0.139     -0.290      0.772      -0.312       0.232
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.MI]     -0.1662      0.139     -1.199      0.231      -0.438       0.106
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.MI]      0.0101      0.139      0.073      0.942      -0.262       0.282
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.MI]     -0.0850      0.139     -0.613      0.540      -0.357       0.187
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.MI]     -0.0279      0.139     -0.201      0.841      -0.300       0.244
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.MI]     -0.1076      0.139     -0.777      0.438      -0.380       0.165
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.MI]     -0.0663      0.139     -0.478      0.633      -0.339       0.206
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.MI]     -0.0531      0.139     -0.383      0.702      -0.325       0.219
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.MI]     -0.0665      0.139     -0.480      0.632      -0.339       0.206
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.MI]    -0.0106      0.139     -0.077      0.939      -0.283       0.262
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.MI]    -0.0237      0.139     -0.171      0.864      -0.296       0.248
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.MI]    -0.0195      0.139     -0.140      0.888      -0.292       0.253
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.MI]    -0.0435      0.139     -0.314      0.754      -0.316       0.229
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.MI]    -0.0314      0.139     -0.226      0.821      -0.304       0.241
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.MI]    -0.0234      0.139     -0.169      0.866      -0.296       0.249
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MN]      0.0712      0.152      0.469      0.639      -0.227       0.369
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MN]      0.0649      0.152      0.428      0.669      -0.233       0.363
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MN]      0.0681      0.152      0.449      0.654      -0.230       0.366
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MN]      0.1727      0.152      1.137      0.256      -0.126       0.471
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MN]      0.0790      0.152      0.520      0.603      -0.219       0.377
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.MN]      0.0893      0.152      0.588      0.557      -0.209       0.388
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.MN]      0.1266      0.152      0.834      0.405      -0.172       0.425
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.MN]      0.0952      0.152      0.627      0.531      -0.203       0.393
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.MN]      0.0493      0.152      0.325      0.746      -0.249       0.348
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.MN]      0.0119      0.152      0.078      0.937      -0.286       0.310
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.MN]      0.1411      0.152      0.930      0.353      -0.157       0.439
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.MN]      0.0485      0.152      0.319      0.750      -0.250       0.347
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.MN]      0.1540      0.152      1.015      0.311      -0.144       0.452
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.MN]      0.0585      0.152      0.385      0.700      -0.240       0.357
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.MN]      0.1406      0.152      0.926      0.355      -0.158       0.439
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.MN]      0.0785      0.152      0.517      0.605      -0.220       0.377
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.MN]      0.0890      0.152      0.586      0.558      -0.209       0.387
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.MN]     0.2243      0.152      1.477      0.140      -0.074       0.522
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.MN]     0.1253      0.152      0.825      0.409      -0.173       0.424
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.MN]     0.0757      0.152      0.498      0.618      -0.223       0.374
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.MN]     0.0837      0.152      0.551      0.582      -0.215       0.382
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.MN]     0.1245      0.152      0.820      0.413      -0.174       0.423
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.MN]     0.1339      0.152      0.882      0.378      -0.164       0.432
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MO]      0.0834      0.175      0.476      0.634      -0.261       0.428
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MO]      0.0429      0.175      0.245      0.807      -0.301       0.387
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MO]     -0.0705      0.175     -0.402      0.688      -0.415       0.274
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MO]      0.1035      0.175      0.590      0.555      -0.241       0.448
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MO]      0.0184      0.175      0.105      0.916      -0.326       0.363
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.MO]      0.0202      0.175      0.115      0.908      -0.324       0.365
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.MO]      0.0597      0.175      0.340      0.734      -0.285       0.404
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.MO]     -0.0614      0.175     -0.350      0.727      -0.406       0.283
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.MO]     -0.0019      0.175     -0.011      0.991      -0.346       0.342
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.MO]     -0.1529      0.175     -0.872      0.384      -0.497       0.191
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.MO]     -0.0223      0.175     -0.127      0.899      -0.367       0.322
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.MO]      0.0161      0.175      0.092      0.927      -0.328       0.360
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.MO]     -0.0129      0.175     -0.073      0.942      -0.357       0.331
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.MO]      0.0110      0.175      0.063      0.950      -0.333       0.355
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.MO]      0.0646      0.175      0.369      0.713      -0.280       0.409
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.MO]      0.0752      0.175      0.429      0.668      -0.269       0.420
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.MO]      0.1027      0.175      0.586      0.558      -0.242       0.447
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.MO]     0.1619      0.175      0.924      0.356      -0.182       0.506
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.MO]    -0.0224      0.175     -0.128      0.898      -0.367       0.322
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.MO]     0.1188      0.175      0.678      0.498      -0.226       0.463
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.MO]     0.0209      0.175      0.119      0.905      -0.323       0.365
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.MO]     0.1354      0.175      0.772      0.440      -0.209       0.480
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.MO]     0.0603      0.175      0.344      0.731      -0.284       0.405
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.NC]      0.0258      0.152      0.170      0.865      -0.272       0.324
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.NC]     -0.0662      0.152     -0.436      0.663      -0.364       0.232
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.NC]      0.0008      0.152      0.005      0.996      -0.297       0.299
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.NC]      0.0471      0.152      0.310      0.757      -0.251       0.345
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.NC]     -0.0405      0.152     -0.266      0.790      -0.339       0.258
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.NC]     -0.0843      0.152     -0.555      0.579      -0.382       0.214
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.NC]      0.0165      0.152      0.109      0.913      -0.282       0.315
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.NC]     -0.0552      0.152     -0.364      0.716      -0.353       0.243
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.NC]     -0.0035      0.152     -0.023      0.981      -0.302       0.295
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.NC]     -0.1678      0.152     -1.105      0.270      -0.466       0.130
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.NC]     -0.0460      0.152     -0.303      0.762      -0.344       0.252
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.NC]     -0.0650      0.152     -0.428      0.669      -0.363       0.233
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.NC]     -0.0030      0.152     -0.020      0.984      -0.301       0.295
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.NC]     -0.0708      0.152     -0.467      0.641      -0.369       0.227
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.NC]      0.0660      0.152      0.435      0.664      -0.232       0.364
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.NC]     -0.0090      0.152     -0.060      0.953      -0.307       0.289
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.NC]      0.0213      0.152      0.140      0.889      -0.277       0.319
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.NC]    -0.0071      0.152     -0.047      0.962      -0.305       0.291
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.NC]    -0.0053      0.152     -0.035      0.972      -0.304       0.293
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.NC]    -0.0292      0.152     -0.192      0.848      -0.327       0.269
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.NC]    -0.0768      0.152     -0.506      0.613      -0.375       0.221
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.NC]    -0.0505      0.152     -0.333      0.739      -0.349       0.248
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.NC]    -0.0367      0.152     -0.242      0.809      -0.335       0.262
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.NE]     -0.1498      0.175     -0.854      0.393      -0.494       0.195
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.NE]     -0.0254      0.175     -0.145      0.885      -0.370       0.319
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.NE]      0.0364      0.175      0.207      0.836      -0.308       0.381
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.NE]     -0.0043      0.175     -0.025      0.980      -0.349       0.340
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.NE]      0.1132      0.175      0.646      0.519      -0.231       0.458
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.NE]     -0.1302      0.175     -0.742      0.458      -0.474       0.214
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.NE]      0.0937      0.175      0.534      0.593      -0.251       0.438
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.NE]     -0.1604      0.175     -0.915      0.361      -0.505       0.184
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.NE]      0.0566      0.175      0.323      0.747      -0.288       0.401
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.NE]      0.0335      0.175      0.191      0.849      -0.311       0.378
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.NE]      0.0626      0.175      0.357      0.721      -0.282       0.407
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.NE]     -0.1021      0.175     -0.582      0.561      -0.446       0.242
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.NE]     -0.0894      0.175     -0.510      0.611      -0.434       0.255
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.NE]     -0.0951      0.175     -0.542      0.588      -0.439       0.249
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.NE]     -0.0507      0.175     -0.289      0.773      -0.395       0.294
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.NE]     -0.0469      0.175     -0.267      0.789      -0.391       0.297
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.NE]     -0.1220      0.175     -0.696      0.487      -0.466       0.222
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.NE]     0.0653      0.175      0.373      0.710      -0.279       0.410
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.NE]    -0.0177      0.175     -0.101      0.920      -0.362       0.327
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.NE]    -0.0779      0.175     -0.444      0.657      -0.422       0.266
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.NE]    -0.0102      0.175     -0.058      0.954      -0.355       0.334
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.NE]     0.2096      0.175      1.195      0.232      -0.135       0.554
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.NE]    -0.0398      0.175     -0.227      0.821      -0.384       0.305
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.NJ]      0.0392      0.175      0.224      0.823      -0.305       0.384
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.NJ]     -0.0214      0.175     -0.122      0.903      -0.366       0.323
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.NJ]     -0.0039      0.175     -0.022      0.982      -0.348       0.340
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.NJ]      0.1018      0.175      0.581      0.562      -0.243       0.446
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.NJ]     -0.0048      0.175     -0.027      0.978      -0.349       0.340
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.NJ]      0.0300      0.175      0.171      0.864      -0.314       0.374
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.NJ]      0.0073      0.175      0.042      0.967      -0.337       0.352
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.NJ]      0.0585      0.175      0.334      0.739      -0.286       0.403
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.NJ]      0.0446      0.175      0.254      0.799      -0.300       0.389
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.NJ]     -0.0622      0.175     -0.355      0.723      -0.407       0.282
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.NJ]      0.0798      0.175      0.455      0.649      -0.265       0.424
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.NJ]     -0.0299      0.175     -0.170      0.865      -0.374       0.314
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.NJ]      0.0425      0.175      0.243      0.808      -0.302       0.387
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.NJ]     -0.0521      0.175     -0.297      0.766      -0.396       0.292
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.NJ]      0.0786      0.175      0.448      0.654      -0.266       0.423
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.NJ]      0.0497      0.175      0.283      0.777      -0.295       0.394
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.NJ]     -0.0015      0.175     -0.008      0.993      -0.346       0.343
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.NJ]     0.0879      0.175      0.501      0.616      -0.256       0.432
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.NJ]     0.1221      0.175      0.696      0.487      -0.222       0.466
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.NJ]    -0.0353      0.175     -0.201      0.841      -0.380       0.309
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.NJ]     0.0854      0.175      0.487      0.626      -0.259       0.430
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.NJ]     0.0752      0.175      0.429      0.668      -0.269       0.420
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.NJ]     0.1473      0.175      0.840      0.401      -0.197       0.492
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.NM]     -0.0026      0.131     -0.020      0.984      -0.261       0.255
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.NM]  -3.105e-17   1.18e-16     -0.263      0.793   -2.63e-16    2.01e-16
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.NM]     -0.0002      0.131     -0.002      0.998      -0.258       0.258
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.NM]   1.876e-17   8.44e-17      0.222      0.824   -1.47e-16    1.85e-16
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.NM]     -0.0066      0.131     -0.050      0.960      -0.265       0.251
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.NM]   3.106e-17   1.08e-16      0.288      0.774   -1.81e-16    2.43e-16
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.NM]      0.0667      0.131      0.508      0.612      -0.191       0.325
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.NM]  -6.818e-17   9.25e-17     -0.737      0.461    -2.5e-16    1.14e-16
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.NM]      0.0239      0.131      0.182      0.856      -0.234       0.282
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.NM]     -0.0665      0.135     -0.491      0.623      -0.332       0.199
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.NM]      0.0505      0.131      0.384      0.701      -0.207       0.308
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.NM]     -0.0459      0.131     -0.349      0.727      -0.304       0.212
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.NM]      0.0061      0.131      0.047      0.963      -0.252       0.264
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.NM]     -0.0969      0.131     -0.738      0.461      -0.355       0.161
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.NM]      0.0420      0.131      0.320      0.749      -0.216       0.300
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.NM]     -0.1166      0.131     -0.888      0.375      -0.375       0.141
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.NM]      0.0702      0.131      0.534      0.593      -0.188       0.328
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.NM]     0.1144      0.131      0.871      0.384      -0.144       0.372
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.NM]     0.0831      0.131      0.633      0.527      -0.175       0.341
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.NM]    -0.0780      0.131     -0.594      0.553      -0.336       0.180
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.NM]    -0.1304      0.134     -0.970      0.333      -0.394       0.134
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.NM]    -0.1165      0.131     -0.887      0.375      -0.374       0.141
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.NM]     0.1011      0.134      0.752      0.452      -0.163       0.365
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.NY]      0.0538      0.143      0.376      0.707      -0.227       0.335
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.NY]     -0.0374      0.143     -0.261      0.794      -0.319       0.244
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.NY]     -0.0145      0.143     -0.101      0.919      -0.296       0.267
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.NY]      0.0752      0.143      0.525      0.600      -0.206       0.356
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.NY]      0.0005      0.143      0.003      0.997      -0.281       0.282
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.NY]      0.0037      0.143      0.026      0.979      -0.277       0.285
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.NY]      0.0092      0.143      0.064      0.949      -0.272       0.290
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.NY]      0.0175      0.143      0.123      0.902      -0.264       0.299
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.NY]      0.0219      0.143      0.153      0.879      -0.259       0.303
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.NY]     -0.0878      0.143     -0.614      0.540      -0.369       0.193
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.NY]      0.0216      0.143      0.151      0.880      -0.260       0.303
# ...
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.OH]     -0.0013      0.139     -0.010      0.992      -0.274       0.271
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.OH]     0.1037      0.139      0.749      0.454      -0.168       0.376
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.OH]    -0.0188      0.139     -0.135      0.892      -0.291       0.253
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.OH]     0.0644      0.139      0.465      0.642      -0.208       0.337
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.OH]    -0.0282      0.139     -0.203      0.839      -0.300       0.244
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.OH]    -0.0016      0.139     -0.012      0.991      -0.274       0.271
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.OH]     0.0403      0.139      0.291      0.771      -0.232       0.313
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.PA]      0.0593      0.143      0.415      0.679      -0.222       0.341
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.PA]      0.0035      0.143      0.024      0.981      -0.278       0.285
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.PA]     -0.0217      0.143     -0.152      0.879      -0.303       0.259
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.PA]      0.0932      0.143      0.651      0.515      -0.188       0.374
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.PA]      0.0123      0.143      0.086      0.931      -0.269       0.294
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.PA]      0.0799      0.143      0.558      0.577      -0.201       0.361
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.PA]      0.0419      0.143      0.293      0.770      -0.239       0.323
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.PA]     -0.0326      0.143     -0.228      0.820      -0.314       0.249
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.PA]      0.0278      0.143      0.194      0.846      -0.253       0.309
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.PA]     -0.0870      0.143     -0.608      0.543      -0.368       0.194
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.PA]      0.0347      0.143      0.242      0.809      -0.246       0.316
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.PA]     -0.0093      0.143     -0.065      0.948      -0.291       0.272
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.PA]      0.0181      0.143      0.126      0.900      -0.263       0.299
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.PA]     -0.0200      0.143     -0.140      0.889      -0.301       0.261
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.PA]      0.0201      0.143      0.140      0.889      -0.261       0.301
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.PA]      0.0675      0.143      0.471      0.638      -0.214       0.349
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.PA]      0.0053      0.143      0.037      0.970      -0.276       0.286
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.PA]     0.1002      0.143      0.700      0.484      -0.181       0.381
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.PA]     0.0143      0.143      0.100      0.921      -0.267       0.295
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.PA]     0.0329      0.143      0.230      0.818      -0.248       0.314
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.PA]     0.0214      0.143      0.150      0.881      -0.260       0.303
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.PA]     0.0250      0.143      0.175      0.861      -0.256       0.306
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.PA]     0.0547      0.143      0.382      0.702      -0.226       0.336
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.SC]      0.0054      0.131      0.041      0.967      -0.253       0.263
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.SC]    1.88e-18    1.2e-16      0.016      0.987   -2.33e-16    2.37e-16
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.SC]     -0.0321      0.131     -0.244      0.807      -0.290       0.226
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.SC]   4.793e-17   1.15e-16      0.417      0.676   -1.78e-16    2.73e-16
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.SC]     -0.0448      0.131     -0.341      0.733      -0.303       0.213
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.SC]   7.833e-17   9.05e-17      0.866      0.387   -9.93e-17    2.56e-16
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.SC]      0.1141      0.131      0.869      0.385      -0.144       0.372
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.SC]   2.845e-17   9.59e-17      0.297      0.767    -1.6e-16    2.17e-16
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.SC]      0.0174      0.131      0.132      0.895      -0.241       0.275
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.SC]     -0.0250      0.135     -0.185      0.854      -0.291       0.241
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.SC]      0.0194      0.131      0.148      0.883      -0.239       0.277
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.SC]     -0.0149      0.131     -0.113      0.910      -0.273       0.243
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.SC]     -0.0185      0.131     -0.141      0.888      -0.276       0.239
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.SC]     -0.0476      0.131     -0.363      0.717      -0.306       0.210
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.SC]      0.0548      0.131      0.417      0.677      -0.203       0.313
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.SC]      0.0145      0.131      0.111      0.912      -0.243       0.272
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.SC]      0.0592      0.131      0.451      0.652      -0.199       0.317
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.SC]     0.0751      0.131      0.572      0.568      -0.183       0.333
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.SC]     0.1136      0.131      0.865      0.387      -0.144       0.372
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.SC]    -0.0054      0.131     -0.041      0.967      -0.263       0.253
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.SC]    -0.1386      0.134     -1.031      0.303      -0.403       0.125
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.SC]    -0.1914      0.131     -1.457      0.146      -0.449       0.067
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.SC]     0.0388      0.134      0.289      0.773      -0.225       0.303
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.VA]      0.0064      0.137      0.047      0.962      -0.262       0.275
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.VA]      0.0290      0.137      0.212      0.832      -0.239       0.297
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.VA]     -0.0124      0.137     -0.091      0.928      -0.281       0.256
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.VA]      0.1485      0.137      1.087      0.277      -0.120       0.417
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.VA]      0.0120      0.137      0.088      0.930      -0.256       0.280
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.VA]      0.0960      0.137      0.702      0.483      -0.172       0.364
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.VA]      0.0385      0.137      0.282      0.778      -0.230       0.307
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.VA]      0.0031      0.137      0.022      0.982      -0.265       0.271
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.VA]      0.0384      0.137      0.281      0.779      -0.230       0.307
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.VA]     -0.0427      0.137     -0.313      0.755      -0.311       0.226
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.VA]      0.0899      0.137      0.658      0.511      -0.179       0.359
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.VA]      0.0598      0.137      0.438      0.662      -0.209       0.328
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.VA]      0.0548      0.138      0.398      0.690      -0.215       0.325
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.VA]      0.0309      0.137      0.226      0.821      -0.237       0.299
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.VA]      0.0311      0.138      0.226      0.822      -0.239       0.301
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.VA]      0.0481      0.137      0.352      0.725      -0.220       0.316
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.VA]      0.0502      0.138      0.365      0.716      -0.220       0.320
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.VA]     0.1045      0.137      0.765      0.445      -0.164       0.373
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.VA]     0.0253      0.138      0.184      0.854      -0.245       0.296
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.VA]    -0.0064      0.137     -0.047      0.963      -0.275       0.262
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.VA]     0.0484      0.138      0.352      0.725      -0.222       0.319
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.VA]     0.0072      0.137      0.053      0.958      -0.261       0.276
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.VA]     0.0050      0.138      0.036      0.971      -0.265       0.275
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.WA]     -0.0052      0.166     -0.031      0.975      -0.332       0.321
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.WA]     -0.0339      0.167     -0.203      0.839      -0.362       0.294
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.WA]     -0.0700      0.166     -0.422      0.674      -0.396       0.256
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.WA]      0.0563      0.166      0.339      0.735      -0.270       0.383
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.WA]     -0.0008      0.166     -0.005      0.996      -0.327       0.325
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.WA]     -0.0143      0.166     -0.086      0.932      -0.341       0.312
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.WA]     -0.0064      0.166     -0.039      0.969      -0.333       0.320
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.WA]     -0.0608      0.166     -0.366      0.715      -0.387       0.266
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.WA]      0.0185      0.166      0.111      0.911      -0.308       0.345
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.WA]     -0.0268      0.166     -0.161      0.872      -0.353       0.300
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.WA]      0.0418      0.166      0.252      0.801      -0.284       0.368
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.WA]     -0.0676      0.166     -0.407      0.684      -0.394       0.259
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.WA]     -0.0847      0.167     -0.508      0.612      -0.412       0.243
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.WA]     -0.1048      0.166     -0.631      0.528      -0.431       0.222
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.WA]     -0.0480      0.167     -0.287      0.774      -0.376       0.280
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.WA]     -0.0331      0.166     -0.199      0.842      -0.359       0.293
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.WA]      0.0420      0.175      0.240      0.811      -0.302       0.386
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.WA]     0.0717      0.166      0.431      0.666      -0.255       0.398
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.WA]     0.1059      0.175      0.604      0.546      -0.238       0.450
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.WA]    -0.0182      0.166     -0.109      0.913      -0.344       0.308
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.WA]     0.0474      0.175      0.271      0.787      -0.297       0.392
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.WA]    -0.0089      0.166     -0.054      0.957      -0.335       0.317
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.WA]     0.0860      0.175      0.491      0.624      -0.258       0.430
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.WI]     -0.0731      0.152     -0.482      0.630      -0.371       0.225
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.WI]     -0.0199      0.152     -0.131      0.896      -0.318       0.278
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.WI]     -0.0903      0.152     -0.595      0.552      -0.389       0.208
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.WI]      0.0548      0.152      0.361      0.718      -0.243       0.353
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.WI]     -0.0889      0.152     -0.585      0.558      -0.387       0.209
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.WI]     -0.0462      0.152     -0.304      0.761      -0.344       0.252
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.WI]      0.0072      0.152      0.048      0.962      -0.291       0.305
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.WI]     -0.0486      0.152     -0.320      0.749      -0.347       0.250
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.WI]      0.0094      0.152      0.062      0.951      -0.289       0.308
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.WI]     -0.1322      0.152     -0.871      0.384      -0.430       0.166
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.WI]      0.0445      0.152      0.293      0.769      -0.254       0.343
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.WI]     -0.0397      0.152     -0.261      0.794      -0.338       0.259
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.WI]      0.0083      0.152      0.055      0.957      -0.290       0.306
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.WI]     -0.1160      0.152     -0.764      0.445      -0.414       0.182
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.WI]     -0.0645      0.152     -0.425      0.671      -0.363       0.234
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.WI]     -0.0352      0.152     -0.232      0.817      -0.333       0.263
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.WI]     -0.0586      0.152     -0.386      0.700      -0.357       0.240
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.WI]     0.0154      0.152      0.102      0.919      -0.283       0.314
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.WI]    -0.0218      0.152     -0.144      0.886      -0.320       0.276
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.WI]    -0.0258      0.152     -0.170      0.865      -0.324       0.272
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.WI]    -0.1048      0.152     -0.690      0.490      -0.403       0.193
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.WI]    -0.0840      0.152     -0.553      0.580      -0.382       0.214
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.WI]    -0.1142      0.152     -0.752      0.452      -0.412       0.184
# ==============================================================================
# Omnibus:                       63.315   Durbin-Watson:                   0.760
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              237.952
# Skew:                           0.071   Prob(JB):                     2.13e-52
# Kurtosis:                       5.279   Cond. No.                     7.72e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.61e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
import scipy.stats as stats

plt.figure(figsize=(20, 10))
plt.title('Effect of a WM entry on fresh produce price - monthly interaction terms (200-300 p/km^2 counties)')
plt.xlabel('Months before/after the entry')


coefs0 = np.exp(results0.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs0) - 2)
lower_CI_5_0 = coefs0 - cv_t * results0.bse[2:16]
upper_CI_5_0 = coefs0 + cv_t * results0.bse[2:16]
plt.plot(range(-6, 8), coefs0, color='lightblue', label='ø effects')
plt.plot(range(-6, 8), lower_CI_5_0, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_0, color='grey')

coefs1 = np.exp(results1.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs1) - 2)
lower_CI_5_1 = coefs1 - cv_t * results1.bse[2:16]
upper_CI_5_1 = coefs1 + cv_t * results1.bse[2:16]
plt.plot(range(-6, 8), coefs1, color='blue', label='time fixed effects')
plt.plot(range(-6, 8), lower_CI_5_1, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_1, color='grey')

coefs2 = np.exp(results2.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs2) - 2)
lower_CI_5_2 = coefs2 - cv_t * results2.bse[2:16]
upper_CI_5_2 = coefs2 + cv_t * results2.bse[2:16]
plt.plot(range(-6, 8), coefs2, color='darkblue', label='time fixed effects + state effects' )
plt.plot(range(-6, 8), lower_CI_5_2, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_2, color='grey')


plt.plot([-4, 5], [0, 0], linestyle='--', color='lightgrey')
plt.vlines(0, -0.5, 0.5, color='red', label='WM entry')
plt.legend();
plt.savefig("../../results_summary/results_freshp_d=200-300.png")

# %% [markdown]
# ### High density regression

# %%
# Final dataset for the regression :
treatment_hd = treatment[(treatment.B01001_calc_PopDensity<=4350)&(treatment.B01001_calc_PopDensity>=3915)]
control_hd = control[(control.B01001_calc_PopDensity<=4350)&(control.B01001_calc_PopDensity>=3915)]

print(f"Size of the control group: {len(control_hd.guessed_store_county_fips.unique())}.")
print(f"Size of the treatment group: {len(treatment_hd.guessed_store_county_fips.unique())}.")

df = pd.concat((control_hd, treatment_hd))[['upc_price', 'treat', 'interaction', 'time_fixed_effects',
                                            'store_state', "B01001_calc_PopDensity"]]
df = df[df.upc_price != 0]

print(treatment_hd.shape[0])
print(control_hd.shape[0])
# Out:
# Size of the control group: 1.
# Size of the treatment group: 1.
# 19
# 24

# %%
wm15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
wm16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
wm15['year'] = 2015
wm16['year'] = 2016
wm = pd.concat((wm15, wm16))
wm = wm[wm.is_walmart]
wm = pd.merge(wm, density,  how='inner', left_on='guessed_store_county_fips', right_on='GEOID')


## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes still remain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
wm = wm[~np.isin(wm.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# %%
# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]


# We choose to focus on milk prices
product_groupwm = wm[wm.product_group_descr == 'FRESH PRODUCE']

# The control group is composed by all states where nothing (no entry nor exit) happened.
controlwm = product_groupwm[~np.isin(product_groupwm.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(controlwm.guessed_store_county_fips.unique())}.")

# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.Opening_date + count.Closing_date == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]

treatmentwm = product_groupwm[np.isin(product_groupwm.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatmentwm = treatmentwm.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatmentwm.guessed_store_county_fips.unique())}.")

treatmentwm['treat'] = True
treatmentwm['purchase_0'] = treatmentwm.purchase_month * (treatmentwm.purchase_year == 2015) + (treatmentwm.purchase_month + 12) * (treatmentwm.purchase_year == 2016)
treatmentwm['opening_0'] = treatmentwm.Opening_date.dt.month * (treatmentwm.Opening_date.dt.year == 2015) + (treatmentwm.Opening_date.dt.month + 12) * (treatmentwm.Opening_date.dt.year == 2016)
treatmentwm['interaction'] = treatmentwm.purchase_0 - treatmentwm.opening_0
treatmentwm = treatmentwm[abs(treatmentwm.interaction) <=7]
treatmentwm['time_fixed_effects'] = list(zip(treatmentwm.purchase_month, treatmentwm.purchase_year))

treatmentwm_hd = treatmentwm[(treatmentwm.B01001_calc_PopDensity<=4350)&(treatmentwm.B01001_calc_PopDensity>=3915)]
controlwm_hd = controlwm[(controlwm.B01001_calc_PopDensity<=4350)&(controlwm.B01001_calc_PopDensity>=3915)]

print(f"Size of the control group: {len(controlwm_hd.guessed_store_county_fips.unique())}.")
print(f"Size of the treatment group: {len(treatmentwm_hd.guessed_store_county_fips.unique())}.")

dfwm = pd.concat((controlwm_hd, treatmentwm_hd))[['upc_price', 'treat', 'interaction', 'time_fixed_effects', 'store_state', "B01001_calc_PopDensity"]]
dfwm = dfwm[dfwm.upc_price != 0]
# Out:
# Size of the control group: 1182.
# Size of the treatment group: 82.
# Size of the control group: 0.
# Size of the treatment group: 1.

# %%
huhu = treatmentwm_hd.loc[treatmentwm_hd.index.repeat(treatmentwm_hd.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
hihi = treatment_hd.loc[treatment_hd.index.repeat(treatment_hd.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_4932\3055201021.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   huhu = treatmentwm_hd.loc[treatmentwm_hd.index.repeat(treatmentwm_hd.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
# C:\Users\inesn\AppData\Local\Temp\ipykernel_4932\3055201021.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hihi = treatment_hd.loc[treatment_hd.index.repeat(treatment_hd.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()

# %%
plt.plot(huhu.index, huhu.upc_price, '-+', color='lightgreen', label='WM')
plt.plot(hihi.index, hihi.upc_price, '-+', color='pink', label='others')
plt.title('Milk price evolution before and after a WM entry')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Milk price ($/gal)')
#plt.ylim((0,6))
plt.vlines(0, 0, 6, linestyles='-.');

# %%
plt.figure(figsize=(20,10))
#plt.plot(hohowm.index, hohowm.upc_price, '-+', color='green', label='WM')
plt.plot(huhu.index, huhu.upc_price, '-+', color='lightgreen', label='WM')
#plt.plot(hoho.index, hoho.upc_price, '-+', color='red', label='others')
plt.title('Fresh produce price evolution before and after a WM entry')
plt.plot(hihi.index, hihi.upc_price, '-+', color='pink', label='others')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Average price of items ($)')
plt.vlines(0, 2, 2.3, linestyles='-.');

# %% [markdown]
# Regression model :
# $$ Price_{i, t} = \alpha + \beta \cdot treat_i + \delta \cdot treat_i \cdot post_{t} + \sum_{\tau=Janv15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau) + \sum_{s \in USStates}\gamma_{s} \cdot \mathbb{1}(state = s) + \varepsilon_{i, t}$$

# %%
reg0 = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction)',
    data=df)
results0 = reg0.fit()

reg1 = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects)',
    data=df)
results1 = reg1.fit()

reg2 = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
    data=df)
results2 = reg2.fit()

# %%
import scipy.stats as stats

plt.figure(figsize=(20, 10))
plt.title('Effect of WM entry on package meats-deli prices')
plt.xlabel('Months before/after the entry')


coefs0 = np.exp(results0.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs0) - 2)
lower_CI_5_0 = coefs0 - cv_t * results0.bse[2:16]
upper_CI_5_0 = coefs0 + cv_t * results0.bse[2:16]
plt.plot(range(-6, 8), coefs0, color='lightblue', label='ø effects')
plt.plot(range(-6, 8), lower_CI_5_0, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_0, color='grey')

coefs1 = np.exp(results1.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs1) - 2)
lower_CI_5_1 = coefs1 - cv_t * results1.bse[2:16]
upper_CI_5_1 = coefs1 + cv_t * results1.bse[2:16]
plt.plot(range(-6, 8), coefs1, color='blue', label='time fixed effects')
plt.plot(range(-6, 8), lower_CI_5_1, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_1, color='grey')

coefs2 = np.exp(results2.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs2) - 2)
lower_CI_5_2 = coefs2 - cv_t * results2.bse[2:16]
upper_CI_5_2 = coefs2 + cv_t * results2.bse[2:16]
plt.plot(range(-6, 8), coefs2, color='darkblue', label='time fixed effects + state effects' )
plt.plot(range(-6, 8), lower_CI_5_2, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_2, color='grey')


plt.plot([-4, 5], [0, 0], linestyle='--', color='lightgrey')
plt.vlines(0, -0.5, 0.5, color='red', label='WM entry')
plt.legend();
# Out:
# C:\anaconda\envs\tr_econ\lib\site-packages\statsmodels\regression\linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# C:\anaconda\envs\tr_econ\lib\site-packages\statsmodels\regression\linear_model.py:1671: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid

# %%
import scipy.stats as stats

plt.figure(figsize=(20, 10))
plt.title('Effect of WM entry on package meats-deli prices')
plt.xlabel('Months before/after the entry')


coefs0 = np.exp(results0.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs0) - 2)
lower_CI_5_0 = coefs0 - cv_t * results0.bse[2:16]
upper_CI_5_0 = coefs0 + cv_t * results0.bse[2:16]
plt.plot(range(-6, 8), (coefs0 - coefs0[0]) / coefs0[0], color='lightblue', label='ø effects')
plt.plot(range(-6, 8), lower_CI_5_0, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_0, color='grey')

coefs1 = np.exp(results1.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs1) - 2)
lower_CI_5_1 = coefs1 - cv_t * results1.bse[2:16]
upper_CI_5_1 = coefs1 + cv_t * results1.bse[2:16]
plt.plot(range(-6, 8), (coefs1 - coefs1[0]) / coefs1[0], color='blue', label='time fixed effects')
plt.plot(range(-6, 8), lower_CI_5_1, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_1, color='grey')

coefs2 = np.exp(results2.params[2:16]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs2) - 2)
lower_CI_5_2 = coefs2 - cv_t * results2.bse[2:16]
upper_CI_5_2 = coefs2 + cv_t * results2.bse[2:16]
plt.plot(range(-6, 8), (coefs2 - coefs2[0]) / coefs2[0], color='darkblue', label='time fixed effects + state effects' )
plt.plot(range(-6, 8), lower_CI_5_2, color='grey', label='confidence interval, 95%')
plt.plot(range(-6, 8), upper_CI_5_2, color='grey')


plt.plot([-4, 5], [0, 0], linestyle='--', color='lightgrey')
plt.vlines(0, -0.5, 0.5, color='red', label='WM entry')
plt.legend();
