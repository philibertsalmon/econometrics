# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

# %%
nielsen = pd.concat((nielsen15, nielsen16))

# %%
## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]

wm = nielsen[nielsen.is_walmart].copy()
nielsen = nielsen[~nielsen.is_walmart]

# %%
nielsen.groupby('product_group_descr').count().sort_values('upc_price', ascending=False).head(20)
# Out:
#                                   is_walmart  store_state  \
# product_group_descr
# FRESH PRODUCE                          42329        42329
# BREAD AND BAKED GOODS                  41725        41725
# MILK                                   40079        40079
# SNACKS                                 39978        39978
# PACKAGED MEATS-DELI                    39929        39929
# CHEESE                                 39595        39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN       39240        39240
# CARBONATED BEVERAGES                   37764        37764
# CONDIMENTS, GRAVIES, AND SAUCES        37701        37701
# DRESSINGS/SALADS/PREP FOODS-DELI       37008        37008
# CANDY                                  35877        35877
# JUICE, DRINKS - CANNED, BOTTLED        35694        35694
# EGGS                                   35616        35616
# VEGETABLES - CANNED                    35279        35279
# ICE CREAM, NOVELTIES                   34590        34590
# CEREAL                                 34333        34333
# VEGETABLES-FROZEN                      34296        34296
# PREPARED FOOD-DRY MIXES                34035        34035
# PAPER PRODUCTS                         33956        33956
# PREPARED FOODS-FROZEN                  33906        33906
#
#                                   guessed_store_county  \
# product_group_descr
# FRESH PRODUCE                                    42329
# BREAD AND BAKED GOODS                            41725
# MILK                                             40079
# SNACKS                                           39978
# PACKAGED MEATS-DELI                              39929
# CHEESE                                           39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN                 39240
# CARBONATED BEVERAGES                             37764
# CONDIMENTS, GRAVIES, AND SAUCES                  37701
# DRESSINGS/SALADS/PREP FOODS-DELI                 37008
# CANDY                                            35877
# JUICE, DRINKS - CANNED, BOTTLED                  35694
# EGGS                                             35616
# VEGETABLES - CANNED                              35279
# ICE CREAM, NOVELTIES                             34590
# CEREAL                                           34333
# VEGETABLES-FROZEN                                34296
# PREPARED FOOD-DRY MIXES                          34035
# PAPER PRODUCTS                                   33956
# PREPARED FOODS-FROZEN                            33906
#
#                                   guessed_store_county_fips  purchase_year  \
# product_group_descr
# FRESH PRODUCE                                         42329          42329
# BREAD AND BAKED GOODS                                 41725          41725
# MILK                                                  40079          40079
# SNACKS                                                39978          39978
# PACKAGED MEATS-DELI                                   39929          39929
# CHEESE                                                39595          39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN                      39240          39240
# CARBONATED BEVERAGES                                  37764          37764
# CONDIMENTS, GRAVIES, AND SAUCES                       37701          37701
# DRESSINGS/SALADS/PREP FOODS-DELI                      37008          37008
# CANDY                                                 35877          35877
# JUICE, DRINKS - CANNED, BOTTLED                       35694          35694
# EGGS                                                  35616          35616
# VEGETABLES - CANNED                                   35279          35279
# ICE CREAM, NOVELTIES                                  34590          34590
# CEREAL                                                34333          34333
# VEGETABLES-FROZEN                                     34296          34296
# PREPARED FOOD-DRY MIXES                               34035          34035
# PAPER PRODUCTS                                        33956          33956
# PREPARED FOODS-FROZEN                                 33906          33906
#
#                                   purchase_month  upc_price  upc_price_std  \
# product_group_descr
# FRESH PRODUCE                              42329      42329          40500
# BREAD AND BAKED GOODS                      41725      41725          38980
# MILK                                       40079      40079          36097
# SNACKS                                     39978      39978          36697
# PACKAGED MEATS-DELI                        39929      39929          36608
# CHEESE                                     39595      39595          36234
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN           39240      39240          36505
# CARBONATED BEVERAGES                       37764      37764          33777
# CONDIMENTS, GRAVIES, AND SAUCES            37701      37701          33389
# DRESSINGS/SALADS/PREP FOODS-DELI           37008      37008          32648
# CANDY                                      35877      35877          31653
# JUICE, DRINKS - CANNED, BOTTLED            35694      35694          31029
# EGGS                                       35616      35616          29230
# VEGETABLES - CANNED                        35279      35279          31325
# ICE CREAM, NOVELTIES                       34590      34590          29502
# CEREAL                                     34333      34333          30045
# VEGETABLES-FROZEN                          34296      34296          29332
# PREPARED FOOD-DRY MIXES                    34035      34035          29041
# PAPER PRODUCTS                             33956      33956          28978
# PREPARED FOODS-FROZEN                      33906      33906          29665
#
#                                   nb_of_obs   year
# product_group_descr
# FRESH PRODUCE                         42329  42329
# BREAD AND BAKED GOODS                 41725  41725
# MILK                                  40079  40079
# SNACKS                                39978  39978
# PACKAGED MEATS-DELI                   39929  39929
# CHEESE                                39595  39595
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN      39240  39240
# CARBONATED BEVERAGES                  37764  37764
# CONDIMENTS, GRAVIES, AND SAUCES       37701  37701
# DRESSINGS/SALADS/PREP FOODS-DELI      37008  37008
# CANDY                                 35877  35877
# JUICE, DRINKS - CANNED, BOTTLED       35694  35694
# EGGS                                  35616  35616
# VEGETABLES - CANNED                   35279  35279
# ICE CREAM, NOVELTIES                  34590  34590
# CEREAL                                34333  34333
# VEGETABLES-FROZEN                     34296  34296
# PREPARED FOOD-DRY MIXES               34035  34035
# PAPER PRODUCTS                        33956  33956
# PREPARED FOODS-FROZEN                 33906  33906

# %%
category = "FRESH PRODUCE"

# %% [markdown]
# ## THIRD MODEL : adding entity effects

# %%
# We choose to focus on fresh produce
product_group = nielsen[nielsen.product_group_descr == category]


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State==1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Opening_date >= '2015-01-31') & (treatment_movements.Opening_date <= '2017-01-31') & ((treatment_movements.Closing_date >= '2017-01-31')|(treatment_movements.Closing_date.apply(str) == 'NaT'))]

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = 0
control['time_fixed_effects'] = list(zip(control.purchase_month, control.purchase_year))
control['post'] = False

treatment['treat'] = True
treatment['purchase_0'] = treatment.purchase_month * (treatment.purchase_year == 2015) + (treatment.purchase_month +12) * (treatment.purchase_year == 2016)
treatment['opening_0'] = treatment.Opening_date.dt.month * (treatment.Opening_date.dt.year == 2015) + (treatment.Opening_date.dt.month +12) * (treatment.Opening_date.dt.year == 2016)
treatment['interaction'] = treatment.purchase_0 - treatment.opening_0
treatment = treatment[abs(treatment.interaction - 5) <=12]
treatment['time_fixed_effects'] = list(zip(treatment.purchase_month, treatment.purchase_year))
treatment['post'] = treatment.purchase_0 > treatment.opening_0


# Final dataset for the regression :

df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'time_fixed_effects', 'store_state', 'post']]
df = df[df.upc_price != 0]
# Out:
# Size of the control group: 1831.
# Size of the treatment group: 91.

# %%
# We choose to focus on milk prices
product_groupwm = wm[wm.product_group_descr == category]

# The control group is composed by all states where nothing (no entry nor exit) happened.
controlwm = product_groupwm[~np.isin(product_groupwm.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")

# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State==1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Opening_date >= '2015-01-31') & (treatment_movements.Opening_date <= '2017-01-31') & ((treatment_movements.Closing_date >= '2017-01-31')|(treatment_movements.Closing_date.apply(str) == 'NaT'))]


treatmentwm = product_groupwm[np.isin(product_groupwm.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatmentwm = treatmentwm.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatmentwm.guessed_store_county_fips.unique())}.")


controlwm['treat'] = False
controlwm['interaction'] = 0
controlwm['time_fixed_effects'] = list(zip(controlwm.purchase_month, controlwm.purchase_year))

treatmentwm['treat'] = True
treatmentwm['purchase_0'] = treatmentwm.purchase_month * (treatmentwm.purchase_year == 2015) + (treatmentwm.purchase_month + 12) * (treatmentwm.purchase_year == 2016)
treatmentwm['opening_0'] = treatmentwm.Opening_date.dt.month * (treatmentwm.Opening_date.dt.year == 2015) + (treatmentwm.Opening_date.dt.month + 12) * (treatmentwm.Opening_date.dt.year == 2016)
treatmentwm['interaction'] = treatmentwm.purchase_0 - treatmentwm.opening_0
treatmentwm = treatmentwm[abs(treatmentwm.interaction - 5) <= 12]
treatmentwm['time_fixed_effects'] = list(zip(treatmentwm.purchase_month, treatmentwm.purchase_year))

dfwm = pd.concat((controlwm, treatmentwm))[['upc_price', 'treat', 'interaction', 'time_fixed_effects', 'store_state']]
dfwm = dfwm[dfwm.upc_price != 0]
# Out:
# Size of the control group: 1831.
# Size of the treatment group: 83.

# %%
huhu = treatmentwm.loc[treatmentwm.index.repeat(treatmentwm.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()
hihi = treatment.loc[treatment.index.repeat(treatment.nb_of_obs)].reset_index(drop=True).drop('nb_of_obs', axis=1).groupby('interaction').mean()

# %%
plt.figure(figsize=(20,10))
#plt.plot(hohowm.index, hohowm.upc_price, '-+', color='green', label='WM')
plt.plot(huhu.index, huhu.upc_price, '-+', color='lightgreen', label='WM')
#plt.plot(hoho.index, hoho.upc_price, '-+', color='red', label='others')
plt.title(f'{category} price evolution before and after a WM entry')
plt.plot(hihi.index, hihi.upc_price, '-+', color='pink', label='others')
plt.legend()
plt.xlabel('Months before/after the entry')
plt.ylabel('Average price of items ($)')
plt.vlines(0, min(hihi.upc_price.min(), huhu.upc_price.min()) - 0.05 , max(hihi.upc_price.max(), huhu.upc_price.max()) + 0.05, linestyles='-.');
#plt.savefig(f"./figs/{category}_prices.png")

# %% [markdown]
# Regression model :
# $$
#
# Price_{i, t}\quad = \quad\alpha \quad +\quad \beta \cdot treat_i \quad+ \quad\sum_{\tau=-7}^{17} \delta_{\tau} \cdot treat_i \cdot \mathbb{1}(t'=\tau) \quad + \quad\sum_{\tau=Feb15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau)\quad +\quad \sum_{s \in USStates}\gamma_{s} \cdot \mathbb{1}(state = s) \quad+\quad \varepsilon_{i, t}
# $$

# %%
df['post']=df.interaction>=0

# %%
reg0 = smf.ols(
   formula='np.log(upc_price) ~ treat + post + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
  data=df)
results0 = reg0.fit()
#
#reg1 = smf.ols(
#    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects)',
#   data=df)
#results1 = reg1.fit()

#reg2 = smf.ols(
#    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
#    data=df)
#results2 = reg2.fit()

# %%
results0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(upc_price)   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     3.126
# Date:                Thu, 03 Nov 2022   Prob (F-statistic):          1.92e-215
# Time:                        15:22:22   Log-Likelihood:                -4711.2
# No. Observations:               39513   AIC:                         1.153e+04
# Df Residuals:                   38457   BIC:                         2.060e+04
# Df Model:                        1055
# Covariance Type:            nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                    0.6530      0.041     15.853      0.000       0.572       0.734
# treat[T.True]                                               -0.0051      0.011     -0.447      0.655      -0.027       0.017
# post[T.True]                                                 0.0012      0.015      0.081      0.935      -0.027       0.030
# C(time_fixed_effects)[T.(1, 2016)]                           0.0272      0.059      0.463      0.643      -0.088       0.142
# C(time_fixed_effects)[T.(2, 2015)]                           0.0770      0.058      1.336      0.181      -0.036       0.190
# C(time_fixed_effects)[T.(2, 2016)]                           0.1191      0.059      2.033      0.042       0.004       0.234
# C(time_fixed_effects)[T.(3, 2015)]                           0.0208      0.059      0.354      0.723      -0.094       0.136
# C(time_fixed_effects)[T.(3, 2016)]                           0.0931      0.058      1.598      0.110      -0.021       0.207
# C(time_fixed_effects)[T.(4, 2015)]                           0.0108      0.059      0.185      0.853      -0.104       0.126
# C(time_fixed_effects)[T.(4, 2016)]                           0.0108      0.059      0.183      0.855      -0.105       0.126
# C(time_fixed_effects)[T.(5, 2015)]                           0.0248      0.058      0.426      0.670      -0.089       0.139
# C(time_fixed_effects)[T.(5, 2016)]                           0.0179      0.059      0.305      0.761      -0.097       0.133
# C(time_fixed_effects)[T.(6, 2015)]                           0.1005      0.058      1.725      0.084      -0.014       0.215
# C(time_fixed_effects)[T.(6, 2016)]                           0.0413      0.059      0.700      0.484      -0.074       0.157
# C(time_fixed_effects)[T.(7, 2015)]                           0.0777      0.058      1.341      0.180      -0.036       0.191
# C(time_fixed_effects)[T.(7, 2016)]                           0.0842      0.059      1.429      0.153      -0.031       0.200
# C(time_fixed_effects)[T.(8, 2015)]                           0.0760      0.058      1.304      0.192      -0.038       0.190
# C(time_fixed_effects)[T.(8, 2016)]                           0.0437      0.060      0.732      0.464      -0.073       0.161
# C(time_fixed_effects)[T.(9, 2015)]                           0.0445      0.059      0.756      0.450      -0.071       0.160
# C(time_fixed_effects)[T.(9, 2016)]                          -0.0158      0.058     -0.274      0.784      -0.129       0.097
# C(time_fixed_effects)[T.(10, 2015)]                          0.0229      0.059      0.392      0.695      -0.092       0.138
# C(time_fixed_effects)[T.(10, 2016)]                          0.0384      0.059      0.648      0.517      -0.078       0.155
# C(time_fixed_effects)[T.(11, 2015)]                          0.0873      0.059      1.481      0.139      -0.028       0.203
# C(time_fixed_effects)[T.(11, 2016)]                          0.0827      0.060      1.386      0.166      -0.034       0.200
# C(time_fixed_effects)[T.(12, 2015)]                          0.0478      0.058      0.824      0.410      -0.066       0.161
# C(time_fixed_effects)[T.(12, 2016)]                          0.0855      0.060      1.433      0.152      -0.031       0.202
# C(store_state)[T.AR]                                        -0.1062      0.061     -1.732      0.083      -0.226       0.014
# C(store_state)[T.AZ]                                         0.0088      0.093      0.094      0.925      -0.173       0.191
# C(store_state)[T.CO]                                         0.0805      0.065      1.248      0.212      -0.046       0.207
# C(store_state)[T.CT]                                         0.2467      0.120      2.054      0.040       0.011       0.482
# C(store_state)[T.DC]                                         0.1408      0.057      2.454      0.014       0.028       0.253
# C(store_state)[T.DE]                                         0.1556      0.165      0.944      0.345      -0.167       0.479
# C(store_state)[T.FL]                                         0.1603      0.060      2.669      0.008       0.043       0.278
# C(store_state)[T.IA]                                         0.0676      0.053      1.288      0.198      -0.035       0.171
# C(store_state)[T.ID]                                        -0.1066      0.067     -1.603      0.109      -0.237       0.024
# C(store_state)[T.IL]                                         0.0149      0.053      0.282      0.778      -0.089       0.119
# C(store_state)[T.IN]                                         0.1000      0.052      1.915      0.055      -0.002       0.202
# C(store_state)[T.KY]                                         0.1138      0.052      2.190      0.029       0.012       0.216
# C(store_state)[T.MA]                                         0.1500      0.087      1.723      0.085      -0.021       0.320
# C(store_state)[T.MD]                                         0.1636      0.076      2.163      0.031       0.015       0.312
# C(store_state)[T.ME]                                         0.0767      0.080      0.954      0.340      -0.081       0.234
# C(store_state)[T.MI]                                         0.0645      0.052      1.231      0.218      -0.038       0.167
# C(store_state)[T.MN]                                         0.0888      0.054      1.651      0.099      -0.017       0.194
# C(store_state)[T.MO]                                         0.0328      0.054      0.609      0.543      -0.073       0.139
# C(store_state)[T.MS]                                         0.1004      0.058      1.724      0.085      -0.014       0.215
# C(store_state)[T.MT]                                         0.0755      0.070      1.081      0.280      -0.061       0.212
# C(store_state)[T.NC]                                         0.0548      0.054      1.010      0.313      -0.052       0.161
# C(store_state)[T.ND]                                         0.2066      0.077      2.681      0.007       0.056       0.358
# C(store_state)[T.NE]                                        -0.0435      0.059     -0.734      0.463      -0.160       0.073
# C(store_state)[T.NH]                                         0.0849      0.097      0.879      0.379      -0.104       0.274
# C(store_state)[T.NJ]                                         0.2304      0.076      3.048      0.002       0.082       0.379
# C(store_state)[T.NM]                                        -0.0344      0.077     -0.447      0.655      -0.185       0.117
# C(store_state)[T.NV]                                         0.0495      0.093      0.533      0.594      -0.133       0.232
# C(store_state)[T.NY]                                         0.1842      0.055      3.356      0.001       0.077       0.292
# C(store_state)[T.OH]                                         0.1137      0.051      2.218      0.027       0.013       0.214
# C(store_state)[T.OK]                                        -0.0484      0.062     -0.777      0.437      -0.170       0.074
# C(store_state)[T.OR]                                         0.0676      0.069      0.981      0.326      -0.067       0.203
# C(store_state)[T.PA]                                         0.1829      0.054      3.369      0.001       0.076       0.289
# C(store_state)[T.RI]                                         0.2509      0.130      1.926      0.054      -0.004       0.506
# C(store_state)[T.SC]                                         0.0282      0.068      0.414      0.679      -0.105       0.162
# C(store_state)[T.SD]                                         0.1359      0.067      2.043      0.041       0.006       0.266
# C(store_state)[T.TN]                                         0.0280      0.054      0.517      0.605      -0.078       0.134
# C(store_state)[T.UT]                                        -0.0077      0.082     -0.093      0.926      -0.169       0.154
# C(store_state)[T.VA]                                         0.1025      0.051      2.007      0.045       0.002       0.203
# C(store_state)[T.VT]                                         0.2546      0.097      2.635      0.008       0.065       0.444
# C(store_state)[T.WA]                                         0.0792      0.065      1.216      0.224      -0.048       0.207
# C(store_state)[T.WI]                                         0.0887      0.054      1.638      0.101      -0.017       0.195
# C(store_state)[T.WV]                                         0.0613      0.064      0.951      0.342      -0.065       0.188
# C(store_state)[T.WY]                                         0.1779      0.077      2.308      0.021       0.027       0.329
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.AR]      0.0280      0.086      0.324      0.746      -0.141       0.197
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.AR]      0.0372      0.085      0.435      0.663      -0.130       0.205
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.AR]      0.0237      0.087      0.274      0.784      -0.146       0.194
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.AR]      0.0597      0.085      0.701      0.484      -0.107       0.227
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.AR]      0.0094      0.086      0.109      0.913      -0.159       0.178
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.AR]      0.0684      0.087      0.787      0.432      -0.102       0.239
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.AR]      0.0456      0.087      0.527      0.598      -0.124       0.215
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.AR]      0.1181      0.085      1.388      0.165      -0.049       0.285
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.AR]      0.1133      0.086      1.317      0.188      -0.055       0.282
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.AR]     -0.0615      0.086     -0.716      0.474      -0.230       0.107
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.AR]      0.0796      0.087      0.916      0.360      -0.091       0.250
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.AR]      0.0545      0.085      0.642      0.521      -0.112       0.221
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.AR]      0.0913      0.088      1.044      0.297      -0.080       0.263
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.AR]      0.0367      0.086      0.429      0.668      -0.131       0.204
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.AR]      0.0574      0.088      0.652      0.514      -0.115       0.230
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.AR]      0.0643      0.086      0.748      0.454      -0.104       0.233
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.AR]      0.0544      0.087      0.625      0.532      -0.116       0.225
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.AR]     0.1005      0.086      1.168      0.243      -0.068       0.269
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.AR]     0.1434      0.087      1.646      0.100      -0.027       0.314
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.AR]    -0.0188      0.086     -0.218      0.827      -0.187       0.150
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.AR]    -0.0684      0.087     -0.788      0.431      -0.238       0.102
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.AR]     0.0297      0.085      0.349      0.727      -0.137       0.196
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.AR]    -0.0933      0.087     -1.075      0.283      -0.263       0.077
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.AZ]     -0.0549      0.126     -0.437      0.662      -0.302       0.192
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.AZ]     -0.1263      0.131     -0.963      0.335      -0.383       0.131
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.AZ]     -0.1419      0.126     -1.128      0.259      -0.389       0.105
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.AZ]     -0.0260      0.132     -0.198      0.843      -0.284       0.232
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.AZ]     -0.1527      0.126     -1.215      0.224      -0.399       0.094
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.AZ]     -0.0515      0.132     -0.392      0.695      -0.309       0.206
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.AZ]     -0.0375      0.126     -0.298      0.766      -0.284       0.209
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.AZ]     -0.0021      0.131     -0.016      0.987      -0.260       0.256
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.AZ]      0.0361      0.127      0.283      0.777      -0.214       0.286
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.AZ]     -0.1650      0.127     -1.296      0.195      -0.415       0.085
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.AZ]     -0.1111      0.126     -0.882      0.378      -0.358       0.136
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.AZ]     -0.0098      0.127     -0.077      0.938      -0.259       0.239
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.AZ]     -0.1674      0.126     -1.329      0.184      -0.414       0.080
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.AZ]     -0.1525      0.126     -1.214      0.225      -0.399       0.094
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.AZ]     -0.1405      0.126     -1.112      0.266      -0.388       0.107
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.AZ]     -0.1398      0.126     -1.110      0.267      -0.387       0.107
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.AZ]     -0.0053      0.127     -0.042      0.966      -0.254       0.244
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.AZ]    -0.0907      0.126     -0.721      0.471      -0.337       0.156
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.AZ]    -0.0261      0.128     -0.204      0.838      -0.277       0.224
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.AZ]    -0.1143      0.126     -0.907      0.364      -0.361       0.133
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.AZ]    -0.1159      0.128     -0.906      0.365      -0.367       0.135
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.AZ]    -0.0602      0.126     -0.479      0.632      -0.306       0.186
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.AZ]    -0.0683      0.128     -0.534      0.593      -0.319       0.182
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.CO]      0.0277      0.090      0.308      0.758      -0.148       0.204
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.CO]     -0.0806      0.090     -0.891      0.373      -0.258       0.097
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.CO]     -0.1760      0.091     -1.943      0.052      -0.354       0.002
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.CO]     -0.1021      0.091     -1.127      0.260      -0.280       0.076
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.CO]     -0.1931      0.090     -2.136      0.033      -0.370      -0.016
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.CO]     -0.0372      0.091     -0.409      0.683      -0.216       0.141
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.CO]     -0.0239      0.090     -0.265      0.791      -0.200       0.153
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.CO]     -0.0881      0.090     -0.979      0.328      -0.265       0.088
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.CO]     -0.0150      0.090     -0.167      0.868      -0.192       0.162
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.CO]     -0.1141      0.090     -1.268      0.205      -0.291       0.062
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.CO]     -0.1634      0.090     -1.806      0.071      -0.341       0.014
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.CO]     -0.1127      0.089     -1.260      0.208      -0.288       0.063
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.CO]     -0.0485      0.090     -0.539      0.590      -0.225       0.128
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.CO]     -0.1196      0.090     -1.328      0.184      -0.296       0.057
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.CO]     -0.0367      0.090     -0.407      0.684      -0.214       0.140
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.CO]     -0.1559      0.091     -1.717      0.086      -0.334       0.022
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.CO]     -0.0713      0.089     -0.799      0.424      -0.246       0.104
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.CO]    -0.0875      0.091     -0.966      0.334      -0.265       0.090
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.CO]    -0.0749      0.091     -0.823      0.411      -0.253       0.104
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.CO]    -0.0943      0.090     -1.047      0.295      -0.271       0.082
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.CO]    -0.0025      0.091     -0.028      0.978      -0.180       0.175
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.CO]    -0.0553      0.092     -0.602      0.547      -0.236       0.125
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.CO]    -0.1081      0.091     -1.184      0.236      -0.287       0.071
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.CT]      0.0213      0.170      0.125      0.900      -0.312       0.354
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.CT]     -0.1109      0.170     -0.654      0.513      -0.443       0.222
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.CT]     -0.0638      0.170     -0.376      0.707      -0.397       0.269
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.CT]     -0.0665      0.170     -0.391      0.695      -0.400       0.267
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.CT]     -0.1162      0.170     -0.684      0.494      -0.449       0.217
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.CT]     -0.0607      0.170     -0.357      0.721      -0.394       0.272
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.CT]     -0.0455      0.170     -0.268      0.789      -0.379       0.288
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.CT]     -0.0717      0.170     -0.422      0.673      -0.405       0.261
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.CT]      0.0098      0.170      0.057      0.954      -0.323       0.343
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.CT]     -0.1469      0.170     -0.865      0.387      -0.480       0.186
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.CT]     -0.0418      0.170     -0.246      0.806      -0.375       0.292
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.CT]     -0.1200      0.170     -0.707      0.480      -0.453       0.213
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.CT]     -0.0306      0.170     -0.180      0.857      -0.364       0.303
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.CT]     -0.1354      0.170     -0.797      0.425      -0.468       0.198
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.CT]     -0.0461      0.170     -0.271      0.787      -0.380       0.288
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.CT]     -0.0896      0.170     -0.527      0.598      -0.423       0.244
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.CT]      0.0157      0.170      0.093      0.926      -0.317       0.348
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.CT]    -0.0550      0.170     -0.323      0.746      -0.388       0.278
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.CT]    -0.0675      0.170     -0.397      0.692      -0.401       0.266
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.CT]    -0.0933      0.170     -0.548      0.583      -0.427       0.240
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.CT]    -0.0870      0.170     -0.511      0.610      -0.421       0.247
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.CT]    -0.0613      0.170     -0.361      0.718      -0.394       0.271
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.CT]    -0.0965      0.170     -0.567      0.571      -0.430       0.237
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.DC]      0.1376      0.273      0.504      0.614      -0.398       0.673
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.DC]   8.568e-17   1.44e-15      0.059      0.953   -2.74e-15    2.91e-15
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.DC]     -0.0273      0.273     -0.100      0.920      -0.563       0.508
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.DC]     -0.0750      0.273     -0.275      0.784      -0.610       0.460
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.DC]     -0.0529      0.273     -0.194      0.847      -0.588       0.482
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.DC]      0.0361      0.273      0.132      0.895      -0.499       0.572
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.DC]      0.1035      0.273      0.379      0.705      -0.432       0.639
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.DC]      0.0223      0.273      0.082      0.935      -0.513       0.558
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.DC]     -0.0354      0.273     -0.130      0.897      -0.571       0.500
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.DC]     -0.1318      0.273     -0.482      0.629      -0.667       0.404
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.DC]      0.0435      0.273      0.159      0.873      -0.492       0.579
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.DC]      0.0493      0.273      0.181      0.857      -0.486       0.585
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.DC]     -0.0555      0.273     -0.203      0.839      -0.591       0.480
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.DC]     -0.0510      0.273     -0.187      0.852      -0.586       0.484
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.DC]     -0.0454      0.273     -0.166      0.868      -0.581       0.490
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.DC]     -0.0006      0.273     -0.002      0.998      -0.536       0.535
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.DC]      0.0923      0.273      0.338      0.735      -0.443       0.627
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.DC]     0.1199      0.273      0.439      0.661      -0.416       0.655
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.DC]    -0.0248      0.273     -0.091      0.928      -0.560       0.511
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.DC]     0.0183      0.273      0.067      0.946      -0.517       0.554
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.DC]     0.0049      0.273      0.018      0.986      -0.531       0.541
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.DC]     0.0185      0.273      0.068      0.946      -0.517       0.553
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.DC]    -0.0059      0.273     -0.021      0.983      -0.542       0.530
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.DE]      0.0467      0.233      0.201      0.841      -0.410       0.504
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.DE]     -0.0961      0.233     -0.413      0.680      -0.552       0.360
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.DE]     -0.0684      0.233     -0.293      0.769      -0.525       0.389
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.DE]     -0.0438      0.233     -0.188      0.851      -0.501       0.413
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.DE]     -0.0663      0.233     -0.285      0.776      -0.523       0.390
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.DE]     -0.0578      0.233     -0.248      0.804      -0.515       0.399
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.DE]      0.0411      0.233      0.176      0.860      -0.416       0.498
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.DE]     -0.0082      0.233     -0.035      0.972      -0.465       0.449
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.DE]      0.0801      0.233      0.343      0.731      -0.377       0.537
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.DE]     -0.0715      0.233     -0.307      0.759      -0.528       0.385
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.DE]      0.0499      0.233      0.214      0.831      -0.407       0.507
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.DE]     -0.0224      0.233     -0.096      0.924      -0.479       0.434
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.DE]     -0.0005      0.233     -0.002      0.998      -0.458       0.457
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.DE]     -0.0716      0.233     -0.307      0.759      -0.528       0.385
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.DE]     -0.0160      0.233     -0.069      0.945      -0.473       0.441
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.DE]     -0.1255      0.233     -0.538      0.590      -0.583       0.332
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.DE]      0.0125      0.233      0.054      0.957      -0.444       0.469
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.DE]    -0.0295      0.233     -0.126      0.899      -0.486       0.427
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.DE]    -0.0474      0.233     -0.203      0.839      -0.505       0.410
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.DE]    -0.0351      0.233     -0.150      0.880      -0.492       0.422
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.DE]    -0.0576      0.233     -0.247      0.805      -0.515       0.400
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.DE]    -0.0096      0.233     -0.041      0.967      -0.466       0.447
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.DE]    -0.0569      0.233     -0.244      0.807      -0.514       0.401
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.FL]     -0.0247      0.083     -0.295      0.768      -0.188       0.139
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.FL]     -0.0957      0.084     -1.133      0.257      -0.261       0.070
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.FL]     -0.0870      0.083     -1.042      0.298      -0.251       0.077
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.FL]     -0.0038      0.085     -0.044      0.965      -0.171       0.163
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.FL]     -0.0537      0.083     -0.646      0.518      -0.217       0.109
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.FL]     -0.0478      0.085     -0.561      0.575      -0.215       0.119
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.FL]     -0.0117      0.084     -0.139      0.889      -0.176       0.152
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.FL]     -0.0685      0.085     -0.809      0.418      -0.234       0.097
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.FL]     -0.0187      0.083     -0.224      0.823      -0.182       0.145
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.FL]     -0.1017      0.085     -1.201      0.230      -0.268       0.064
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.FL]     -0.0180      0.084     -0.216      0.829      -0.182       0.146
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.FL]     -0.0859      0.084     -1.023      0.306      -0.250       0.079
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.FL]     -0.0426      0.084     -0.509      0.611      -0.207       0.122
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.FL]     -0.0547      0.084     -0.652      0.514      -0.219       0.110
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.FL]     -0.0313      0.084     -0.370      0.711      -0.197       0.134
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.FL]     -0.0069      0.084     -0.082      0.935      -0.172       0.158
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.FL]     -0.0022      0.083     -0.026      0.979      -0.165       0.161
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.FL]     0.0034      0.084      0.041      0.967      -0.161       0.167
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.FL]    -0.0344      0.084     -0.410      0.682      -0.199       0.130
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.FL]    -0.0996      0.084     -1.189      0.234      -0.264       0.065
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.FL]    -0.0610      0.085     -0.721      0.471      -0.227       0.105
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.FL]    -0.1035      0.083     -1.247      0.212      -0.266       0.059
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.FL]    -0.0686      0.084     -0.815      0.415      -0.234       0.096
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.IA]      0.0474      0.075      0.630      0.529      -0.100       0.195
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.IA]     -0.1278      0.074     -1.723      0.085      -0.273       0.018
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.IA]     -0.1113      0.075     -1.485      0.138      -0.258       0.036
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.IA]      0.0078      0.075      0.105      0.917      -0.139       0.155
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.IA]     -0.0522      0.075     -0.698      0.485      -0.199       0.094
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.IA]     -0.0277      0.075     -0.370      0.711      -0.174       0.119
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.IA]     -0.0387      0.075     -0.517      0.605      -0.186       0.108
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.IA]      0.0057      0.074      0.077      0.938      -0.140       0.152
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.IA]      0.0525      0.075      0.701      0.483      -0.094       0.199
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.IA]     -0.0146      0.075     -0.196      0.845      -0.161       0.132
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.IA]      0.0867      0.075      1.151      0.250      -0.061       0.234
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.IA]     -0.0224      0.074     -0.302      0.763      -0.168       0.123
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.IA]      0.0042      0.076      0.055      0.956      -0.144       0.152
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.IA]     -0.0134      0.074     -0.180      0.857      -0.159       0.133
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.IA]     -0.0450      0.076     -0.592      0.554      -0.194       0.104
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.IA]     -0.0862      0.075     -1.150      0.250      -0.233       0.061
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.IA]      0.0506      0.074      0.682      0.496      -0.095       0.196
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.IA]    -0.0005      0.075     -0.007      0.994      -0.147       0.146
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.IA]     0.0040      0.076      0.052      0.958      -0.145       0.153
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.IA]    -0.1078      0.075     -1.437      0.151      -0.255       0.039
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.IA]     0.0083      0.076      0.108      0.914      -0.142       0.158
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.IA]     0.0112      0.075      0.151      0.880      -0.135       0.157
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.IA]    -0.0382      0.076     -0.500      0.617      -0.188       0.112
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.ID]      0.1992      0.095      2.102      0.036       0.013       0.385
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.ID]     -0.0207      0.094     -0.221      0.825      -0.204       0.163
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.ID]     -0.0312      0.095     -0.329      0.742      -0.217       0.155
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.ID]      0.1498      0.094      1.598      0.110      -0.034       0.334
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.ID]      0.0598      0.095      0.632      0.528      -0.126       0.245
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.ID]      0.1015      0.094      1.082      0.279      -0.082       0.285
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.ID]      0.2158      0.094      2.296      0.022       0.032       0.400
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.ID]     -0.0957      0.095     -1.012      0.312      -0.281       0.090
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.ID]      0.1860      0.094      1.984      0.047       0.002       0.370
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.ID]      0.0216      0.093      0.232      0.817      -0.161       0.204
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.ID]      0.0685      0.096      0.716      0.474      -0.119       0.256
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.ID]      0.1092      0.094      1.157      0.247      -0.076       0.294
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.ID]      0.0603      0.097      0.622      0.534      -0.130       0.250
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.ID]      0.1780      0.094      1.893      0.058      -0.006       0.362
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.ID]      0.1727      0.097      1.775      0.076      -0.018       0.363
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.ID]      0.1337      0.096      1.399      0.162      -0.054       0.321
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.ID]      0.1829      0.094      1.942      0.052      -0.002       0.368
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.ID]     0.1210      0.095      1.277      0.202      -0.065       0.307
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.ID]     0.1665      0.095      1.758      0.079      -0.019       0.352
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.ID]     0.0834      0.094      0.882      0.378      -0.102       0.269
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.ID]    -0.0087      0.097     -0.090      0.929      -0.198       0.181
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.ID]     0.1156      0.094      1.225      0.221      -0.069       0.301
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.ID]     0.0722      0.095      0.757      0.449      -0.115       0.259
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.IL]     -0.0253      0.075     -0.337      0.736      -0.173       0.122
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.IL]     -0.0434      0.075     -0.582      0.560      -0.189       0.103
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.IL]     -0.0803      0.075     -1.073      0.283      -0.227       0.066
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.IL]     -0.0454      0.075     -0.604      0.546      -0.193       0.102
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.IL]     -0.0846      0.075     -1.134      0.257      -0.231       0.062
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.IL]     -0.0524      0.075     -0.700      0.484      -0.199       0.094
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.IL]     -0.0533      0.075     -0.707      0.479      -0.201       0.094
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.IL]      0.0071      0.075      0.095      0.924      -0.140       0.155
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.IL]      0.0254      0.075      0.339      0.734      -0.121       0.172
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.IL]     -0.1248      0.075     -1.673      0.094      -0.271       0.021
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.IL]     -0.0292      0.075     -0.389      0.697      -0.177       0.118
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.IL]     -0.0600      0.074     -0.806      0.420      -0.206       0.086
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.IL]     -0.0455      0.075     -0.605      0.545      -0.193       0.102
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.IL]     -0.0973      0.075     -1.304      0.192      -0.243       0.049
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.IL]     -0.1234      0.076     -1.627      0.104      -0.272       0.025
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.IL]     -0.0639      0.075     -0.850      0.395      -0.211       0.083
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.IL]     -0.0585      0.074     -0.788      0.431      -0.204       0.087
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.IL]    -0.0375      0.075     -0.501      0.617      -0.184       0.109
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.IL]    -0.1244      0.076     -1.643      0.100      -0.273       0.024
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.IL]    -0.0561      0.075     -0.747      0.455      -0.203       0.091
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.IL]    -0.1206      0.075     -1.599      0.110      -0.268       0.027
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.IL]     0.0473      0.074      0.636      0.525      -0.098       0.193
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.IL]    -0.0747      0.076     -0.982      0.326      -0.224       0.074
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.IN]     -0.0722      0.074     -0.977      0.329      -0.217       0.073
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.IN]     -0.1019      0.073     -1.392      0.164      -0.245       0.042
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.IN]     -0.1300      0.074     -1.764      0.078      -0.274       0.014
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.IN]     -0.0686      0.074     -0.926      0.354      -0.214       0.077
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.IN]     -0.1628      0.074     -2.207      0.027      -0.307      -0.018
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.IN]     -0.0965      0.074     -1.307      0.191      -0.241       0.048
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.IN]     -0.0426      0.074     -0.577      0.564      -0.187       0.102
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.IN]     -0.0375      0.074     -0.506      0.613      -0.183       0.108
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.IN]     -0.0192      0.074     -0.259      0.795      -0.164       0.126
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.IN]     -0.1255      0.074     -1.703      0.089      -0.270       0.019
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.IN]     -0.0703      0.074     -0.948      0.343      -0.216       0.075
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.IN]     -0.1452      0.074     -1.972      0.049      -0.289      -0.001
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.IN]     -0.1354      0.074     -1.826      0.068      -0.281       0.010
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.IN]     -0.1438      0.074     -1.954      0.051      -0.288       0.000
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.IN]     -0.1585      0.075     -2.124      0.034      -0.305      -0.012
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.IN]     -0.0901      0.075     -1.210      0.226      -0.236       0.056
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.IN]     -0.0744      0.073     -1.015      0.310      -0.218       0.069
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.IN]    -0.0526      0.074     -0.711      0.477      -0.198       0.092
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.IN]    -0.1326      0.075     -1.777      0.076      -0.279       0.014
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.IN]    -0.0891      0.074     -1.200      0.230      -0.235       0.056
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.IN]    -0.1210      0.075     -1.608      0.108      -0.269       0.027
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.IN]    -0.0538      0.074     -0.732      0.464      -0.198       0.090
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.IN]    -0.1021      0.075     -1.364      0.173      -0.249       0.045
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.KY]      0.0286      0.074      0.389      0.697      -0.116       0.173
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.KY]     -0.1173      0.073     -1.606      0.108      -0.260       0.026
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.KY]     -0.0868      0.074     -1.172      0.241      -0.232       0.058
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.KY]     -0.0199      0.074     -0.269      0.788      -0.165       0.125
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.KY]     -0.0927      0.074     -1.260      0.208      -0.237       0.052
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.KY]     -0.0643      0.074     -0.875      0.382      -0.208       0.080
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.KY]     -0.0818      0.074     -1.107      0.268      -0.227       0.063
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.KY]     -0.0511      0.073     -0.696      0.486      -0.195       0.093
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.KY]     -0.0458      0.074     -0.621      0.535      -0.190       0.099
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.KY]     -0.1289      0.073     -1.756      0.079      -0.273       0.015
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.KY]     -0.0199      0.074     -0.270      0.787      -0.165       0.125
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.KY]     -0.1336      0.073     -1.826      0.068      -0.277       0.010
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.KY]     -0.0921      0.074     -1.252      0.211      -0.236       0.052
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.KY]     -0.1097      0.073     -1.496      0.135      -0.253       0.034
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.KY]     -0.0582      0.074     -0.782      0.434      -0.204       0.088
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.KY]     -0.0942      0.074     -1.271      0.204      -0.240       0.051
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.KY]     -0.0774      0.073     -1.060      0.289      -0.221       0.066
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.KY]    -0.0422      0.074     -0.572      0.568      -0.187       0.102
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.KY]    -0.0520      0.074     -0.701      0.483      -0.197       0.093
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.KY]    -0.0652      0.074     -0.877      0.381      -0.211       0.081
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.KY]    -0.1366      0.075     -1.813      0.070      -0.284       0.011
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.KY]    -0.0129      0.073     -0.176      0.860      -0.157       0.131
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.KY]    -0.1217      0.075     -1.627      0.104      -0.268       0.025
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MA]      0.0130      0.123      0.106      0.916      -0.228       0.255
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MA]     -0.1207      0.123     -0.984      0.325      -0.361       0.120
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MA]     -0.0799      0.123     -0.649      0.517      -0.321       0.162
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MA]     -0.0322      0.123     -0.261      0.794      -0.274       0.209
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MA]     -0.0308      0.123     -0.250      0.802      -0.272       0.210
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.MA]     -0.0232      0.123     -0.188      0.851      -0.265       0.218
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.MA]      0.0313      0.123      0.254      0.800      -0.210       0.273
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.MA]     -0.0897      0.123     -0.729      0.466      -0.331       0.152
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.MA]      0.0539      0.123      0.437      0.662      -0.188       0.295
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.MA]     -0.0273      0.123     -0.222      0.824      -0.268       0.214
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.MA]      0.0395      0.123      0.320      0.749      -0.202       0.281
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.MA]      0.0089      0.123      0.073      0.942      -0.232       0.250
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.MA]      0.0158      0.123      0.128      0.898      -0.226       0.258
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.MA]     -0.0481      0.123     -0.391      0.696      -0.289       0.193
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.MA]     -0.0132      0.124     -0.107      0.915      -0.256       0.229
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.MA]     -0.0578      0.123     -0.468      0.640      -0.300       0.184
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.MA]      0.0194      0.123      0.158      0.874      -0.221       0.260
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.MA]    -0.0136      0.123     -0.110      0.912      -0.255       0.228
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.MA]    -0.0599      0.124     -0.485      0.628      -0.302       0.182
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.MA]    -0.0967      0.123     -0.784      0.433      -0.338       0.145
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.MA]    -0.0483      0.124     -0.390      0.696      -0.291       0.194
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.MA]    -0.0084      0.123     -0.069      0.945      -0.249       0.232
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.MA]    -0.0748      0.124     -0.604      0.546      -0.317       0.168
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.MD]     -0.0220      0.106     -0.207      0.836      -0.230       0.186
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.MD]     -0.0468      0.107     -0.440      0.660      -0.256       0.162
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.MD]     -0.0718      0.106     -0.676      0.499      -0.280       0.136
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.MD]     -0.0339      0.107     -0.317      0.752      -0.244       0.176
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.MD]     -0.0367      0.106     -0.347      0.729      -0.244       0.171
# ...
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.VA]     -0.0448      0.071     -0.631      0.528      -0.184       0.094
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.VA]    -0.0810      0.073     -1.115      0.265      -0.223       0.061
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.VA]    -0.0926      0.073     -1.272      0.203      -0.235       0.050
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.VA]    -0.1259      0.073     -1.731      0.084      -0.268       0.017
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.VA]    -0.0559      0.073     -0.765      0.444      -0.199       0.087
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.VA]    -0.0144      0.072     -0.201      0.841      -0.155       0.126
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.VA]    -0.0838      0.073     -1.148      0.251      -0.227       0.059
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.VT]      0.0351      0.134      0.262      0.794      -0.228       0.298
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.VT]     -0.1291      0.134     -0.965      0.334      -0.391       0.133
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.VT]     -0.0866      0.134     -0.645      0.519      -0.350       0.176
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.VT]     -0.0260      0.134     -0.194      0.846      -0.289       0.237
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.VT]     -0.0178      0.134     -0.133      0.895      -0.281       0.245
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.VT]     -0.0957      0.134     -0.713      0.476      -0.359       0.167
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.VT]      0.0471      0.132      0.357      0.721      -0.212       0.306
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.VT]     -0.0184      0.134     -0.137      0.891      -0.281       0.244
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.VT]      0.0529      0.132      0.401      0.689      -0.206       0.312
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.VT]     -0.0597      0.132     -0.453      0.651      -0.318       0.199
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.VT]      0.1618      0.132      1.224      0.221      -0.097       0.421
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.VT]     -0.0998      0.134     -0.746      0.456      -0.362       0.163
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.VT]      0.0070      0.132      0.053      0.958      -0.252       0.266
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.VT]     -0.1202      0.134     -0.897      0.370      -0.383       0.143
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.VT]     -0.0032      0.135     -0.024      0.981      -0.267       0.261
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.VT]     -0.1429      0.132     -1.081      0.280      -0.402       0.116
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.VT]     -0.0689      0.132     -0.523      0.601      -0.327       0.189
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.VT]    -0.1230      0.132     -0.932      0.351      -0.382       0.136
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.VT]     0.0603      0.132      0.456      0.649      -0.199       0.320
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.VT]    -0.1665      0.134     -1.239      0.215      -0.430       0.097
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.VT]    -0.0004      0.133     -0.003      0.998      -0.260       0.259
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.VT]    -0.1339      0.134     -1.000      0.317      -0.396       0.129
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.VT]    -0.0522      0.133     -0.394      0.693      -0.312       0.207
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.WA]      0.0266      0.092      0.290      0.772      -0.153       0.207
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.WA]     -0.0452      0.092     -0.491      0.624      -0.226       0.135
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.WA]     -0.0546      0.093     -0.589      0.556      -0.237       0.127
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.WA]      0.0209      0.092      0.227      0.820      -0.159       0.201
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.WA]     -0.0152      0.092     -0.165      0.869      -0.195       0.165
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.WA]     -0.0293      0.092     -0.318      0.751      -0.210       0.152
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.WA]      0.0395      0.093      0.427      0.669      -0.142       0.221
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.WA]     -0.0392      0.092     -0.428      0.669      -0.219       0.140
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.WA]      0.1016      0.092      1.106      0.269      -0.078       0.282
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.WA]     -0.0172      0.092     -0.188      0.851      -0.197       0.162
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.WA]      0.0473      0.093      0.511      0.609      -0.134       0.229
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.WA]      0.0044      0.092      0.048      0.962      -0.176       0.185
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.WA]      0.0254      0.092      0.276      0.782      -0.155       0.206
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.WA]     -0.0393      0.092     -0.427      0.669      -0.220       0.141
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.WA]     -0.0381      0.093     -0.409      0.682      -0.220       0.144
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.WA]     -0.0627      0.092     -0.681      0.496      -0.243       0.118
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.WA]      0.0014      0.092      0.016      0.988      -0.179       0.182
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.WA]     0.0540      0.092      0.585      0.559      -0.127       0.235
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.WA]    -0.0086      0.092     -0.093      0.926      -0.190       0.172
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.WA]    -0.0536      0.092     -0.584      0.559      -0.233       0.126
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.WA]    -0.1233      0.094     -1.312      0.190      -0.307       0.061
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.WA]     0.0295      0.092      0.320      0.749      -0.151       0.210
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.WA]    -0.0420      0.093     -0.450      0.653      -0.225       0.141
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.WI]      0.0320      0.077      0.417      0.677      -0.118       0.182
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.WI]     -0.0494      0.076     -0.648      0.517      -0.199       0.100
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.WI]     -0.0684      0.077     -0.892      0.372      -0.219       0.082
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.WI]     -0.0292      0.077     -0.379      0.705      -0.181       0.122
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.WI]     -0.0496      0.076     -0.649      0.516      -0.199       0.100
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.WI]     -0.0188      0.077     -0.245      0.806      -0.170       0.132
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.WI]      0.0167      0.077      0.218      0.828      -0.134       0.167
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.WI]      0.0290      0.077      0.377      0.706      -0.122       0.179
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.WI]      0.0527      0.076      0.690      0.490      -0.097       0.202
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.WI]      0.0046      0.077      0.060      0.952      -0.145       0.155
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.WI]      0.0322      0.077      0.418      0.676      -0.119       0.183
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.WI]      0.0011      0.077      0.014      0.989      -0.150       0.152
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.WI]     -0.0226      0.077     -0.295      0.768      -0.173       0.128
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.WI]     -0.0405      0.077     -0.527      0.598      -0.191       0.110
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.WI]     -0.0365      0.077     -0.472      0.637      -0.188       0.115
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.WI]     -0.0279      0.078     -0.359      0.719      -0.180       0.124
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.WI]      0.0322      0.076      0.424      0.672      -0.117       0.181
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.WI]    -0.0252      0.077     -0.326      0.744      -0.176       0.126
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.WI]    -0.0141      0.077     -0.183      0.855      -0.165       0.137
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.WI]    -0.0552      0.077     -0.714      0.475      -0.207       0.096
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.WI]    -0.1559      0.077     -2.021      0.043      -0.307      -0.005
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.WI]    -0.0362      0.076     -0.475      0.635      -0.186       0.113
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.WI]    -0.0382      0.077     -0.494      0.621      -0.190       0.113
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.WV]     -0.0389      0.090     -0.435      0.664      -0.214       0.137
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.WV]     -0.0412      0.090     -0.458      0.647      -0.218       0.135
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.WV]     -0.1182      0.089     -1.325      0.185      -0.293       0.057
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.WV]     -0.0323      0.091     -0.356      0.722      -0.210       0.145
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.WV]     -0.0259      0.090     -0.288      0.773      -0.202       0.150
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.WV]      0.0364      0.090      0.403      0.687      -0.140       0.213
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.WV]      0.0121      0.091      0.133      0.894      -0.166       0.190
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.WV]      0.0408      0.092      0.445      0.656      -0.139       0.220
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.WV]     -0.0136      0.090     -0.151      0.880      -0.190       0.163
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.WV]     -0.0742      0.090     -0.821      0.412      -0.251       0.103
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.WV]      0.0467      0.090      0.517      0.606      -0.131       0.224
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.WV]     -0.0051      0.089     -0.057      0.955      -0.180       0.170
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.WV]      0.0379      0.089      0.424      0.672      -0.137       0.213
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.WV]     -0.0966      0.092     -1.054      0.292      -0.276       0.083
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.WV]     -0.0177      0.091     -0.196      0.845      -0.195       0.160
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.WV]     -0.0927      0.091     -1.016      0.309      -0.272       0.086
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.WV]      0.0573      0.089      0.642      0.521      -0.118       0.232
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.WV]    -0.0445      0.093     -0.479      0.632      -0.227       0.137
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.WV]    -0.0512      0.091     -0.562      0.574      -0.230       0.127
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.WV]    -0.0600      0.092     -0.654      0.513      -0.240       0.120
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.WV]    -0.1007      0.091     -1.112      0.266      -0.278       0.077
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.WV]    -0.0349      0.092     -0.380      0.704      -0.215       0.145
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.WV]     0.0171      0.092      0.187      0.852      -0.163       0.197
# C(time_fixed_effects)[T.(1, 2016)]:C(store_state)[T.WY]     -0.1360      0.112     -1.219      0.223      -0.355       0.083
# C(time_fixed_effects)[T.(2, 2015)]:C(store_state)[T.WY]     -0.1004      0.109     -0.924      0.355      -0.313       0.113
# C(time_fixed_effects)[T.(2, 2016)]:C(store_state)[T.WY]     -0.1865      0.110     -1.691      0.091      -0.403       0.030
# C(time_fixed_effects)[T.(3, 2015)]:C(store_state)[T.WY]     -0.1105      0.109     -1.012      0.312      -0.324       0.103
# C(time_fixed_effects)[T.(3, 2016)]:C(store_state)[T.WY]     -0.1175      0.111     -1.054      0.292      -0.336       0.101
# C(time_fixed_effects)[T.(4, 2015)]:C(store_state)[T.WY]     -0.0488      0.112     -0.438      0.662      -0.268       0.170
# C(time_fixed_effects)[T.(4, 2016)]:C(store_state)[T.WY]     -0.0625      0.110     -0.566      0.571      -0.279       0.154
# C(time_fixed_effects)[T.(5, 2015)]:C(store_state)[T.WY]     -0.2071      0.108     -1.918      0.055      -0.419       0.005
# C(time_fixed_effects)[T.(5, 2016)]:C(store_state)[T.WY]     -0.2519      0.112     -2.258      0.024      -0.471      -0.033
# C(time_fixed_effects)[T.(6, 2015)]:C(store_state)[T.WY]     -0.0685      0.109     -0.629      0.529      -0.282       0.145
# C(time_fixed_effects)[T.(6, 2016)]:C(store_state)[T.WY]      0.0469      0.110      0.425      0.671      -0.170       0.263
# C(time_fixed_effects)[T.(7, 2015)]:C(store_state)[T.WY]     -0.0974      0.109     -0.895      0.371      -0.311       0.116
# C(time_fixed_effects)[T.(7, 2016)]:C(store_state)[T.WY]     -0.1258      0.110     -1.138      0.255      -0.342       0.091
# C(time_fixed_effects)[T.(8, 2015)]:C(store_state)[T.WY]     -0.1410      0.109     -1.294      0.196      -0.355       0.073
# C(time_fixed_effects)[T.(8, 2016)]:C(store_state)[T.WY]     -0.1868      0.115     -1.622      0.105      -0.412       0.039
# C(time_fixed_effects)[T.(9, 2015)]:C(store_state)[T.WY]     -0.2648      0.108     -2.445      0.015      -0.477      -0.053
# C(time_fixed_effects)[T.(9, 2016)]:C(store_state)[T.WY]     -0.0186      0.110     -0.170      0.865      -0.234       0.197
# C(time_fixed_effects)[T.(10, 2015)]:C(store_state)[T.WY]    -0.1797      0.109     -1.646      0.100      -0.394       0.034
# C(time_fixed_effects)[T.(10, 2016)]:C(store_state)[T.WY]    -0.1966      0.113     -1.735      0.083      -0.419       0.026
# C(time_fixed_effects)[T.(11, 2015)]:C(store_state)[T.WY]    -0.1266      0.109     -1.157      0.247      -0.341       0.088
# C(time_fixed_effects)[T.(11, 2016)]:C(store_state)[T.WY]    -0.0778      0.115     -0.676      0.499      -0.303       0.148
# C(time_fixed_effects)[T.(12, 2015)]:C(store_state)[T.WY]    -0.1343      0.109     -1.234      0.217      -0.348       0.079
# C(time_fixed_effects)[T.(12, 2016)]:C(store_state)[T.WY]    -0.1016      0.112     -0.906      0.365      -0.321       0.118
# ==============================================================================
# Omnibus:                     6450.626   Durbin-Watson:                   1.390
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            48125.774
# Skew:                          -0.583   Prob(JB):                         0.00
# Kurtosis:                       8.279   Cond. No.                     1.93e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.14e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#reg3 = smf.ols(
#    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
#    data=df)
#results3 = reg3.fit(cov_type='cluster', cov_kwds={'groups': df['store_state']})

# %%
#reg4 = smf.ols(
#    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
#    data=df)
#results4 = reg4.fit(cov_type='cluster', cov_kwds={'groups': df['time_fixed_effects']})

# %%
# import scipy.stats as stats

# plt.figure(figsize=(20, 10))
# plt.title(f'Effect of WM entry on {category} prices')
# plt.xlabel('Months before/after the entry')

# coefs3 = np.exp(results3.params[2:16]) - 1
# cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs3) - 2)
# lower_CI_5_3 = coefs3 - cv_t * results3.bse[2:16]
# upper_CI_5_3 = coefs3 + cv_t * results3.bse[2:16]
# plt.plot(range(-6, 8), coefs3, color='blue', label='use_correction')
# plt.plot(range(-6, 8), lower_CI_5_3, color='lightblue', linestyle='--', label='confidence interval, 95%')
# plt.plot(range(-6, 8), upper_CI_5_3, color='lightblue', linestyle='--')


# coefs4 = np.exp(results4.params[2:16]) - 1
# cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs4) - 2)
# lower_CI_5_4 = coefs4 - cv_t * results4.bse[2:16]
# upper_CI_5_4 = coefs4 + cv_t * results4.bse[2:16]
# plt.plot(range(-6, 8), coefs4, color='pink', label='df_correction')
# plt.plot(range(-6, 8), lower_CI_5_4, color='pink', label='confidence interval, 95%')
# plt.plot(range(-6, 8), upper_CI_5_4, color='pink')

# coefs5 = np.exp(results5.params[2:16]) - 1
# cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs5) - 2)
# lower_CI_5_5 = coefs5 - cv_t * results5.bse[2:16]
# upper_CI_5_5 = coefs5 + cv_t * results5.bse[2:16]
# plt.plot(range(-6, 8), coefs5, color='darkblue', label='ø' )
# plt.plot(range(-6, 8), lower_CI_5_5, color='darkblue', label='confidence interval, 95%')
# plt.plot(range(-6, 8), upper_CI_5_5, color='darkblue')


# plt.plot([-7, 7], [0, 0], linestyle='--', color='lightgrey')
# plt.vlines(0, -0.5, 0.5, color='red', label='WM entry')
# plt.legend();
# #plt.savefig(f"./figs/{category}regression.png")

# %%
notwm_reg = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
    data=df)
notwm_results = notwm_reg.fit(cov_type='cluster', cov_kwds={'groups': df['store_state']})

# %%
wm_reg = smf.ols(
    formula='np.log(upc_price) ~ treat + C(interaction) + C(time_fixed_effects) + C(store_state) + C(time_fixed_effects)*C(store_state)',
    data=dfwm)
wm_results = wm_reg.fit(cov_type='cluster', cov_kwds={'groups': dfwm['store_state']})

# %%
# import scipy.stats as stats

# plt.figure(figsize=(20, 10))
# plt.title(f'Effect of WM entry on {category} prices')
# plt.xlabel('Months before/after the entry')


# # NOT WALMART
# start_price = hihi.upc_price[-7]

# coefs = np.exp(notwm_results.params[2:16]) - 1
# cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs) - 2)
# lower_CI_5 = coefs - cv_t * notwm_results.bse[2:16]
# upper_CI_5 = coefs + cv_t * notwm_results.bse[2:16]

# prices_minus = [start_price]
# prices = [start_price]
# prices_plus = [start_price]
# for i in range(14):
#     prices_minus.append(prices[0] * (1 + lower_CI_5[i]))
#     prices.append(prices[0] * (1 + coefs[i]))
#     prices_plus.append(prices[0] * (1 + upper_CI_5[i]))

# plt.plot(range(-7, 8), prices, '-+', color='blue', label='not-WM : price after control (regression results)')
# plt.plot(range(-7, 8), prices_minus, color='navy', linestyle='--', label='confidence interval, 95%')
# plt.plot(range(-7, 8), prices_plus, color='navy', linestyle='--')

# plt.plot(hihi.index, hihi.upc_price, '-+', color='cornflowerblue', label='not-WM : rough price (no correction)')



# # WALMART
# start_pricewm = huhu.upc_price[-7]

# coefswm = np.exp(wm_results.params[2:16]) - 1
# cv_twm = stats.t.ppf(1 - 0.005, len(dfwm) - len(coefswm) - 2)
# lower_CI_5_wm = coefswm - cv_twm * wm_results.bse[2:16]
# upper_CI_5_wm = coefswm + cv_twm * wm_results.bse[2:16]

# prices_minuswm = [start_pricewm]
# priceswm = [start_pricewm]
# prices_pluswm = [start_pricewm]
# for i in range(14):
#     prices_minuswm.append(priceswm[0] * (1 + lower_CI_5_wm[i]))
#     priceswm.append(priceswm[0] * (1 + coefswm[i]))
#     prices_pluswm.append(priceswm[0] * (1 + upper_CI_5_wm[i]))

# plt.plot(range(-7, 8), priceswm, '-+', color='limegreen', label='WM : price after control (regression results)')
# plt.plot(range(-7, 8), prices_minuswm, color='darkgreen', linestyle='--', label='confidence interval, 95%')
# plt.plot(range(-7, 8), prices_pluswm, color='darkgreen', linestyle='--')

# plt.plot(huhu.index, huhu.upc_price, '-+', color='mediumspringgreen', label='WM : rough price (no correction)')



# plt.plot([-7, 7], [start_price, start_price], linestyle='--', color='lightgrey')
# plt.vlines(0, 1.8, 2.3, color='red', label='WM entry')
# plt.legend();

# %%
import scipy.stats as stats

fig, ax = plt.subplots(1, 2, figsize=(25, 10))
fig.suptitle(f'Effect of WM entry on {category} prices')


# NOT WALMART
start_price = hihi.upc_price[-7]

coefs = np.exp(notwm_results.params[2:26]) - 1
cv_t = stats.t.ppf(1 - 0.005, len(df) - len(coefs) - 2)
lower_CI_5 = coefs - cv_t * notwm_results.bse[2:26]
upper_CI_5 = coefs + cv_t * notwm_results.bse[2:26]

prices_minus = [start_price]
prices = [start_price]
prices_plus = [start_price]
for i in range(24):
    prices_minus.append(prices[0] * (1 + lower_CI_5[i]))
    prices.append(prices[0] * (1 + coefs[i]))
    prices_plus.append(prices[0] * (1 + upper_CI_5[i]))

ax[0].set_xlabel('Months before/after the entry')
ax[0].set_ylabel('Average item price ($)')
ax[0].plot(range(-7, 18), prices, '-+', color='blue', label='not-WM : price after control (regression results)')
ax[0].plot(range(-7, 18), prices_minus, color='navy', linestyle='--', label='confidence interval, 95%')
ax[0].plot(range(-7, 18), prices_plus, color='navy', linestyle='--')
ax[0].plot(hihi.index, hihi.upc_price, '-+', color='cornflowerblue', label='not-WM : rough price (no correction)')



# WALMART
start_pricewm = huhu.upc_price[-7]

coefswm = np.exp(wm_results.params[2:26]) - 1
cv_twm = stats.t.ppf(1 - 0.005, len(dfwm) - len(coefswm) - 2)
lower_CI_5_wm = coefswm - cv_twm * wm_results.bse[2:26]
upper_CI_5_wm = coefswm + cv_twm * wm_results.bse[2:26]

prices_minuswm = [start_pricewm]
priceswm = [start_pricewm]
prices_pluswm = [start_pricewm]
for i in range(24):
    prices_minuswm.append(priceswm[0] * (1 + lower_CI_5_wm[i]))
    priceswm.append(priceswm[0] * (1 + coefswm[i]))
    prices_pluswm.append(priceswm[0] * (1 + upper_CI_5_wm[i]))

ax[1].set_xlabel('Months before/after the entry')
ax[1].set_ylabel('Average item price ($)')
ax[1].plot(range(-7, 18), priceswm, '-+', color='limegreen', label='WM : price after control (regression results)')
ax[1].plot(range(-7, 18), prices_minuswm, color='darkgreen', linestyle='--', label='confidence interval, 95%')
ax[1].plot(range(-7, 18), prices_pluswm, color='darkgreen', linestyle='--')
ax[1].plot(huhu.index, huhu.upc_price, '-+', color='mediumspringgreen', label='WM : rough price (no correction)')


a = min(np.array(priceswm).min(), np.array(prices).min()) - 0.4
b = max(np.array(priceswm).max(), np.array(prices).max()) + 0.4

ax[0].plot([-7, 18], [start_price, start_price], linestyle='--', color='lightgrey')
ax[0].vlines(0, a , b, color='red', label='WM entry')
ax[1].plot([-7, 18], [start_pricewm, start_pricewm], linestyle='--', color='lightgrey')
ax[1].vlines(0, a, b, color='red', label='WM entry')
ax[0].set_ylim((a, b))
ax[1].set_ylim((a, b))
ax[0].legend()
ax[1].legend();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -7
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/2x/jyk25dss11q4zcwpyjj6vtx40000gn/T/ipykernel_1674/3996651649.py in <module>
#      31
#      32 # WALMART
# ---> 33 start_pricewm = huhu.upc_price[-7]
#      34
#      35 coefswm = np.exp(wm_results.params[2:26]) - 1
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: -7
