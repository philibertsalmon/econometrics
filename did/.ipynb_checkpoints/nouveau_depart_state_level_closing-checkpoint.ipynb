# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen15['year'] = 2015
nielsen16['year'] = 2016

# %%
nielsen = pd.concat((nielsen15, nielsen16))
nielsen = nielsen[~nielsen.is_walmart]

# %%
## Entriy/exit dates
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# We drop the state in which we do not trust our data (some mistakes stillremain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) during the fiscal years 2015 and 2016
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]
#movements['year'] = movements.Opening_date.dt.year
#movements['month'] = movements.Opening_date.dt.month

# %%
nielsen.groupby('product_group_descr').mean().sort_values('upc_price_std', ascending=True).head(30)
# Out:
# C:\Users\inesn\AppData\Local\Temp\ipykernel_28752\742464934.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nielsen.groupby('product_group_descr').mean().sort_values('upc_price_std', ascending=True).head(30)
#                                   is_walmart  guessed_store_county_fips  \
# product_group_descr
# YEAST                                    0.0               34358.913876
# JUICES, DRINKS-FROZEN                    0.0               31276.076638
# ICE                                      0.0               29888.888000
# VEGETABLES - CANNED                      0.0               31244.049491
# PASTA                                    0.0               31698.057646
# PUDDING, DESSERTS-DAIRY                  0.0               31518.914590
# FRUIT - CANNED                           0.0               31497.732971
# DOUGH PRODUCTS                           0.0               31231.945841
# SOUP                                     0.0               31434.031000
# GUM                                      0.0               31532.015477
# EGGS                                     0.0               31345.729111
# DESSERTS, GELATINS, SYRUP                0.0               31682.336283
# MILK                                     0.0               31264.830260
# COT CHEESE, SOUR CREAM, TOPPINGS         0.0               31420.536087
# VEGETABLES-FROZEN                        0.0               31455.984284
# BAKING SUPPLIES                          0.0               31623.886590
# PREPARED FOOD-DRY MIXES                  0.0               31368.326664
# CRACKERS                                 0.0               31528.327936
# BREAKFAST FOOD                           0.0               31667.962369
# BAKING MIXES                             0.0               31368.848848
# PICKLES, OLIVES, AND RELISH              0.0               31503.006320
# SEAFOOD - CANNED                         0.0               31417.291453
# COOKIES                                  0.0               31571.239501
# CONDIMENTS, GRAVIES, AND SAUCES          0.0               31378.312830
# CEREAL                                   0.0               31589.883494
# SALAD DRESSINGS, MAYO, TOPPINGS          0.0               31464.686899
# YOGURT                                   0.0               31731.185230
# GRT CARDS/PARTY NEEDS/NOVELTIES          0.0               30358.341927
# ICE CREAM, NOVELTIES                     0.0               31437.917693
# SUGAR, SWEETENERS                        0.0               31413.855066
#
#                                   purchase_year  purchase_month  upc_price  \
# product_group_descr
# YEAST                               2015.550239        6.937799   3.457727
# JUICES, DRINKS-FROZEN               2015.491695        6.359750   1.825015
# ICE                                 2015.499846        6.668000   2.318100
# VEGETABLES - CANNED                 2015.498625        6.517163   1.038096
# PASTA                               2015.500946        6.462988   1.449016
# PUDDING, DESSERTS-DAIRY             2015.495125        6.446009   2.434284
# FRUIT - CANNED                      2015.496603        6.641208   1.654077
# DOUGH PRODUCTS                      2015.496236        6.548513   1.972625
# SOUP                                2015.497921        6.540429   1.506098
# GUM                                 2015.496877        6.441103   1.745169
# EGGS                                2015.503566        6.486635   2.238733
# DESSERTS, GELATINS, SYRUP           2015.499024        6.506341   1.636837
# MILK                                2015.496769        6.487837   2.723501
# COT CHEESE, SOUR CREAM, TOPPINGS    2015.499460        6.519845   2.233282
# VEGETABLES-FROZEN                   2015.496676        6.472504   2.072474
# BAKING SUPPLIES                     2015.496328        6.638361   1.987657
# PREPARED FOOD-DRY MIXES             2015.499310        6.451330   1.711323
# CRACKERS                            2015.497737        6.513375   2.391497
# BREAKFAST FOOD                      2015.497006        6.420365   2.557283
# BAKING MIXES                        2015.494379        6.548053   1.786729
# PICKLES, OLIVES, AND RELISH         2015.497373        6.495065   2.110917
# SEAFOOD - CANNED                    2015.493755        6.337237   1.571332
# COOKIES                             2015.498704        6.498155   2.482487
# CONDIMENTS, GRAVIES, AND SAUCES     2015.498899        6.471552   1.894580
# CEREAL                              2015.496112        6.474034   2.873315
# SALAD DRESSINGS, MAYO, TOPPINGS     2015.498747        6.457757   2.660938
# YOGURT                              2015.497655        6.424320   1.495639
# GRT CARDS/PARTY NEEDS/NOVELTIES     2015.488588        5.273457   2.681477
# ICE CREAM, NOVELTIES                2015.498786        6.473518   3.490118
# SUGAR, SWEETENERS                   2015.492973        6.670240   2.496874
#
#                                   upc_price_std  nb_of_obs         year
# product_group_descr
# YEAST                                  0.190346   1.186603  2015.550239
# JUICES, DRINKS-FROZEN                  0.440367   4.133884  2015.491695
# ICE                                    0.465500   2.631077  2015.499846
# VEGETABLES - CANNED                    0.517872  29.851215  2015.498625
# PASTA                                  0.546721  15.659901  2015.500946
# PUDDING, DESSERTS-DAIRY                0.547729   4.569520  2015.495125
# FRUIT - CANNED                         0.633034  10.802289  2015.496603
# DOUGH PRODUCTS                         0.634339   8.207640  2015.496236
# SOUP                                   0.698717  25.787703  2015.497921
# GUM                                    0.737202   6.212702  2015.496877
# EGGS                                   0.738354  18.050876  2015.503566
# DESSERTS, GELATINS, SYRUP              0.747172  13.229601  2015.499024
# MILK                                   0.779023  41.067142  2015.496769
# COT CHEESE, SOUR CREAM, TOPPINGS       0.811789  15.934220  2015.499460
# VEGETABLES-FROZEN                      0.822271  24.974953  2015.496676
# BAKING SUPPLIES                        0.824083  13.958656  2015.496328
# PREPARED FOOD-DRY MIXES                0.827380  22.465668  2015.499310
# CRACKERS                               0.829885  17.883054  2015.497737
# BREAKFAST FOOD                         0.838743  16.343905  2015.497006
# BAKING MIXES                           0.840069  10.791884  2015.494379
# PICKLES, OLIVES, AND RELISH            0.863501  10.618512  2015.497373
# SEAFOOD - CANNED                       0.868828   8.614726  2015.493755
# COOKIES                                0.905754  21.215682  2015.498704
# CONDIMENTS, GRAVIES, AND SAUCES        0.944298  31.564998  2015.498899
# CEREAL                                 0.954139  29.365974  2015.496112
# SALAD DRESSINGS, MAYO, TOPPINGS        0.959769  14.658500  2015.498747
# YOGURT                                 0.964137  41.319962  2015.497655
# GRT CARDS/PARTY NEEDS/NOVELTIES        1.023813   1.986898  2015.488588
# ICE CREAM, NOVELTIES                   1.057332  24.922868  2015.498786
# SUGAR, SWEETENERS                      1.076299   8.931382  2015.492973

# %%
categories = [
    "FRESH PRODUCE",
    "BREAD AND BAKED GOODS",
    "MILK",
    "SNACKS",
    "PACKAGED MEATS-DELI",
    "CHEESE",
    "UNPREP MEAT/POULTRY/SEAFOOD-FRZN",
    "CARBONATED BEVERAGES",
    "CONDIMENTS, GRAVIES, AND SAUCES",
    "CANDY",
    "JUICE, DRINKS - CANNED, BOTTLED",
    "EGGS",
    "CEREAL",
    "PASTA",
    "COT CHEESE, SOUR CREAM, TOPPINGS",
    "PAPER PRODUCTS",
    "YOGURT"
]

# %%
state_for_cat = {"FRESH PRODUCE" : "NC",
    "BREAD AND BAKED GOODS" : "NC",
    "MILK" : "NC",
    "SNACKS" : "NC",
    "PACKAGED MEATS-DELI" : "NC",
    "CHEESE" : "NC",
    "UNPREP MEAT/POULTRY/SEAFOOD-FRZN" : "NC",
    "CARBONATED BEVERAGES" : "NC",
    "CONDIMENTS, GRAVIES, AND SAUCES" : "NC",
    "CANDY" : "NC",
    "JUICE, DRINKS - CANNED, BOTTLED" : "NC",
    "EGGS" : "NC",
    "CEREAL" : "NC",
    "PASTA" : "NC",
    "PAPER PRODUCTS" : "NC",
    "YOGURT" : "NC"}

# %% [markdown]
# ## PREMIER MODELE

# %% [markdown]
# $$Prices_{i, t} = \alpha + \beta treat_i + \gamma treat_i* post_t$$

# %% [markdown]
# #### In a single state

# %% [markdown]
# ##### FL

# %%
state = "MS"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Closing_date>='2015-01-31' ) & (treatment_movements.Closing_date<='2017-01-31') & (treatment_movements.Opening_date<'2015-01-31')]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False

    treatment['treat'] = True
    treatment['interaction'] = (((treatment.purchase_month > treatment.Closing_date.dt.month) & (treatment.purchase_year == treatment.Closing_date.dt.year))|(treatment.purchase_year > treatment.Closing_date.dt.year))


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction', data=df)
    results0 = reg0.fit()
    #if abs(results0.params[2] / results0.bse[2]) > 1. :
    if True :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 56.
# Size of the treatment group: 5.
# =========================================================
# FRESH PRODUCE
# Coef : -0.15863411755635504
# Coef/err : 2.3844644844931904
# CI_up : -0.2701124654706356
# CI_down : -0.03012928067523568
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : -0.057529467981216276
# Coef/err : 0.8076383126825624
# CI_up : -0.18388873481234214
# CI_down : 0.08839412174946948
# Size of the control group: 55.
# Size of the treatment group: 5.
# =========================================================
# MILK
# Coef : -0.07773021423704851
# Coef/err : 1.5168122039530891
# CI_up : -0.16940438569016292
# CI_down : 0.024062182700073986
# Size of the control group: 58.
# Size of the treatment group: 5.
# =========================================================
# SNACKS
# Coef : -0.060977234090671795
# Coef/err : 0.692855284823337
# CI_up : -0.2142483933113697
# CI_down : 0.12219147551221154
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.13170246523161444
# Coef/err : 1.739628213415947
# CI_up : -0.2595669870108911
# CI_down : 0.018242833124386237
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# CHEESE
# Coef : 0.07842216988177886
# Coef/err : 1.2185644136113145
# CI_up : -0.045046421620627886
# CI_down : 0.21785435734605363
# Size of the control group: 55.
# Size of the treatment group: 5.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : 0.004640993787886849
# Coef/err : 0.06513950638502013
# CI_up : -0.12615629960163666
# CI_down : 0.15501608118133348
# Size of the control group: 56.
# Size of the treatment group: 5.
# =========================================================
# CARBONATED BEVERAGES
# Coef : -0.05255386708525933
# Coef/err : 0.47145515646137576
# CI_up : -0.24325421244169732
# CI_down : 0.18620306783793983
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : -0.028767167523416903
# Coef/err : 0.3451749030316108
# CI_up : -0.17729634515959536
# CI_down : 0.1465771536695979
# Size of the control group: 50.
# Size of the treatment group: 5.
# =========================================================
# CANDY
# Coef : -0.19722857461578014
# Coef/err : 1.3464507608604073
# CI_up : -0.41731677991748783
# CI_down : 0.10599025199688183
# Size of the control group: 53.
# Size of the treatment group: 5.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.04851170764552182
# Coef/err : 0.43108831613597287
# CI_up : -0.24131849531651506
# CI_down : 0.19329384583500087
# Size of the control group: 55.
# Size of the treatment group: 5.
# =========================================================
# EGGS
# Coef : -0.4448421337918914
# Coef/err : 4.908401517630567
# CI_up : -0.5612649157318326
# CI_down : -0.29752539182765847
# Size of the control group: 52.
# Size of the treatment group: 5.
# =========================================================
# CEREAL
# Coef : -0.2230253685808845
# Coef/err : 2.3345610093060905
# CI_up : -0.37160723825792685
# CI_down : -0.03931169385961564
# Size of the control group: 50.
# Size of the treatment group: 5.
# =========================================================
# PASTA
# Coef : -0.2860694210548286
# Coef/err : 2.3387488826901714
# CI_up : -0.46213497451387286
# CI_down : -0.05237030221044925
# Size of the control group: 46.
# Size of the treatment group: 5.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : -0.011949266306833795
# Coef/err : 0.14122492559144692
# CI_up : -0.16410009912737944
# CI_down : 0.16789612169169277
# Size of the control group: 51.
# Size of the treatment group: 5.
# =========================================================
# PAPER PRODUCTS
# Coef : 0.0293138087013618
# Coef/err : 0.18190699802277654
# CI_up : -0.24649122776603427
# CI_down : 0.406071111345113
# Size of the control group: 42.
# Size of the treatment group: 5.
# =========================================================
# YOGURT
# Coef : -0.4014534907438736
# Coef/err : 2.3352771654967963
# CI_up : -0.6114309149545027
# CI_down : -0.07800713558891048

# %% [markdown]
# ##### SC

# %%
state = "SC"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 1. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 27.
# Size of the treatment group: 9.
# Size of the control group: 28.
# Size of the treatment group: 9.
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# MILK
# Coef : -0.07800429529166508
# Coef/err : 3.4987482014331537
# CI_up : -0.11907852189898538
# CI_down : -0.035014923994007185
# Size of the control group: 27.
# Size of the treatment group: 9.
# Size of the control group: 27.
# Size of the treatment group: 9.
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# CHEESE
# Coef : -0.0947775261385293
# Coef/err : 3.2596637359269685
# CI_up : -0.14747196583965083
# CI_down : -0.03882606278052603
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : -0.048480308554737395
# Coef/err : 1.2403480695834481
# CI_up : -0.12045739164558544
# CI_down : 0.029386995704542507
# Size of the control group: 28.
# Size of the treatment group: 9.
# Size of the control group: 28.
# Size of the treatment group: 9.
# Size of the control group: 28.
# Size of the treatment group: 9.
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.08962210776411494
# Coef/err : 2.1645355424969357
# CI_up : -0.16395441264530675
# CI_down : -0.008680962847737006
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# EGGS
# Coef : -0.2892306646097331
# Coef/err : 6.0586477798779335
# CI_up : -0.36368143205146086
# CI_down : -0.20606898245977623
# Size of the control group: 28.
# Size of the treatment group: 9.
# Size of the control group: 25.
# Size of the treatment group: 9.
# =========================================================
# PASTA
# Coef : -0.06468220965239624
# Coef/err : 1.6891764532259732
# CI_up : -0.13465290905680682
# CI_down : 0.010946218109090244
# Size of the control group: 24.
# Size of the treatment group: 9.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : -0.0632910750840624
# Coef/err : 1.6368239249870278
# CI_up : -0.13397874595071557
# CI_down : 0.013166369664223465

# %% [markdown]
# ##### VA

# %%
state = "VA"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 1. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 95.
# Size of the treatment group: 10.
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : 0.07046983675354812
# Coef/err : 1.8771795873301251
# CI_up : -0.003039142388288174
# CI_down : 0.14939885819014354
# Size of the control group: 93.
# Size of the treatment group: 10.
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# SNACKS
# Coef : 0.06780540090502085
# Coef/err : 1.7355046995743726
# CI_up : -0.008492487601254872
# CI_down : 0.14997451854241306
# Size of the control group: 94.
# Size of the treatment group: 10.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.05093125217700256
# Coef/err : 1.2074275185990706
# CI_up : -0.1281850378051177
# CI_down : 0.033168191822069426
# Size of the control group: 93.
# Size of the treatment group: 10.
# Size of the control group: 93.
# Size of the treatment group: 10.
# Size of the control group: 92.
# Size of the treatment group: 10.
# Size of the control group: 94.
# Size of the treatment group: 10.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : 0.07900698231176384
# Coef/err : 1.7879912395079953
# CI_up : -0.007338429579527683
# CI_down : 0.1728630407082068
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# CANDY
# Coef : 0.1582026484737189
# Coef/err : 2.4360736765506013
# CI_up : 0.02904137066331791
# CI_down : 0.3035757484335657
# Size of the control group: 93.
# Size of the treatment group: 10.
# Size of the control group: 92.
# Size of the treatment group: 10.
# =========================================================
# EGGS
# Coef : -0.07778435050916
# Coef/err : 1.6731293808220256
# CI_up : -0.16129790488035356
# CI_down : 0.014045045451430482
# Size of the control group: 92.
# Size of the treatment group: 10.
# Size of the control group: 91.
# Size of the treatment group: 10.
# Size of the control group: 91.
# Size of the treatment group: 10.

# %% [markdown]
# ##### NC

# %%
state = "NC"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Closing_date>='2015-01-31' ) & (treatment_movements.Closing_date<='2017-01-31') & (treatment_movements.Opening_date<'2015-01-31')]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Closing_date.dt.month) & (treatment.purchase_year >= treatment.Closing_date.dt.year)


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 0. :
    #if True :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# FRESH PRODUCE
# Coef : -0.04156930545994597
# Coef/err : 1.1445176132202872
# CI_up : -0.10883189247315983
# CI_down : 0.03077005166375324
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : -0.006812994944340844
# Coef/err : 0.1818988383076487
# CI_up : -0.0773946767922119
# CI_down : 0.0691683672296235
# Size of the control group: 64.
# Size of the treatment group: 9.
# =========================================================
# MILK
# Coef : -0.018163769495236015
# Coef/err : 0.6590731056059679
# CI_up : -0.07029358914977601
# CI_down : 0.036889035378615986
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# SNACKS
# Coef : 0.003351376104518744
# Coef/err : 0.08552482374176296
# CI_up : -0.07075993989809426
# CI_down : 0.08337342217083199
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.004257207827341181
# Coef/err : 0.11221483329165714
# CI_up : -0.07581251325624971
# CI_down : 0.07283827403596654
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# CHEESE
# Coef : -0.04630971711908016
# Coef/err : 1.4415657436111688
# CI_up : -0.10589879636469768
# CI_down : 0.017250789914469156
# Size of the control group: 64.
# Size of the treatment group: 9.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : -0.013404563419534887
# Coef/err : 0.33021192031051166
# CI_up : -0.08941071479779106
# CI_down : 0.0689457599594403
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# CARBONATED BEVERAGES
# Coef : 0.08599784609847427
# Coef/err : 1.58056595427622
# CI_up : -0.019688248272838882
# CI_down : 0.20307781647278644
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : 0.007953499994671986
# Coef/err : 0.1928472422848679
# CI_up : -0.07008240167139157
# CI_down : 0.09253794097193979
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# CANDY
# Coef : 0.022658793859121173
# Coef/err : 0.35590101860470924
# CI_up : -0.09614732590275576
# CI_down : 0.15708127953701556
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.045702095706708024
# Coef/err : 1.0028238488967742
# CI_up : -0.12915201889641348
# CI_down : 0.045744504091861815
# Size of the control group: 64.
# Size of the treatment group: 9.
# =========================================================
# EGGS
# Coef : -0.2185943097311348
# Coef/err : 4.643798964626868
# CI_up : -0.29591668305497965
# CI_down : -0.13278039957841947
# Size of the control group: 65.
# Size of the treatment group: 9.
# =========================================================
# CEREAL
# Coef : -0.03105410747214543
# Coef/err : 0.982669580945954
# CI_up : -0.09019415543272213
# CI_down : 0.03193021703783372
# Size of the control group: 60.
# Size of the treatment group: 8.
# =========================================================
# PASTA
# Coef : 0.005248858432709724
# Coef/err : 0.11478300547736921
# CI_up : -0.0808035320363063
# CI_down : 0.09935721317434387
# Size of the control group: 64.
# Size of the treatment group: 8.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : 0.0658114321742942
# Coef/err : 1.6239421725186602
# CI_up : -0.013181988804494948
# CI_down : 0.15112816757087844

# %% [markdown]
# #### In all states

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 1. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 1831.
# Size of the treatment group: 91.
# =========================================================
# FRESH PRODUCE
# Coef : -0.019621247262986752
# Coef/err : 1.5430619774681942
# CI_up : -0.04399037238436332
# CI_down : 0.005369058066232002
# Size of the control group: 1836.
# Size of the treatment group: 91.
# Size of the control group: 1822.
# Size of the treatment group: 91.
# =========================================================
# MILK
# Coef : -0.0480801454734886
# Coef/err : 4.722368379334626
# CI_up : -0.06735054500610205
# CI_down : -0.028411581018183085
# Size of the control group: 1837.
# Size of the treatment group: 91.
# Size of the control group: 1816.
# Size of the treatment group: 91.
# Size of the control group: 1816.
# Size of the treatment group: 91.
# =========================================================
# CHEESE
# Coef : -0.027670775680054716
# Coef/err : 2.1548667078264567
# CI_up : -0.0521740931634157
# CI_down : -0.0025339952755394357
# Size of the control group: 1794.
# Size of the treatment group: 90.
# Size of the control group: 1815.
# Size of the treatment group: 91.
# =========================================================
# CARBONATED BEVERAGES
# Coef : -0.019389046844327407
# Coef/err : 1.029692451449872
# CI_up : -0.05526350201274499
# CI_down : 0.017847668103798675
# Size of the control group: 1821.
# Size of the treatment group: 91.
# Size of the control group: 1821.
# Size of the treatment group: 91.
# =========================================================
# CANDY
# Coef : 0.04779006551045528
# Coef/err : 2.374422961803247
# CI_up : 0.008180531567357763
# CI_down : 0.08895578421418326
# Size of the control group: 1797.
# Size of the treatment group: 90.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.01738581762418623
# Coef/err : 1.0945432057447064
# CI_up : -0.04776735480737293
# CI_down : 0.013965060198888768
# Size of the control group: 1776.
# Size of the treatment group: 91.
# =========================================================
# EGGS
# Coef : -0.18049580505156415
# Coef/err : 10.25024410695158
# CI_up : -0.2111024966644247
# CI_down : -0.14870167201884354
# Size of the control group: 1777.
# Size of the treatment group: 91.
# =========================================================
# CEREAL
# Coef : -0.0145337513179431
# Coef/err : 1.3045038953844108
# CI_up : -0.035974786418170424
# CI_down : 0.007384157187349194
# Size of the control group: 1712.
# Size of the treatment group: 90.
# =========================================================
# PASTA
# Coef : -0.03662785684714798
# Coef/err : 2.662459286757395
# CI_up : -0.06273238524386193
# CI_down : -0.009796272066444733
# Size of the control group: 1761.
# Size of the treatment group: 91.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : -0.05266226802398333
# Coef/err : 4.195494886764817
# CI_up : -0.07630534803806
# CI_down : -0.02841401482701056

# %% [markdown]
# ## DEUXIEME MODELE

# %% [markdown]
# $$Prices_{i, t} = \alpha + \beta treat_i + \gamma treat_i* post_t + \sum_{\tau=Janv15}^{Dec16}\gamma_{\tau} \cdot \mathbb{1}(t=\tau)$$

# %% [markdown]
# #### In a single state

# %% [markdown]
# ##### FL

# %%
state = "FL"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['time_effects'] = list(zip(control.purchase_year, control.purchase_month))

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)
    treatment['time_effects'] = list(zip(treatment.purchase_year, treatment.purchase_month))


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction','time_effects']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(time_effects)', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 0. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 39.
# Size of the treatment group: 10.
# =========================================================
# FRESH PRODUCE
# Coef : 0.0035982725363352674
# Coef/err : 0.1448211329637845
# CI_up : -0.04407128318419562
# CI_down : 0.05364497887763853
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : 0.016535780154484758
# Coef/err : 0.5992397389677007
# CI_up : -0.03661440111163261
# CI_down : 0.07261826783236569
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# MILK
# Coef : -0.009448272544888003
# Coef/err : 0.5853912883031741
# CI_up : -0.04047111533671077
# CI_down : 0.02257757994291043
# Size of the control group: 39.
# Size of the treatment group: 10.
# =========================================================
# SNACKS
# Coef : 0.027982765215579297
# Coef/err : 0.7939553014544407
# CI_up : -0.03979462358666419
# CI_down : 0.10054431222573634
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.06200589046535254
# Coef/err : 1.8388709479139225
# CI_up : -0.12393567893430113
# CI_down : 0.004301771417209332
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# CHEESE
# Coef : -0.009243336175628336
# Coef/err : 0.3898773636070967
# CI_up : -0.05448184173228665
# CI_down : 0.038159614735256975
# Size of the control group: 39.
# Size of the treatment group: 9.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : 0.01586350686723681
# Coef/err : 0.492548226381097
# CI_up : -0.045875445743584486
# CI_down : 0.08159742874331521
# Size of the control group: 39.
# Size of the treatment group: 10.
# =========================================================
# CARBONATED BEVERAGES
# Coef : -0.01074649219166135
# Coef/err : 0.23870733092620047
# CI_up : -0.09481900695520151
# CI_down : 0.08113461311120318
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : 0.036119779421828424
# Coef/err : 0.9337871559336516
# CI_up : -0.03832596301109059
# CI_down : 0.1163285645835932
# Size of the control group: 39.
# Size of the treatment group: 10.
# =========================================================
# CANDY
# Coef : -0.06010741320629387
# Coef/err : 1.3022633715313883
# CI_up : -0.14392565573260152
# CI_down : 0.03191747378640186
# Size of the control group: 38.
# Size of the treatment group: 9.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.0127400810727486
# Coef/err : 0.3489882736902018
# CI_up : -0.08141222088845246
# CI_down : 0.06106587708248146
# Size of the control group: 37.
# Size of the treatment group: 10.
# =========================================================
# EGGS
# Coef : 0.027781052249472582
# Coef/err : 0.9116783263324549
# CI_up : -0.03108461492555037
# CI_down : 0.09022305521742346
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# CEREAL
# Coef : 0.016968414845985436
# Coef/err : 0.6297113738166166
# CI_up : -0.03498028399456021
# CI_down : 0.07171360298769924
# Size of the control group: 38.
# Size of the treatment group: 9.
# =========================================================
# PASTA
# Coef : 0.01237938619237311
# Coef/err : 0.387828107027326
# CI_up : -0.04872827153432424
# CI_down : 0.07741246892761766
# Size of the control group: 38.
# Size of the treatment group: 10.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : 0.027673994241282918
# Coef/err : 0.9749231968762174
# CI_up : -0.027270407394612173
# CI_down : 0.0857219174458399

# %% [markdown]
# ##### SC

# %%
state = "SC"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['time_effects'] = list(zip(control.purchase_year, control.purchase_month))

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)
    treatment['time_effects'] = list(zip(treatment.purchase_year, treatment.purchase_month))


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction','time_effects']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(time_effects)', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 0. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# FRESH PRODUCE
# Coef : 0.00314638556438096
# Coef/err : 0.07677471821968783
# CI_up : -0.07428545188203084
# CI_down : 0.08705504619836923
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : -0.015679259307807447
# Coef/err : 0.46351288784097633
# CI_up : -0.0794094557521523
# CI_down : 0.05246282031762428
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# MILK
# Coef : -0.019523469493136436
# Coef/err : 0.8682142456388696
# CI_up : -0.06227941200949938
# CI_down : 0.0251819563169442
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# SNACKS
# Coef : -0.0328377722526868
# Coef/err : 0.8981633600886594
# CI_up : -0.10091639248201689
# CI_down : 0.04039576181733029
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.051111977047971435
# Coef/err : 1.215261336471939
# CI_up : -0.12822661147492542
# CI_down : 0.03282400214710357
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# CHEESE
# Coef : -0.07548254418076583
# Coef/err : 2.395293004278227
# CI_up : -0.13308703169811675
# CI_down : -0.014050363338401373
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : -0.05285204809324151
# Coef/err : 1.2739207013160738
# CI_up : -0.1288899358109561
# CI_down : 0.029823072514158833
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# CARBONATED BEVERAGES
# Coef : 0.013547294968493606
# Coef/err : 0.24697810761052436
# CI_up : -0.08928057927973532
# CI_down : 0.12798530015479703
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : -0.0464841027154409
# Coef/err : 1.217223955874934
# CI_up : -0.11695582937832283
# CI_down : 0.029611650948663026
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# CANDY
# Coef : -0.002520050188100531
# Coef/err : 0.041136621115116054
# CI_up : -0.11572445558685185
# CI_down : 0.1251767128051262
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.06443964518288514
# Coef/err : 1.4382858703511374
# CI_up : -0.14576659002854064
# CI_down : 0.02462999841550273
# Size of the control group: 27.
# Size of the treatment group: 9.
# =========================================================
# EGGS
# Coef : -0.03996656506121932
# Coef/err : 1.0395091656672315
# CI_up : -0.11115931175685534
# CI_down : 0.036928448923830404
# Size of the control group: 28.
# Size of the treatment group: 9.
# =========================================================
# CEREAL
# Coef : -0.03684738641708041
# Coef/err : 1.0327199082116307
# CI_up : -0.10320767334190983
# CI_down : 0.03442338819797719
# Size of the control group: 25.
# Size of the treatment group: 9.
# =========================================================
# PASTA
# Coef : -0.036815046467687185
# Coef/err : 0.87164093152461
# CI_up : -0.11489018055970335
# CI_down : 0.048147059647010826
# Size of the control group: 24.
# Size of the treatment group: 9.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : -0.035460585909277365
# Coef/err : 0.8310507279189966
# CI_up : -0.11436488078551099
# CI_down : 0.050473565411038424

# %% [markdown]
# ##### VA

# %%
state = "VA"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['time_effects'] = list(zip(control.purchase_year, control.purchase_month))

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)
    treatment['time_effects'] = list(zip(treatment.purchase_year, treatment.purchase_month))


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction','time_effects']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(time_effects)', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 0. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# FRESH PRODUCE
# Coef : 0.031127247591678175
# Coef/err : 0.8077557088826056
# CI_up : -0.042822368459940585
# CI_down : 0.1107900620444997
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : 0.06691290842161535
# Coef/err : 1.7365060546645
# CI_up : -0.008341931289547966
# CI_down : 0.1478786792275233
# Size of the control group: 93.
# Size of the treatment group: 10.
# =========================================================
# MILK
# Coef : -0.030917701075765414
# Coef/err : 1.1506402705031102
# CI_up : -0.08142628907605387
# CI_down : 0.022368146312032433
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# SNACKS
# Coef : 0.06216661835186765
# Coef/err : 1.5555839493950951
# CI_up : -0.015600436423068076
# CI_down : 0.14607723010522466
# Size of the control group: 94.
# Size of the treatment group: 10.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.06657740142865609
# Coef/err : 1.5514428569436873
# CI_up : -0.14443056326090464
# CI_down : 0.0183600653670557
# Size of the control group: 93.
# Size of the treatment group: 10.
# =========================================================
# CHEESE
# Coef : 0.006111424021850276
# Coef/err : 0.17564495959315826
# CI_up : -0.060057053729844045
# CI_down : 0.0769379158214718
# Size of the control group: 93.
# Size of the treatment group: 10.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : 0.021370461768105198
# Coef/err : 0.4951015670686201
# CI_up : -0.06069473693869287
# CI_down : 0.11060553070094348
# Size of the control group: 92.
# Size of the treatment group: 10.
# =========================================================
# CARBONATED BEVERAGES
# Coef : 0.08449555004627074
# Coef/err : 1.5308794925095996
# CI_up : -0.022542770509924592
# CI_down : 0.20325530630504707
# Size of the control group: 94.
# Size of the treatment group: 10.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : 0.07803681215776148
# Coef/err : 1.7184925617687188
# CI_up : -0.010556080621947461
# CI_down : 0.17456214102339906
# Size of the control group: 95.
# Size of the treatment group: 10.
# =========================================================
# CANDY
# Coef : 0.11199288236213434
# Coef/err : 1.7244810477785146
# CI_up : -0.014469197884731444
# CI_down : 0.2546824186215768
# Size of the control group: 93.
# Size of the treatment group: 10.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : 0.03922064562566452
# Coef/err : 0.878301540901082
# CI_up : -0.04632778656278025
# CI_down : 0.13244313410597042
# Size of the control group: 92.
# Size of the treatment group: 10.
# =========================================================
# EGGS
# Coef : 0.050593286039876784
# Coef/err : 1.2752544668233374
# CI_up : -0.026203027423033154
# CI_down : 0.1334459684663154
# Size of the control group: 92.
# Size of the treatment group: 10.
# =========================================================
# CEREAL
# Coef : 0.040236964111354245
# Coef/err : 1.1307871098557434
# CI_up : -0.02855640001984816
# CI_down : 0.1139019717930263
# Size of the control group: 91.
# Size of the treatment group: 10.
# =========================================================
# PASTA
# Coef : -0.014131718550196903
# Coef/err : 0.3427915949131053
# CI_up : -0.09123925608103978
# CI_down : 0.06951832467739338
# Size of the control group: 91.
# Size of the treatment group: 10.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : -0.03521546598983538
# Coef/err : 0.9160197031163576
# CI_up : -0.10650862444513354
# CI_down : 0.0417662917979138

# %% [markdown]
# ##### NC

# %%
state = "MS"

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Closing_date>='2015-01-31' ) & (treatment_movements.Closing_date<='2017-01-31') & (treatment_movements.Opening_date<'2015-01-31')]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False
    control['time_effects'] = list(zip(control.purchase_year, control.purchase_month))

    treatment['treat'] = True
    treatment['interaction'] = (((treatment.purchase_month > treatment.Closing_date.dt.month) & (treatment.purchase_year == treatment.Closing_date.dt.year))|(treatment.purchase_year > treatment.Closing_date.dt.year))
    treatment['time_effects'] = list(zip(treatment.purchase_year, treatment.purchase_month))


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction','time_effects']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(time_effects)', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 0. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 56.
# Size of the treatment group: 5.
# =========================================================
# FRESH PRODUCE
# Coef : -0.07963698379598305
# Coef/err : 1.0902305422919254
# CI_up : -0.20732890842098595
# CI_down : 0.06862491971137952
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# BREAD AND BAKED GOODS
# Coef : -0.06733078204930287
# Coef/err : 0.8930205295783119
# CI_up : -0.1997807761696715
# CI_down : 0.08704195576436824
# Size of the control group: 55.
# Size of the treatment group: 5.
# =========================================================
# MILK
# Coef : -0.020895877882021074
# Coef/err : 0.37656357005327973
# CI_up : -0.12293749948127286
# CI_down : 0.09301775116532762
# Size of the control group: 58.
# Size of the treatment group: 5.
# =========================================================
# SNACKS
# Coef : -0.10476915784685081
# Coef/err : 1.1462711024335495
# CI_up : -0.2592944846933263
# CI_down : 0.08199310546569616
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# PACKAGED MEATS-DELI
# Coef : -0.05088942207945313
# Coef/err : 0.6077918339663326
# CI_up : -0.19817532508465763
# CI_down : 0.12345119488344913
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# CHEESE
# Coef : 0.1828307323040479
# Coef/err : 2.5629730835355353
# CI_up : 0.04011873239927377
# CI_down : 0.34512387644015363
# Size of the control group: 55.
# Size of the treatment group: 5.
# =========================================================
# UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# Coef : 0.07656936746263754
# Coef/err : 0.980181627352534
# CI_up : -0.07126212214852645
# CI_down : 0.24793187679619355
# Size of the control group: 56.
# Size of the treatment group: 5.
# =========================================================
# CARBONATED BEVERAGES
# Coef : -0.02360395206228738
# Coef/err : 0.1951793303725205
# CI_up : -0.23210270306195258
# CI_down : 0.24150618348289177
# Size of the control group: 57.
# Size of the treatment group: 5.
# =========================================================
# CONDIMENTS, GRAVIES, AND SAUCES
# Coef : -0.048204618634225094
# Coef/err : 0.552712766281827
# CI_up : -0.20136340673643627
# CI_down : 0.1343262450412832
# Size of the control group: 50.
# Size of the treatment group: 5.
# =========================================================
# CANDY
# Coef : -0.185151516060582
# Coef/err : 1.1837893135328679
# CI_up : -0.4198467699692481
# CI_down : 0.14448738265780725
# Size of the control group: 53.
# Size of the treatment group: 5.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.05331524624328543
# Coef/err : 0.4514139472738108
# CI_up : -0.2540221829674826
# CI_down : 0.20139232364914283
# Size of the control group: 55.
# Size of the treatment group: 5.
# =========================================================
# EGGS
# Coef : -0.14296201984379975
# Coef/err : 1.6274252393449933
# CI_up : -0.28848938206579056
# CI_down : 0.03233048237958558
# Size of the control group: 52.
# Size of the treatment group: 5.
# =========================================================
# CEREAL
# Coef : -0.2141243881628193
# Coef/err : 2.1543891505856423
# CI_up : -0.369083344157612
# CI_down : -0.021106081823351608
# Size of the control group: 50.
# Size of the treatment group: 5.
# =========================================================
# PASTA
# Coef : -0.2363140874962233
# Coef/err : 1.7865101882155083
# CI_up : -0.4323442654977211
# CI_down : 0.02741175242084104
# Size of the control group: 46.
# Size of the treatment group: 5.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : 0.04836825692026636
# Coef/err : 0.5127377832693785
# CI_up : -0.12520464359750372
# CI_down : 0.2563806998677629
# Size of the control group: 51.
# Size of the treatment group: 5.
# =========================================================
# PAPER PRODUCTS
# Coef : 0.0937249854663933
# Coef/err : 0.5280526358616804
# CI_up : -0.2162057724751112
# CI_down : 0.5262096884931151
# Size of the control group: 42.
# Size of the treatment group: 5.
# =========================================================
# YOGURT
# Coef : -0.38251467160480834
# Coef/err : 2.057175913350835
# CI_up : -0.6104845809774234
# CI_down : -0.021121855098583553

# %% [markdown]
# #### In all states

# %%
# We choose to focus on milk prices
for category in categories:
    product_group = nielsen[(nielsen.product_group_descr == category)]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))]

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


    # We create our dummies for the regression
    control['treat'] = False
    control['interaction'] = False

    treatment['treat'] = True
    treatment['interaction'] = (treatment.purchase_month > treatment.Opening_date.dt.month) & (treatment.purchase_year >= treatment.Opening_date.dt.year)


    # Final dataset for the regression :

    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction']]
    df = df[df.upc_price != 0]
    reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction', data=df)
    results0 = reg0.fit()
    if abs(results0.params[2] / results0.bse[2]) > 1. :
        print("=========================================================")
        print(category)
        print(f"Coef : {np.exp(results0.params[2])-1}")
        print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
        print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
        print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 1831.
# Size of the treatment group: 91.
# =========================================================
# FRESH PRODUCE
# Coef : -0.019621247262986752
# Coef/err : 1.5430619774681942
# CI_up : -0.04399037238436332
# CI_down : 0.005369058066232002
# Size of the control group: 1836.
# Size of the treatment group: 91.
# Size of the control group: 1822.
# Size of the treatment group: 91.
# =========================================================
# MILK
# Coef : -0.0480801454734886
# Coef/err : 4.722368379334626
# CI_up : -0.06735054500610205
# CI_down : -0.028411581018183085
# Size of the control group: 1837.
# Size of the treatment group: 91.
# Size of the control group: 1816.
# Size of the treatment group: 91.
# Size of the control group: 1816.
# Size of the treatment group: 91.
# =========================================================
# CHEESE
# Coef : -0.027670775680054716
# Coef/err : 2.1548667078264567
# CI_up : -0.0521740931634157
# CI_down : -0.0025339952755394357
# Size of the control group: 1794.
# Size of the treatment group: 90.
# Size of the control group: 1815.
# Size of the treatment group: 91.
# =========================================================
# CARBONATED BEVERAGES
# Coef : -0.019389046844327407
# Coef/err : 1.029692451449872
# CI_up : -0.05526350201274499
# CI_down : 0.017847668103798675
# Size of the control group: 1821.
# Size of the treatment group: 91.
# Size of the control group: 1821.
# Size of the treatment group: 91.
# =========================================================
# CANDY
# Coef : 0.04779006551045528
# Coef/err : 2.374422961803247
# CI_up : 0.008180531567357763
# CI_down : 0.08895578421418326
# Size of the control group: 1797.
# Size of the treatment group: 90.
# =========================================================
# JUICE, DRINKS - CANNED, BOTTLED
# Coef : -0.01738581762418623
# Coef/err : 1.0945432057447064
# CI_up : -0.04776735480737293
# CI_down : 0.013965060198888768
# Size of the control group: 1776.
# Size of the treatment group: 91.
# =========================================================
# EGGS
# Coef : -0.18049580505156415
# Coef/err : 10.25024410695158
# CI_up : -0.2111024966644247
# CI_down : -0.14870167201884354
# Size of the control group: 1777.
# Size of the treatment group: 91.
# =========================================================
# CEREAL
# Coef : -0.0145337513179431
# Coef/err : 1.3045038953844108
# CI_up : -0.035974786418170424
# CI_down : 0.007384157187349194
# Size of the control group: 1712.
# Size of the treatment group: 90.
# =========================================================
# PASTA
# Coef : -0.03662785684714798
# Coef/err : 2.662459286757395
# CI_up : -0.06273238524386193
# CI_down : -0.009796272066444733
# Size of the control group: 1761.
# Size of the treatment group: 91.
# =========================================================
# COT CHEESE, SOUR CREAM, TOPPINGS
# Coef : -0.05266226802398333
# Coef/err : 4.195494886764817
# CI_up : -0.07630534803806
# CI_down : -0.02841401482701056

# %% [markdown]
# ### Build a better control group

# %% [markdown]
# ##### NC

# %%
state = "NC"
category = "MILK"

# %%
product_group = nielsen[(nielsen.product_group_descr == category)&(nielsen.store_state == state)]


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Closing_date>='2015-01-31' ) & (treatment_movements.Closing_date<='2017-01-31') & (treatment_movements.Opening_date<'2015-01-31')]

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")


# We create our dummies for the regression
control['treat'] = False
control['interaction'] = False
control['time_effects'] = list(zip(control.purchase_year, control.purchase_month))

treatment['treat'] = True
treatment['interaction'] = (treatment.purchase_month > treatment.Closing_date.dt.month) & (treatment.purchase_year >= treatment.Closing_date.dt.year)
treatment['time_effects'] = list(zip(treatment.purchase_year, treatment.purchase_month))


# Final dataset for the regression :

df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction','time_effects']]
df = df[df.upc_price != 0]
reg0 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(time_effects)', data=df)
results0 = reg0.fit()
y_hat = results0.fittedvalues
u_hat = results0.resid
#pd.set_option("display.max_rows", None)
#y_hat.shape[0]
plt.plot(np.arange(1, 1528), np.log(df['upc_price']), color='grey', marker='o', linestyle='')
plt.plot(np.arange(1, 1528), results0.fittedvalues, color='black', linestyle='-')
plt.ylabel('upc_price')
plt.xlabel('observation')
#if abs(results0.params[2] / results0.bse[2]) > 0. :
#    print("=========================================================")
#    print(category)
#    print(f"Coef : {np.exp(results0.params[2])-1}")
#    print(f"Coef/err : {abs(results0.params[2] / results0.bse[2])}")
#    print(f"CI_up : {np.exp(results0.conf_int(alpha=0.05)[0][2])-1}")
#    print(f"CI_down : {np.exp(results0.conf_int(alpha=0.05)[1][2])-1}")
# Out:
# Size of the control group: 64.
# Size of the treatment group: 9.
# Text(0.5, 0, 'observation')

# %%
results0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      np.log(upc_price)   R-squared:                       0.090
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     5.918
# Date:                Fri, 04 Nov 2022   Prob (F-statistic):           2.29e-18
# Time:                        14:27:17   Log-Likelihood:                 393.36
# No. Observations:                1527   AIC:                            -734.7
# Df Residuals:                    1501   BIC:                            -596.1
# Df Model:                          25
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         1.1508      0.023     49.617      0.000       1.105       1.196
# treat[T.True]                    -0.0284      0.020     -1.455      0.146      -0.067       0.010
# interaction[T.True]               0.0668      0.029      2.326      0.020       0.010       0.123
# C(time_effects)[T.(2015, 2)]     -0.0893      0.033     -2.720      0.007      -0.154      -0.025
# C(time_effects)[T.(2015, 3)]     -0.1330      0.033     -4.035      0.000      -0.198      -0.068
# C(time_effects)[T.(2015, 4)]     -0.1343      0.033     -4.089      0.000      -0.199      -0.070
# C(time_effects)[T.(2015, 5)]     -0.1376      0.033     -4.155      0.000      -0.202      -0.073
# C(time_effects)[T.(2015, 6)]     -0.1363      0.033     -4.149      0.000      -0.201      -0.072
# C(time_effects)[T.(2015, 7)]     -0.1368      0.033     -4.149      0.000      -0.201      -0.072
# C(time_effects)[T.(2015, 8)]     -0.1114      0.033     -3.364      0.001      -0.176      -0.046
# C(time_effects)[T.(2015, 9)]     -0.1033      0.033     -3.145      0.002      -0.168      -0.039
# C(time_effects)[T.(2015, 10)]    -0.1145      0.033     -3.458      0.001      -0.179      -0.050
# C(time_effects)[T.(2015, 11)]    -0.1268      0.033     -3.861      0.000      -0.191      -0.062
# C(time_effects)[T.(2015, 12)]    -0.0962      0.032     -2.961      0.003      -0.160      -0.032
# C(time_effects)[T.(2016, 1)]     -0.1428      0.033     -4.296      0.000      -0.208      -0.078
# C(time_effects)[T.(2016, 2)]     -0.1816      0.033     -5.468      0.000      -0.247      -0.116
# C(time_effects)[T.(2016, 3)]     -0.1897      0.033     -5.713      0.000      -0.255      -0.125
# C(time_effects)[T.(2016, 4)]     -0.2368      0.034     -7.047      0.000      -0.303      -0.171
# C(time_effects)[T.(2016, 5)]     -0.2084      0.034     -6.196      0.000      -0.274      -0.142
# C(time_effects)[T.(2016, 6)]     -0.2226      0.034     -6.627      0.000      -0.289      -0.157
# C(time_effects)[T.(2016, 7)]     -0.2599      0.033     -7.857      0.000      -0.325      -0.195
# C(time_effects)[T.(2016, 8)]     -0.2037      0.033     -6.115      0.000      -0.269      -0.138
# C(time_effects)[T.(2016, 9)]     -0.2127      0.033     -6.379      0.000      -0.278      -0.147
# C(time_effects)[T.(2016, 10)]    -0.1980      0.034     -5.868      0.000      -0.264      -0.132
# C(time_effects)[T.(2016, 11)]    -0.1923      0.033     -5.749      0.000      -0.258      -0.127
# C(time_effects)[T.(2016, 12)]    -0.0510      0.033     -1.538      0.124      -0.116       0.014
# ==============================================================================
# Omnibus:                      425.557   Durbin-Watson:                   1.139
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2814.983
# Skew:                          -1.130   Prob(JB):                         0.00
# Kurtosis:                       9.256   Cond. No.                         24.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
