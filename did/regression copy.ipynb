# %% [markdown]
# Reression code
# ===

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
# TODO change path
nielsen15 = pd.read_csv('../../Nielsen/aggregated_nielsen_2015.csv')
nielsen16 = pd.read_csv('../..//Nielsen/aggregated_nielsen_2016.csv')
nielsen = pd.concat((nielsen15, nielsen16))

# %%
nielsen.groupby('product_group_descr').sum().describe()
# Out:
#          is_walmart  guessed_store_county_fips  purchase_year  purchase_month  \
# count    118.000000               1.180000e+02   1.180000e+02      118.000000
# mean   23712.974576               1.506986e+09   1.000581e+08   322919.830508
# std    10426.284581               7.169996e+08   4.723022e+07   152046.502040
# min       12.000000               7.919545e+06   4.696210e+05     1603.000000
# 25%    16560.000000               9.821765e+08   6.585168e+07   213015.750000
# 50%    27509.000000               1.653639e+09   1.097099e+08   354036.500000
# 75%    31931.000000               2.105430e+09   1.386709e+08   448288.750000
# max    37170.000000               2.674661e+09   1.776402e+08   571912.000000
#
#            upc_price  upc_price_std     nb_of_obs
# count     118.000000     118.000000  1.180000e+02
# mean   203797.895377   81332.492577  7.771850e+05
# std    136847.473231   78607.989070  1.197041e+06
# min       793.045000       5.329678  2.730000e+02
# 25%    117776.331412   38412.092640  1.269560e+05
# 50%    180256.745927   61524.760399  3.885490e+05
# 75%    259382.773406  105286.743333  7.876950e+05
# max    820665.462272  553743.029262  9.750427e+06

# %%
# Selecting Walmart concurents
nielsen = nielsen[~nielsen.is_walmart]

# %%
# Importing entries/exits data
# TODO change path
fandom = pd.read_csv('../data_collection/plein_de_data/fandom_traitées.csv', parse_dates=['Opening_date', 'Closing_date'])[['State', 'County_name', 'County_fips', 'Opening_date', 'Closing_date']]

# Droping the state in which we do not trust our data (some mistakes still,remain)
fandom = fandom[~np.isin(fandom.State, ('CA', 'GA', 'KS', 'LA', 'TX'))]
nielsen = nielsen[~np.isin(nielsen.store_state, ('CA', 'GA', 'KS', 'LA', 'TX'))]

# We concentrate our study on the movements (entries & exits) that happened between 2014 and 2017 (fiscal year). We add 2014 and 2017 to eliminate side effects.
movements = fandom[((fandom.Opening_date >= '2015-01-31') & (fandom.Opening_date <= '2017-01-31')) | ((fandom.Closing_date >= '2015-01-31') & (fandom.Closing_date <= '2017-01-31'))]

# %%
# Dropping the observations around the opening date (0, 1, 3, 5, 7, 9 , 11)
dropping_period = 5

# %% [markdown]
# ## 1. Entries

# %% [markdown]
# ### A) Pooled values

# %%
# Taking the average price per category to have a first overview of the effect
pool = pd.DataFrame(nielsen.groupby(['is_walmart', 'store_state', 'guessed_store_county', 'guessed_store_county_fips', 'purchase_year', 'purchase_month']).mean()['upc_price']).reset_index()

# %%
print("=========================================================")
print("ENTRY - Pooled results")
print('---------------------------------------------------------')

product_group = pool


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()

# We keep in the control group the only counties where we have data for the entire time period (24 months)
nb_months = control.groupby('guessed_store_county_fips').count()
control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")



# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))] # Treatment group composed by the entries

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



# Creating the dummies
control['treat'] = False
control['interaction'] = False
control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015) # Creating one unique time variable
control['effects'] = list(zip(control.store_state, control.purchase_0)) # Crontrolling for time * state

treatment['treat'] = True
treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015) # Creating one unique time variable
treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0 # The post dummy equals to one in the treatment group, after the opening month
treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) > dropping_period]
treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0)) # Crontrolling for time * state



# Final dataset for the regression :
df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects']]
df = df[df.upc_price != 0] # Dropping the errors in the set


reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
results1 = reg1.fit()

print(f"Coef : {np.exp(results1.params[2])-1}")
print(f"pvalue : { results1.pvalues[2]}")
print(f"Std err : { results1.bse[2]}")
print(f"R2 : { results1.rsquared}")
print(f"N : { results1.nobs}")
# Out:
# =========================================================
# ENTRY - Pooled results
# ---------------------------------------------------------
# Size of the control group: 1457.
# Size of the treatment group: 91.
# Coef : 0.029341900413080824
# pvalue : 0.03977734141684591
# Std err : 0.01406509590724859
# R2 : 0.1578651149374708
# N : 36234.0

# %% [markdown]
# ### B) Other categories

# %%
# Focusing on the categories with the highest number of observations
categories_count = nielsen.groupby('product_group_descr').count()
categories = categories_count[categories_count.is_walmart>=25000].index

# It could be :
# categories = nielsen.product_group_descr.unique()

# %%
data = []

for category in categories:
    print("=========================================================")
    print(f"ENTRY - {category}")
    print('---------------------------------------------------------')

    product_group = nielsen[nielsen.product_group_descr == category]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()

    # Keeping in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]

    # Keeping in the control group the only counties where 4 observations per month and category at least
    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Opening_date>='2015-01-31' ) & (treatment_movements.Opening_date<='2017-01-31') & ((treatment_movements.Closing_date>'2017-01-31') | (treatment_movements.Closing_date.apply(str) == 'NaT'))] # Treatment group composed by the entries

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # Creating the dummies
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015) # Creating one unique time variable
    control['effects'] = list(zip(control.store_state, control.purchase_0)) # Crontrolling for time * state

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015) # Creating one unique time variable
    treatment['opening_0'] = treatment.Opening_date.dt.month  + 12 * (treatment.Opening_date.dt.year - 2015)
    treatment['interaction'] = treatment.purchase_0 >= treatment.opening_0 # The post dummy equals to one in the treatment group, after the opening month
    treatment = treatment[abs(treatment.purchase_0-treatment.opening_0) > dropping_period]
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0)) # Crontrolling for time * state



    # Final dataset for the regression :
    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects']]
    df = df[df.upc_price != 0] # Dropping the errors in the set


    try:
        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
        results1 = reg1.fit()

        print(f"Coef : {np.exp(results1.params[2])-1}")
        print(f"Rapport: {results1.params[2]/results1.bse[2]} ")
        print(f"pvalue : { results1.pvalues[2]}")
        print(f"Std err : { results1.bse[2]}")
        print(f"R2 : { results1.rsquared}")
        print(f"N : { results1.nobs}")

    except:
        print('Method does not converge')

    if abs(results1.params[2]/results1.bse[2]) > 2.:
        data.append([category, np.exp(results1.params[2])-1, results1.bse[2], results1.pvalues[2], results1.rsquared, results1.nobs])

print(data)
# Out:
# =========================================================
# ENTRY - BAKED GOODS-FROZEN
# ---------------------------------------------------------
# Size of the control group: 118.
# Size of the treatment group: 89.
# Coef : -0.007435005539790707
# Rapport: -0.43005065876054466
# pvalue : 0.6671896897021575
# Std err : 0.01735326480876145
# R2 : 0.3911374760510232
# N : 3910.0
# =========================================================
# ENTRY - BAKING MIXES
# ---------------------------------------------------------
# Size of the control group: 209.
# Size of the treatment group: 91.
# Coef : 0.018738614544618892
# Rapport: 1.1525473486290227
# pvalue : 0.24914906265559905
# Std err : 0.016107979967543717
# R2 : 0.35539658038577016
# N : 6153.0
# =========================================================
# ENTRY - BAKING SUPPLIES
# ---------------------------------------------------------
# Size of the control group: 256.
# Size of the treatment group: 91.
# Coef : -0.018782851033047776
# Rapport: -1.4663504380069932
# pvalue : 0.14260246024067363
# Std err : 0.012931076169971106
# R2 : 0.27664711028560507
# N : 7290.0
# =========================================================
# ENTRY - BREAD AND BAKED GOODS
# ---------------------------------------------------------
# Size of the control group: 833.
# Size of the treatment group: 91.
# Coef : 0.00557501892822021
# Rapport: 0.5137064845539167
# pvalue : 0.6074628381114029
# Std err : 0.010822397995112336
# R2 : 0.26584518630574294
# N : 21241.0
# =========================================================
# ENTRY - BREAKFAST FOOD
# ---------------------------------------------------------
# Size of the control group: 269.
# Size of the treatment group: 91.
# Coef : 0.0009255744606442295
# Rapport: 0.08379756453787691
# pvalue : 0.9332199239064929
# Std err : 0.011040253804884529
# R2 : 0.2749239384430059
# N : 7564.0
# =========================================================
# ENTRY - BUTTER AND MARGARINE
# ---------------------------------------------------------
# Size of the control group: 325.
# Size of the treatment group: 91.
# Coef : 0.02555957645714102
# Rapport: 2.1911672072843817
# pvalue : 0.02846862893561889
# Std err : 0.011518240959760402
# R2 : 0.3640509968631248
# N : 8986.0
# =========================================================
# ENTRY - CANDY
# ---------------------------------------------------------
# Size of the control group: 508.
# Size of the treatment group: 91.
# Coef : 0.03418941652907859
# Rapport: 2.3614258938985713
# pvalue : 0.01822023266623719
# Std err : 0.01423629152571466
# R2 : 0.2520410061663845
# N : 13408.0
# =========================================================
# ENTRY - CARBONATED BEVERAGES
# ---------------------------------------------------------
# Size of the control group: 574.
# Size of the treatment group: 91.
# Coef : -0.022996330216423777
# Rapport: -1.5910047070247824
# pvalue : 0.11163116746270371
# Std err : 0.014622754205610872
# R2 : 0.21564724101839272
# N : 15002.0
# =========================================================
# ENTRY - CEREAL
# ---------------------------------------------------------
# Size of the control group: 465.
# Size of the treatment group: 91.
# Coef : 0.008998763184582259
# Rapport: 1.0136886893021682
# pvalue : 0.3107528988469059
# Std err : 0.008837541231243641
# R2 : 0.18510358422591622
# N : 12379.0
# =========================================================
# ENTRY - CHEESE
# ---------------------------------------------------------
# Size of the control group: 687.
# Size of the treatment group: 91.
# Coef : 0.004994719444018747
# Rapport: 0.5477376002560013
# pvalue : 0.5838794150262532
# Std err : 0.009096120497019487
# R2 : 0.2513750799822424
# N : 17737.0
# =========================================================
# ENTRY - COFFEE
# ---------------------------------------------------------
# Size of the control group: 284.
# Size of the treatment group: 91.
# Coef : 0.02148786647635026
# Rapport: 1.7977835902335777
# pvalue : 0.07225468968280564
# Std err : 0.01182581550801035
# R2 : 0.22434602427109074
# N : 7967.0
# =========================================================
# ENTRY - CONDIMENTS, GRAVIES, AND SAUCES
# ---------------------------------------------------------
# Size of the control group: 530.
# Size of the treatment group: 91.
# Coef : 0.028135853441919156
# Rapport: 2.5431672852031824
# pvalue : 0.010996827638233482
# Std err : 0.01091053334028538
# R2 : 0.23219599092555376
# N : 13957.0
# =========================================================
# ENTRY - COOKIES
# ---------------------------------------------------------
# Size of the control group: 357.
# Size of the treatment group: 91.
# Coef : 0.05206530665042819
# Rapport: 4.768909403025123
# pvalue : 1.882195371728973e-06
# Std err : 0.010642934613430369
# R2 : 0.2518094553433209
# N : 9752.0
# =========================================================
# ENTRY - COT CHEESE, SOUR CREAM, TOPPINGS
# ---------------------------------------------------------
# Size of the control group: 356.
# Size of the treatment group: 91.
# Coef : -0.03697438396875308
# Rapport: -3.6789544543329606
# pvalue : 0.0002356045806953113
# Std err : 0.010240753933033059
# R2 : 0.3286980877863015
# N : 9738.0
# =========================================================
# ENTRY - CRACKERS
# ---------------------------------------------------------
# Size of the control group: 340.
# Size of the treatment group: 91.
# Coef : 0.02262377451357267
# Rapport: 2.0910866805756467
# pvalue : 0.036550451414702666
# Std err : 0.010698577292652285
# R2 : 0.26048759318323356
# N : 9337.0
# =========================================================
# ENTRY - DESSERTS, GELATINS, SYRUP
# ---------------------------------------------------------
# Size of the control group: 251.
# Size of the treatment group: 91.
# Coef : -0.01449091315051887
# Rapport: -0.9038458954106948
# pvalue : 0.36611249483371744
# Std err : 0.016149801596233155
# R2 : 0.2847107299955134
# N : 7131.0
# =========================================================
# ENTRY - DETERGENTS
# ---------------------------------------------------------
# Size of the control group: 239.
# Size of the treatment group: 91.
# Coef : 0.0012893978253649685
# Rapport: 0.0740095195560515
# pvalue : 0.9410053173362218
# Std err : 0.017410831384793237
# R2 : 0.26909032656223053
# N : 6854.0
# =========================================================
# ENTRY - DOUGH PRODUCTS
# ---------------------------------------------------------
# Size of the control group: 126.
# Size of the treatment group: 91.
# Coef : 0.022270533228686995
# Rapport: 1.517777945395829
# pvalue : 0.1291691681916036
# Std err : 0.014512113867532704
# R2 : 0.4522870304602594
# N : 4121.0
# =========================================================
# ENTRY - DRESSINGS/SALADS/PREP FOODS-DELI
# ---------------------------------------------------------
# Size of the control group: 541.
# Size of the treatment group: 91.
# Coef : 0.02748297305233116
# Rapport: 2.100347420818731
# pvalue : 0.035717242784549734
# Std err : 0.012908386366752863
# R2 : 0.19471741327713987
# N : 14227.0
# =========================================================
# ENTRY - EGGS
# ---------------------------------------------------------
# Size of the control group: 415.
# Size of the treatment group: 91.
# Coef : -0.007865684690784747
# Rapport: -0.6602601628631604
# pvalue : 0.5091019083580617
# Std err : 0.0119601072573831
# R2 : 0.7543703222941702
# N : 11173.0
# =========================================================
# ENTRY - FRESH PRODUCE
# ---------------------------------------------------------
# Size of the control group: 959.
# Size of the treatment group: 91.
# Coef : -7.324559791943575e-05
# Rapport: -0.007400886931576171
# pvalue : 0.9940950640273005
# Std err : 0.00989723004640917
# R2 : 0.16952582738325261
# N : 24281.0
# =========================================================
# ENTRY - FRUIT - CANNED
# ---------------------------------------------------------
# Size of the control group: 178.
# Size of the treatment group: 91.
# Coef : -0.008368381379066259
# Rapport: -0.579537921113641
# pvalue : 0.5622559373906519
# Std err : 0.014500505585652032
# R2 : 0.31241551025993597
# N : 5374.0
# =========================================================
# ENTRY - ICE CREAM, NOVELTIES
# ---------------------------------------------------------
# Size of the control group: 376.
# Size of the treatment group: 91.
# Coef : -0.012238947283573554
# Rapport: -1.4010069498368858
# pvalue : 0.1612457276887199
# Std err : 0.008789720824229423
# R2 : 0.31843756232587117
# N : 10231.0
# =========================================================
# ENTRY - JAMS, JELLIES, SPREADS
# ---------------------------------------------------------
# Size of the control group: 237.
# Size of the treatment group: 91.
# Coef : -0.011634973347597
# Rapport: -0.7994042587076887
# pvalue : 0.4240885593044994
# Std err : 0.014639888599412669
# R2 : 0.2771154861686099
# N : 6816.0
# =========================================================
# ENTRY - JUICE, DRINKS - CANNED, BOTTLED
# ---------------------------------------------------------
# Size of the control group: 499.
# Size of the treatment group: 90.
# Coef : -0.017848849938176814
# Rapport: -1.6239227979794317
# pvalue : 0.10441819694528677
# Std err : 0.011090466776760746
# R2 : 0.22112799537571026
# N : 13200.0
# =========================================================
# ENTRY - MEDICATIONS/REMEDIES/HEALTH AIDS
# ---------------------------------------------------------
# Size of the control group: 339.
# Size of the treatment group: 91.
# Coef : 0.023851236796023523
# Rapport: 0.8055862682564283
# pvalue : 0.42050450422745766
# Std err : 0.02925973347123541
# R2 : 0.14892292164719412
# N : 9302.0
# =========================================================
# ENTRY - MILK
# ---------------------------------------------------------
# Size of the control group: 716.
# Size of the treatment group: 91.
# Coef : -0.049708532200595124
# Rapport: -6.212971525638029
# pvalue : 5.317379448549128e-10
# Std err : 0.008206464977872087
# R2 : 0.4241588785473872
# N : 18443.0
# =========================================================
# ENTRY - NUTS
# ---------------------------------------------------------
# Size of the control group: 219.
# Size of the treatment group: 91.
# Coef : 0.003915716858972962
# Rapport: 0.2184574452726401
# pvalue : 0.8270809073011387
# Std err : 0.017889389804331517
# R2 : 0.2872419038119709
# N : 6393.0
# =========================================================
# ENTRY - PACKAGED MEATS-DELI
# ---------------------------------------------------------
# Size of the control group: 689.
# Size of the treatment group: 91.
# Coef : 0.007434881669694748
# Rapport: 0.6683211902159976
# pvalue : 0.503937807275127
# Std err : 0.011083561736237252
# R2 : 0.2335029826849464
# N : 17782.0
# =========================================================
# ENTRY - PACKAGED MILK AND MODIFIERS
# ---------------------------------------------------------
# Size of the control group: 244.
# Size of the treatment group: 90.
# Coef : -0.0005480316203781976
# Rapport: -0.03696917548108236
# pvalue : 0.9705108076855578
# Std err : 0.014828078729393429
# R2 : 0.29942333199362403
# N : 6984.0
# =========================================================
# ENTRY - PAPER PRODUCTS
# ---------------------------------------------------------
# Size of the control group: 437.
# Size of the treatment group: 91.
# Coef : 0.08888619040351609
# Rapport: 5.342505095199728
# pvalue : 9.356204346156477e-08
# Std err : 0.01593921364958474
# R2 : 0.1701191474833228
# N : 11691.0
# =========================================================
# ENTRY - PASTA
# ---------------------------------------------------------
# Size of the control group: 280.
# Size of the treatment group: 90.
# Coef : 0.011080929189813515
# Rapport: 0.9648878883121775
# pvalue : 0.3346350204534868
# Std err : 0.011421000950173777
# R2 : 0.24423304664449919
# N : 7835.0
# =========================================================
# ENTRY - PET FOOD
# ---------------------------------------------------------
# Size of the control group: 354.
# Size of the treatment group: 91.
# Coef : 0.10221330656572492
# Rapport: 3.0081284262993724
# pvalue : 0.0026361970633664617
# Std err : 0.03235242693621103
# R2 : 0.1606568731329675
# N : 9650.0
# =========================================================
# ENTRY - PICKLES, OLIVES, AND RELISH
# ---------------------------------------------------------
# Size of the control group: 206.
# Size of the treatment group: 91.
# Coef : 0.026930485280145966
# Rapport: 1.9455677312805992
# pvalue : 0.05176190299053178
# Std err : 0.013658862172682036
# R2 : 0.2773600102172169
# N : 6047.0
# =========================================================
# ENTRY - PIZZA/SNACKS/HORS DOEURVES-FRZN
# ---------------------------------------------------------
# Size of the control group: 280.
# Size of the treatment group: 91.
# Coef : -0.024140672684501596
# Rapport: -1.6970453292266952
# pvalue : 0.08973356630125047
# Std err : 0.014399635875988977
# R2 : 0.2526365123249503
# N : 7844.0
# =========================================================
# ENTRY - PREPARED FOOD-DRY MIXES
# ---------------------------------------------------------
# Size of the control group: 378.
# Size of the treatment group: 91.
# Coef : 0.03385290882704073
# Rapport: 2.709883763187366
# pvalue : 0.006743101743506229
# Std err : 0.01228558652591135
# R2 : 0.19019829623029405
# N : 10269.0
# =========================================================
# ENTRY - PREPARED FOOD-READY-TO-SERVE
# ---------------------------------------------------------
# Size of the control group: 304.
# Size of the treatment group: 91.
# Coef : -0.04726945315629005
# Rapport: -2.856921057688143
# pvalue : 0.004289509082287518
# Std err : 0.016949420848879782
# R2 : 0.26502059775328735
# N : 8482.0
# =========================================================
# ENTRY - PREPARED FOODS-FROZEN
# ---------------------------------------------------------
# Size of the control group: 433.
# Size of the treatment group: 91.
# Coef : -0.032281910051703
# Rapport: -2.3973773010599095
# pvalue : 0.016530185493479798
# Std err : 0.013687650875322071
# R2 : 0.17105860352487445
# N : 11582.0
# =========================================================
# ENTRY - SALAD DRESSINGS, MAYO, TOPPINGS
# ---------------------------------------------------------
# Size of the control group: 306.
# Size of the treatment group: 91.
# Coef : 0.010022214186225398
# Rapport: 0.9795476745714203
# pvalue : 0.3273409474666612
# Std err : 0.010180540584151755
# R2 : 0.2908849862040924
# N : 8539.0
# =========================================================
# ENTRY - SHORTENING, OIL
# ---------------------------------------------------------
# Size of the control group: 157.
# Size of the treatment group: 91.
# Coef : 0.02390096591389579
# Rapport: 1.140370135361469
# pvalue : 0.2542017798529916
# Std err : 0.020712405764744812
# R2 : 0.42922433377936886
# N : 4869.0
# =========================================================
# ENTRY - SNACKS
# ---------------------------------------------------------
# Size of the control group: 712.
# Size of the treatment group: 91.
# Coef : 0.025192958159945045
# Rapport: 2.4872622173311094
# pvalue : 0.01288240350655535
# Std err : 0.010003306673178875
# R2 : 0.2152080039089791
# N : 18334.0
# =========================================================
# ENTRY - SOFT DRINKS-NON-CARBONATED
# ---------------------------------------------------------
# Size of the control group: 299.
# Size of the treatment group: 91.
# Coef : 0.054975076984217
# Rapport: 2.9734821506409945
# pvalue : 0.0029539330970775484
# Std err : 0.01799813828571536
# R2 : 0.22987409353085686
# N : 8338.0
# =========================================================
# ENTRY - SOUP
# ---------------------------------------------------------
# Size of the control group: 342.
# Size of the treatment group: 91.
# Coef : -0.021160511436302154
# Rapport: -1.6727063255995094
# pvalue : 0.09442252724994545
# Std err : 0.012786227950896643
# R2 : 0.2601109001749783
# N : 9402.0
# =========================================================
# ENTRY - SPICES, SEASONING, EXTRACTS
# ---------------------------------------------------------
# Size of the control group: 213.
# Size of the treatment group: 91.
# Coef : 0.047529312975085114
# Rapport: 2.324334541701287
# pvalue : 0.020145331935665946
# Std err : 0.019977484022471494
# R2 : 0.262406277660298
# N : 6254.0
# =========================================================
# ENTRY - SUGAR, SWEETENERS
# ---------------------------------------------------------
# Size of the control group: 173.
# Size of the treatment group: 91.
# Coef : 0.018663352241673703
# Rapport: 1.1970538042861323
# pvalue : 0.2313508895465347
# Std err : 0.015447366588874535
# R2 : 0.43310271864803074
# N : 5291.0
# =========================================================
# ENTRY - TEA
# ---------------------------------------------------------
# Size of the control group: 246.
# Size of the treatment group: 90.
# Coef : -0.010150649503164022
# Rapport: -0.65293246177535
# pvalue : 0.5138246793348521
# Std err : 0.015625687563904648
# R2 : 0.2673881242186241
# N : 6993.0
# =========================================================
# ENTRY - UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# ---------------------------------------------------------
# Size of the control group: 685.
# Size of the treatment group: 90.
# Coef : -0.03443112481670618
# Rapport: -3.065948370441854
# pvalue : 0.002173287001153521
# Std err : 0.011428060469165486
# R2 : 0.21519061735893508
# N : 17681.0
# =========================================================
# ENTRY - VEGETABLES - CANNED
# ---------------------------------------------------------
# Size of the control group: 417.
# Size of the treatment group: 91.
# Coef : 0.03710514097615114
# Rapport: 3.1480039397483948
# pvalue : 0.0016486325877970963
# Std err : 0.01157346508056539
# R2 : 0.21927250852352442
# N : 11225.0
# =========================================================
# ENTRY - VEGETABLES-FROZEN
# ---------------------------------------------------------
# Size of the control group: 399.
# Size of the treatment group: 91.
# Coef : -0.03274091453081007
# Rapport: -3.096576422797873
# pvalue : 0.0019632568274020414
# Std err : 0.010750224702210523
# R2 : 0.2185661222911165
# N : 10785.0
# =========================================================
# ENTRY - WRAPPING MATERIALS AND BAGS
# ---------------------------------------------------------
# Size of the control group: 205.
# Size of the treatment group: 91.
# Coef : 0.06500251102044574
# Rapport: 3.324198901235346
# pvalue : 0.0008930472487065287
# Std err : 0.018945062794191374
# R2 : 0.3129345496364875
# N : 5998.0
# =========================================================
# ENTRY - YOGURT
# ---------------------------------------------------------
# Size of the control group: 429.
# Size of the treatment group: 91.
# Coef : 0.028485969362642916
# Rapport: 1.380220910719959
# pvalue : 0.16754822146372997
# Std err : 0.020350212023951875
# R2 : 0.179269559473496
# N : 11467.0
# [['BUTTER AND MARGARINE', 0.02555957645714102, 0.011518240959760402, 0.02846862893561889, 0.3640509968631248, 8986.0], ['CANDY', 0.03418941652907859, 0.01423629152571466, 0.01822023266623719, 0.2520410061663845, 13408.0], ['CONDIMENTS, GRAVIES, AND SAUCES', 0.028135853441919156, 0.01091053334028538, 0.010996827638233482, 0.23219599092555376, 13957.0], ['COOKIES', 0.05206530665042819, 0.010642934613430369, 1.882195371728973e-06, 0.2518094553433209, 9752.0], ['COT CHEESE, SOUR CREAM, TOPPINGS', -0.03697438396875308, 0.010240753933033059, 0.0002356045806953113, 0.3286980877863015, 9738.0], ['CRACKERS', 0.02262377451357267, 0.010698577292652285, 0.036550451414702666, 0.26048759318323356, 9337.0], ['DRESSINGS/SALADS/PREP FOODS-DELI', 0.02748297305233116, 0.012908386366752863, 0.035717242784549734, 0.19471741327713987, 14227.0], ['MILK', -0.049708532200595124, 0.008206464977872087, 5.317379448549128e-10, 0.4241588785473872, 18443.0], ['PAPER PRODUCTS', 0.08888619040351609, 0.01593921364958474, 9.356204346156477e-08, 0.1701191474833228, 11691.0], ['PET FOOD', 0.10221330656572492, 0.03235242693621103, 0.0026361970633664617, 0.1606568731329675, 9650.0], ['PREPARED FOOD-DRY MIXES', 0.03385290882704073, 0.01228558652591135, 0.006743101743506229, 0.19019829623029405, 10269.0], ['PREPARED FOOD-READY-TO-SERVE', -0.04726945315629005, 0.016949420848879782, 0.004289509082287518, 0.26502059775328735, 8482.0], ['PREPARED FOODS-FROZEN', -0.032281910051703, 0.013687650875322071, 0.016530185493479798, 0.17105860352487445, 11582.0], ['SNACKS', 0.025192958159945045, 0.010003306673178875, 0.01288240350655535, 0.2152080039089791, 18334.0], ['SOFT DRINKS-NON-CARBONATED', 0.054975076984217, 0.01799813828571536, 0.0029539330970775484, 0.22987409353085686, 8338.0], ['SPICES, SEASONING, EXTRACTS', 0.047529312975085114, 0.019977484022471494, 0.020145331935665946, 0.262406277660298, 6254.0], ['UNPREP MEAT/POULTRY/SEAFOOD-FRZN', -0.03443112481670618, 0.011428060469165486, 0.002173287001153521, 0.21519061735893508, 17681.0], ['VEGETABLES - CANNED', 0.03710514097615114, 0.01157346508056539, 0.0016486325877970963, 0.21927250852352442, 11225.0], ['VEGETABLES-FROZEN', -0.03274091453081007, 0.010750224702210523, 0.0019632568274020414, 0.2185661222911165, 10785.0], ['WRAPPING MATERIALS AND BAGS', 0.06500251102044574, 0.018945062794191374, 0.0008930472487065287, 0.3129345496364875, 5998.0]]

# %% [markdown]
# ## 2. Exits

# %% [markdown]
# ### A) Pooled values

# %%
# Taking the average price per category to have a first overview of the effect
pool = pd.DataFrame(nielsen.groupby(['is_walmart', 'store_state', 'guessed_store_county', 'guessed_store_county_fips', 'purchase_year', 'purchase_month']).mean()['upc_price']).reset_index()

# %%
print("=========================================================")
print("EXIT - Pooled results")
print('---------------------------------------------------------')

product_group = pool


# The control group is composed by all states where nothing (no entry nor exit) happened.
control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()

# We keep in the control group the only counties where we have data for the entire time period (24 months)
nb_months = control.groupby('guessed_store_county_fips').count()
control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]
print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")



# The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
count = movements.groupby('County_fips').count()
count = count[count.State == 1] # No more than one movement in the treatement group
treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
treatment_movements = treatment_movements[(treatment_movements.Closing_date>='2015-01-31' ) & (treatment_movements.Closing_date<='2017-01-31') & (treatment_movements.Opening_date<'2015-01-31')] # Treatment group composed by the exits

treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



# Creating the dummies
control['treat'] = False
control['interaction'] = False
control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015) # Creating one unique time variable
control['effects'] = list(zip(control.store_state, control.purchase_0)) # Crontrolling for time * state

treatment['treat'] = True
treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015) # Creating one unique time variable
treatment['closing_0'] = treatment.Closing_date.dt.month  + 12 * (treatment.Closing_date.dt.year - 2015)
treatment['interaction'] = treatment.purchase_0 >= treatment.closing_0 # The post dummy equals to one in the treatment group, after the closing month
treatment = treatment[abs(treatment.purchase_0-treatment.closing_0) > dropping_period]
treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0)) # Crontrolling for time * state



# Final dataset for the regression :
df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects']]
df = df[df.upc_price != 0] # Dropping the errors in the set


reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
results1 = reg1.fit()

print(f"Coef : {np.exp(results1.params[2])-1}")
print(f"pvalue : { results1.pvalues[2]}")
print(f"Std err : { results1.bse[2]}")
print(f"R2 : { results1.rsquared}")
print(f"N : { results1.nobs}")
# Out:
# =========================================================
# EXIT - Pooled results
# ---------------------------------------------------------
# Size of the control group: 1457.
# Size of the treatment group: 43.
# Coef : -0.01195424470475881
# pvalue : 0.5877117693741167
# Std err : 0.022182142733557227
# R2 : 0.15426413736214695
# N : 35499.0

# %% [markdown]
# ### B) Other categories

# %%
# Focusing on the categories with the highest number of observations
categories_count = nielsen.groupby('product_group_descr').count()
categories = categories_count[categories_count.is_walmart>=25000].index

# It could be :
# categories = nielsen.product_group_descr.unique()

# %%
data = []

for category in categories:
    print("=========================================================")
    print(f"EXIT - {category}")
    print('---------------------------------------------------------')

    product_group = nielsen[nielsen.product_group_descr == category]


    # The control group is composed by all states where nothing (no entry nor exit) happened.
    control = product_group[~np.isin(product_group.guessed_store_county_fips, movements)].copy()

    # Keeping in the control group the only counties where we have data for the entire time period (24 months)
    nb_months = control.groupby('guessed_store_county_fips').count()
    control = control[np.isin(control.guessed_store_county_fips, nb_months[nb_months.is_walmart==24].index)]

    # Keeping in the control group the only counties where 4 observations per month and category at least
    nb_obs = control.groupby('guessed_store_county_fips').min()
    control = control[np.isin(control.guessed_store_county_fips, nb_obs[nb_obs.nb_of_obs > 3].index)]
    print(f"Size of the control group: {len(control.guessed_store_county_fips.unique())}.")


    # The treatment group is composed by the states where one entry took place in 2016 and where this entry is the only movement
    count = movements.groupby('County_fips').count()
    count = count[count.State == 1] # No more than one movement in the treatement group
    treatment_movements = movements[(np.isin(movements.County_fips, count.index))]
    treatment_movements = treatment_movements[(treatment_movements.Closing_date>='2015-01-31' ) & (treatment_movements.Closing_date<='2017-01-31') & ((treatment_movements.Opening_date<'2015-01-31'))] # Treatment group composed by the entries

    treatment = product_group[np.isin(product_group.guessed_store_county_fips, treatment_movements.County_fips )].copy()
    treatment = treatment.merge(treatment_movements, left_on='guessed_store_county_fips', right_on='County_fips')
    print(f"Size of the treatment group: {len(treatment.guessed_store_county_fips.unique())}.")



    # Creating the dummies
    control['treat'] = False
    control['interaction'] = False
    control['purchase_0'] = control.purchase_month + 12 * (control.purchase_year - 2015) # Creating one unique time variable
    control['effects'] = list(zip(control.store_state, control.purchase_0)) # Crontrolling for time * state

    treatment['treat'] = True
    treatment['purchase_0'] = treatment.purchase_month + 12 * (treatment.purchase_year - 2015) # Creating one unique time variable
    treatment['closing_0'] = treatment.Closing_date.dt.month  + 12 * (treatment.Closing_date.dt.year - 2015)
    treatment['interaction'] = treatment.purchase_0 >= treatment.closing_0 # The post dummy equals to one in the treatment group, after the closing month
    treatment = treatment[abs(treatment.purchase_0-treatment.closing_0) > dropping_period]
    treatment['effects'] = list(zip(treatment.store_state, treatment.purchase_0)) # Crontrolling for time * state



    # Final dataset for the regression :
    df = pd.concat((control, treatment))[['upc_price', 'treat', 'interaction', 'effects']]
    df = df[df.upc_price != 0] # Dropping the errors in the set

    try:
        reg1 = smf.ols(formula='np.log(upc_price) ~ treat + interaction + C(effects)', data=df)
        results1 = reg1.fit()

        print(f"Coef : {np.exp(results1.params[2])-1}")
        print(f"Rapport: {results1.params[2]/results1.bse[2]} ")
        print(f"pvalue : { results1.pvalues[2]}")
        print(f"Std err : { results1.bse[2]}")
        print(f"R2 : { results1.rsquared}")
        print(f"N : { results1.nobs}")

    except:
        print('Method does not converge')

    if results1.params[2]/results1.bse[2] > 2.:
        data.append([category, np.exp(results1.params[2])-1, results1.bse[2], results1.pvalues[2], results1.rsquared, results1.nobs])

print(data)
# Out:
# =========================================================
# EXIT - BAKED GOODS-FROZEN
# ---------------------------------------------------------
# Size of the control group: 118.
# Size of the treatment group: 42.
# Coef : 0.020960855087863495
# Rapport: 0.7022280341007358
# pvalue : 0.4826049206960059
# Std err : 0.029540544756636075
# R2 : 0.4129158128833499
# N : 3214.0
# =========================================================
# EXIT - BAKING MIXES
# ---------------------------------------------------------
# Size of the control group: 209.
# Size of the treatment group: 42.
# Coef : 0.01007536490850991
# Rapport: 0.3759251908962499
# pvalue : 0.7069899460106576
# Std err : 0.02666739828402053
# R2 : 0.3618792380268543
# N : 5407.0
# =========================================================
# EXIT - BAKING SUPPLIES
# ---------------------------------------------------------
# Size of the control group: 256.
# Size of the treatment group: 43.
# Coef : 0.0007602257260281853
# Rapport: 0.031220037980654362
# pvalue : 0.9750951593152173
# Std err : 0.02434131890851756
# R2 : 0.2589770384443839
# N : 6526.0
# =========================================================
# EXIT - BREAD AND BAKED GOODS
# ---------------------------------------------------------
# Size of the control group: 833.
# Size of the treatment group: 43.
# Coef : -0.039670389424919184
# Rapport: -2.226434176033645
# pvalue : 0.02599652004098097
# Std err : 0.018180959282841903
# R2 : 0.2609528421590471
# N : 20487.0
# =========================================================
# EXIT - BREAKFAST FOOD
# ---------------------------------------------------------
# Size of the control group: 269.
# Size of the treatment group: 38.
# Coef : -0.014566195106122892
# Rapport: -0.7639617207316075
# pvalue : 0.44492045469076225
# Std err : 0.019206883413881482
# R2 : 0.2546502663221436
# N : 6796.0
# =========================================================
# EXIT - BUTTER AND MARGARINE
# ---------------------------------------------------------
# Size of the control group: 325.
# Size of the treatment group: 42.
# Coef : -0.04886297486051494
# Rapport: -2.308529904686906
# pvalue : 0.02099780439605166
# Std err : 0.021700884789993814
# R2 : 0.37169888782305793
# N : 8209.0
# =========================================================
# EXIT - CANDY
# ---------------------------------------------------------
# Size of the control group: 508.
# Size of the treatment group: 42.
# Coef : -0.048745990799707095
# Rapport: -1.961543821535636
# pvalue : 0.04983959681809517
# Std err : 0.025476950655518523
# R2 : 0.25510174863200963
# N : 12587.0
# =========================================================
# EXIT - CARBONATED BEVERAGES
# ---------------------------------------------------------
# Size of the control group: 574.
# Size of the treatment group: 43.
# Coef : 0.03754914199093462
# Rapport: 1.4384229949125908
# pvalue : 0.15033780187927212
# Std err : 0.02562621558871024
# R2 : 0.22392256143114164
# N : 14222.0
# =========================================================
# EXIT - CEREAL
# ---------------------------------------------------------
# Size of the control group: 465.
# Size of the treatment group: 41.
# Coef : -0.03801589854893683
# Rapport: -2.49203100438489
# pvalue : 0.012716685939641365
# Std err : 0.015552517180944369
# R2 : 0.17903743089430424
# N : 11563.0
# =========================================================
# EXIT - CHEESE
# ---------------------------------------------------------
# Size of the control group: 687.
# Size of the treatment group: 43.
# Coef : -0.02776835414598422
# Rapport: -1.8027945550228641
# pvalue : 0.07143937354314456
# Std err : 0.015620850449539222
# R2 : 0.2480649930924922
# N : 16967.0
# =========================================================
# EXIT - COFFEE
# ---------------------------------------------------------
# Size of the control group: 284.
# Size of the treatment group: 40.
# Coef : -0.06788522310721479
# Rapport: -3.3324590580525504
# pvalue : 0.0008658155236888209
# Std err : 0.021095329149398392
# R2 : 0.2076806433594699
# N : 7192.0
# =========================================================
# EXIT - CONDIMENTS, GRAVIES, AND SAUCES
# ---------------------------------------------------------
# Size of the control group: 530.
# Size of the treatment group: 43.
# Coef : 0.0014923120403922407
# Rapport: 0.08055130831971374
# pvalue : 0.9358001172222961
# Std err : 0.018512419977251157
# R2 : 0.24208700016847717
# N : 13185.0
# =========================================================
# EXIT - COOKIES
# ---------------------------------------------------------
# Size of the control group: 357.
# Size of the treatment group: 41.
# Coef : -0.026317200532066765
# Rapport: -1.4728578165987138
# pvalue : 0.14082858715862312
# Std err : 0.018107447967988913
# R2 : 0.246091766697074
# N : 8978.0
# =========================================================
# EXIT - COT CHEESE, SOUR CREAM, TOPPINGS
# ---------------------------------------------------------
# Size of the control group: 356.
# Size of the treatment group: 42.
# Coef : -0.006514551701724991
# Rapport: -0.35313182296713286
# pvalue : 0.7239989276763308
# Std err : 0.018508283816604146
# R2 : 0.3432083418609444
# N : 8961.0
# =========================================================
# EXIT - CRACKERS
# ---------------------------------------------------------
# Size of the control group: 340.
# Size of the treatment group: 42.
# Coef : 0.014100932424916834
# Rapport: 0.7626893063053043
# pvalue : 0.4456722317657109
# Std err : 0.018359296479121302
# R2 : 0.26071756495082665
# N : 8554.0
# =========================================================
# EXIT - DESSERTS, GELATINS, SYRUP
# ---------------------------------------------------------
# Size of the control group: 251.
# Size of the treatment group: 41.
# Coef : -0.0026921929001570977
# Rapport: -0.09694159413130854
# pvalue : 0.9227763149424281
# Std err : 0.027808737756296838
# R2 : 0.2725174428286494
# N : 6386.0
# =========================================================
# EXIT - DETERGENTS
# ---------------------------------------------------------
# Size of the control group: 239.
# Size of the treatment group: 38.
# Coef : 0.01433824409266049
# Rapport: 0.44913343334429784
# pvalue : 0.6533540419509307
# Std err : 0.03169753695557153
# R2 : 0.25465852642307485
# N : 6079.0
# =========================================================
# EXIT - DOUGH PRODUCTS
# ---------------------------------------------------------
# Size of the control group: 126.
# Size of the treatment group: 43.
# Coef : 0.011878074977749842
# Rapport: 0.4409818107837601
# pvalue : 0.6592629005331615
# Std err : 0.026776805862080224
# R2 : 0.4637360389615578
# N : 3392.0
# =========================================================
# EXIT - DRESSINGS/SALADS/PREP FOODS-DELI
# ---------------------------------------------------------
# Size of the control group: 541.
# Size of the treatment group: 42.
# Coef : 0.04933133179661686
# Rapport: 2.1532611417250918
# pvalue : 0.031317380869963385
# Std err : 0.02236288646816654
# R2 : 0.2035916219414946
# N : 13435.0
# =========================================================
# EXIT - EGGS
# ---------------------------------------------------------
# Size of the control group: 415.
# Size of the treatment group: 43.
# Coef : 0.012962864982843492
# Rapport: 0.6181903749596599
# pvalue : 0.5364648746254581
# Std err : 0.020834303895845174
# R2 : 0.7559221339263638
# N : 10386.0
# =========================================================
# EXIT - FRESH PRODUCE
# ---------------------------------------------------------
# Size of the control group: 959.
# Size of the treatment group: 43.
# Coef : 0.001659917778356057
# Rapport: 0.10114739094245898
# pvalue : 0.9194343602463049
# Std err : 0.016397275520704913
# R2 : 0.1673303618238975
# N : 23519.0
# =========================================================
# EXIT - FRUIT - CANNED
# ---------------------------------------------------------
# Size of the control group: 178.
# Size of the treatment group: 39.
# Coef : 0.055018215235765666
# Rapport: 2.0542376043224704
# pvalue : 0.0400214814274323
# Std err : 0.026071975458244655
# R2 : 0.31373268332782356
# N : 4640.0
# =========================================================
# EXIT - ICE CREAM, NOVELTIES
# ---------------------------------------------------------
# Size of the control group: 376.
# Size of the treatment group: 41.
# Coef : -0.0017457901376763951
# Rapport: -0.11318925121044944
# pvalue : 0.9098832031960127
# Std err : 0.015437117805047978
# R2 : 0.3081409094549752
# N : 9458.0
# =========================================================
# EXIT - JAMS, JELLIES, SPREADS
# ---------------------------------------------------------
# Size of the control group: 237.
# Size of the treatment group: 42.
# Coef : -0.025338409480169077
# Rapport: -1.0012548265526504
# pvalue : 0.31675063102201556
# Std err : 0.025632790173400467
# R2 : 0.28205130395633726
# N : 6044.0
# =========================================================
# EXIT - JUICE, DRINKS - CANNED, BOTTLED
# ---------------------------------------------------------
# Size of the control group: 499.
# Size of the treatment group: 41.
# Coef : -0.01718701972210901
# Rapport: -0.9052562475019027
# pvalue : 0.36534876712244757
# Std err : 0.019150854826144197
# R2 : 0.22450429308937214
# N : 12418.0
# =========================================================
# EXIT - MEDICATIONS/REMEDIES/HEALTH AIDS
# ---------------------------------------------------------
# Size of the control group: 339.
# Size of the treatment group: 37.
# Coef : -0.042023584955430016
# Rapport: -0.7753740297749908
# pvalue : 0.43814304807789073
# Std err : 0.055369561807705706
# R2 : 0.14840941069631863
# N : 8474.0
# =========================================================
# EXIT - MILK
# ---------------------------------------------------------
# Size of the control group: 716.
# Size of the treatment group: 43.
# Coef : -0.006622981692809726
# Rapport: -0.4777039346533415
# pvalue : 0.6328672238779042
# Std err : 0.013910312380049394
# R2 : 0.41024949191672744
# N : 17659.0
# =========================================================
# EXIT - NUTS
# ---------------------------------------------------------
# Size of the control group: 219.
# Size of the treatment group: 40.
# Coef : -0.10481012593240946
# Rapport: -3.406071700627623
# pvalue : 0.0006645056157896023
# Std err : 0.032506489335287644
# R2 : 0.3223791430152554
# N : 5610.0
# =========================================================
# EXIT - PACKAGED MEATS-DELI
# ---------------------------------------------------------
# Size of the control group: 689.
# Size of the treatment group: 43.
# Coef : -0.016646910928388214
# Rapport: -0.9124708076200257
# pvalue : 0.36153467734014766
# Std err : 0.01839733150551881
# R2 : 0.2317500635502978
# N : 17035.0
# =========================================================
# EXIT - PACKAGED MILK AND MODIFIERS
# ---------------------------------------------------------
# Size of the control group: 244.
# Size of the treatment group: 41.
# Coef : -0.06951774360426966
# Rapport: -2.901824826644411
# pvalue : 0.0037251622139719957
# Std err : 0.024829986742255485
# R2 : 0.3066173855282167
# N : 6210.0
# =========================================================
# EXIT - PAPER PRODUCTS
# ---------------------------------------------------------
# Size of the control group: 437.
# Size of the treatment group: 42.
# Coef : 0.07202600705932638
# Rapport: 2.5609892145459194
# pvalue : 0.010452154196755263
# Std err : 0.02715760077232542
# R2 : 0.17692815489723446
# N : 10910.0
# =========================================================
# EXIT - PASTA
# ---------------------------------------------------------
# Size of the control group: 280.
# Size of the treatment group: 39.
# Coef : -0.03482594713003917
# Rapport: -1.8099450468468326
# pvalue : 0.07035267724797531
# Std err : 0.019584477606368538
# R2 : 0.2425481782226495
# N : 7093.0
# =========================================================
# EXIT - PET FOOD
# ---------------------------------------------------------
# Size of the control group: 354.
# Size of the treatment group: 36.
# Coef : -0.10326828324712767
# Rapport: -1.8225354887086112
# pvalue : 0.06841169171660098
# Std err : 0.059805996534217205
# R2 : 0.17081652724417673
# N : 8871.0
# =========================================================
# EXIT - PICKLES, OLIVES, AND RELISH
# ---------------------------------------------------------
# Size of the control group: 206.
# Size of the treatment group: 39.
# Coef : -0.02147930695429867
# Rapport: -0.8911600885601132
# pvalue : 0.3728920309046835
# Std err : 0.024365257069558607
# R2 : 0.2625765075612694
# N : 5303.0
# =========================================================
# EXIT - PIZZA/SNACKS/HORS DOEURVES-FRZN
# ---------------------------------------------------------
# Size of the control group: 280.
# Size of the treatment group: 40.
# Coef : -0.05912001723185634
# Rapport: -2.2836128309329164
# pvalue : 0.022428178160492026
# Std err : 0.02668564869162917
# R2 : 0.25097252125364145
# N : 7112.0
# =========================================================
# EXIT - PREPARED FOOD-DRY MIXES
# ---------------------------------------------------------
# Size of the control group: 378.
# Size of the treatment group: 42.
# Coef : -0.07203607604795714
# Rapport: -3.4299512907469505
# pvalue : 0.0006065580932767395
# Std err : 0.02179693402788457
# R2 : 0.19238301849095274
# N : 9489.0
# =========================================================
# EXIT - PREPARED FOOD-READY-TO-SERVE
# ---------------------------------------------------------
# Size of the control group: 304.
# Size of the treatment group: 43.
# Coef : 0.01256321090960233
# Rapport: 0.41842648888357115
# pvalue : 0.6756485777091517
# Std err : 0.02983785422181794
# R2 : 0.25878386254053143
# N : 7709.0
# =========================================================
# EXIT - PREPARED FOODS-FROZEN
# ---------------------------------------------------------
# Size of the control group: 433.
# Size of the treatment group: 42.
# Coef : 0.03609135694389787
# Rapport: 1.4943496487010342
# pvalue : 0.13511627455602765
# Std err : 0.02372625600611834
# R2 : 0.17292546574063095
# N : 10830.0
# =========================================================
# EXIT - SALAD DRESSINGS, MAYO, TOPPINGS
# ---------------------------------------------------------
# Size of the control group: 306.
# Size of the treatment group: 43.
# Coef : -0.0018348635220537535
# Rapport: -0.10442982089308445
# pvalue : 0.9168313153322434
# Std err : 0.017586441597022096
# R2 : 0.3329268869132178
# N : 7771.0
# =========================================================
# EXIT - SHORTENING, OIL
# ---------------------------------------------------------
# Size of the control group: 157.
# Size of the treatment group: 40.
# Coef : -0.031216064782171093
# Rapport: -0.9255087828563499
# pvalue : 0.35476899176582277
# Std err : 0.0342661999683695
# R2 : 0.4392705008055823
# N : 4144.0
# =========================================================
# EXIT - SNACKS
# ---------------------------------------------------------
# Size of the control group: 712.
# Size of the treatment group: 43.
# Coef : 0.007050570303709591
# Rapport: 0.41837639125972
# pvalue : 0.6756773795267724
# Std err : 0.016793087264445842
# R2 : 0.21476781426467806
# N : 17566.0
# =========================================================
# EXIT - SOFT DRINKS-NON-CARBONATED
# ---------------------------------------------------------
# Size of the control group: 299.
# Size of the treatment group: 40.
# Coef : -0.08065853786020272
# Rapport: -2.5263064390037755
# pvalue : 0.01154976994542999
# Std err : 0.03328878317024718
# R2 : 0.23818601512972803
# N : 7558.0
# =========================================================
# EXIT - SOUP
# ---------------------------------------------------------
# Size of the control group: 342.
# Size of the treatment group: 43.
# Coef : 0.04999456064255603
# Rapport: 2.062067314428234
# pvalue : 0.039235190150891025
# Std err : 0.02365828868642832
# R2 : 0.2676608127188743
# N : 8615.0
# =========================================================
# EXIT - SPICES, SEASONING, EXTRACTS
# ---------------------------------------------------------
# Size of the control group: 213.
# Size of the treatment group: 41.
# Coef : -0.014720123675888708
# Rapport: -0.4164333880603201
# pvalue : 0.6771121957860964
# Std err : 0.035610832836144704
# R2 : 0.2556892385063365
# N : 5500.0
# =========================================================
# EXIT - SUGAR, SWEETENERS
# ---------------------------------------------------------
# Size of the control group: 173.
# Size of the treatment group: 43.
# Coef : -0.06520124724172649
# Rapport: -2.526844509997216
# pvalue : 0.011550401576403446
# Std err : 0.026683086468255495
# R2 : 0.412285697055935
# N : 4552.0
# =========================================================
# EXIT - TEA
# ---------------------------------------------------------
# Size of the control group: 246.
# Size of the treatment group: 40.
# Coef : 0.05436317224984388
# Rapport: 1.9866078409767465
# pvalue : 0.047016406385259814
# Std err : 0.026646908051039284
# R2 : 0.2643889923417836
# N : 6282.0
# =========================================================
# EXIT - UNPREP MEAT/POULTRY/SEAFOOD-FRZN
# ---------------------------------------------------------
# Size of the control group: 685.
# Size of the treatment group: 43.
# Method does not converge
# =========================================================
# EXIT - VEGETABLES - CANNED
# ---------------------------------------------------------
# Size of the control group: 417.
# Size of the treatment group: 43.
# Method does not converge
# =========================================================
# EXIT - VEGETABLES-FROZEN
# ---------------------------------------------------------
# Size of the control group: 399.
# Size of the treatment group: 42.
# Coef : -0.014764034907780665
# Rapport: -0.7922946511929008
# pvalue : 0.42820977479663636
# Std err : 0.01877345506238548
# R2 : 0.21648177939352742
# N : 10011.0
# =========================================================
# EXIT - WRAPPING MATERIALS AND BAGS
# ---------------------------------------------------------
# Size of the control group: 205.
# Size of the treatment group: 40.
# Coef : -0.018273308790765608
# Rapport: -0.5605379438494746
# pvalue : 0.5751410152545497
# Std err : 0.032901123094377246
# R2 : 0.2678726262150378
# N : 5267.0
# =========================================================
# EXIT - YOGURT
# ---------------------------------------------------------
# Size of the control group: 429.
# Size of the treatment group: 41.
# Coef : -0.028229490853060035
# Rapport: -0.7642504220119205
# pvalue : 0.4447366601345585
# Std err : 0.03746887574283188
# R2 : 0.17952340213615015
# N : 10676.0
# [['DRESSINGS/SALADS/PREP FOODS-DELI', 0.04933133179661686, 0.02236288646816654, 0.031317380869963385, 0.2035916219414946, 13435.0], ['FRUIT - CANNED', 0.055018215235765666, 0.026071975458244655, 0.0400214814274323, 0.31373268332782356, 4640.0], ['PAPER PRODUCTS', 0.07202600705932638, 0.02715760077232542, 0.010452154196755263, 0.17692815489723446, 10910.0], ['SOUP', 0.04999456064255603, 0.02365828868642832, 0.039235190150891025, 0.2676608127188743, 8615.0]]
